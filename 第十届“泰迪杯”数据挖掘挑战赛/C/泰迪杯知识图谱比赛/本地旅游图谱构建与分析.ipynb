# %% [markdown]
# ##  导入相关包

# %%
import pandas as pd 
import numpy as np
import math
import jieba
from gensim.models import Word2Vec

# %% [markdown]
# ## 读取数据

# %%
# 所有实体
all_entity = pd.read_csv('data/所有实体.csv')
# OTA,UGC数据
df1 = pd.read_csv('data/游记攻略标注后的数据.csv')
df2 = pd.read_csv('data/酒店评论标注后的数据.csv')
df3 = pd.read_csv('data/景区标注后的数据.csv')
df4 = pd.read_csv('data/餐饮标注后的数据.csv')
df_entity = pd.read_csv('data/result2-2.csv')

# %%
df_entity
# Out:
#      产品ID   产品名称  产品热度    年份
# 0    ID26   海滨公园  0.85  2021
# 1    ID56    叉烧饭  0.44  2021
# 2    ID72  脆皮热狗卷  0.41  2020
# 3    ID54   榴莲千层  0.38  2019
# 4    ID33  御水古温泉  0.38  2018
# ..    ...    ...   ...   ...
# 355  ID37     玉湖  0.05  2018
# 356  ID14  红树林栈道  0.05  2018
# 357  ID13     荔枝  0.05  2020
# 358  ID67     蛋挞  0.05  2020
# 359  ID38  野菠萝公园  0.05  2018
#
# [360 rows x 4 columns]

# %%
texts = df1['正文'].astype(str).tolist() + df2['评论内容'].astype(str).tolist() + df3['评论内容'].astype(str).tolist() + df4['评论内容'].astype(str).tolist()

# %% [markdown]
# ## 关联分析

# %% [markdown]
# ### PMI互信息值

# %%
def pmi(texts=None, entity1=None, entity2=None):
    '''
    texts：语料文档
    entity：某个实体
    '''
    tl = len(texts)  # 文档长度
    pmi_value = 0
    w1 = 0
    w2 = 0
    w12 = 0
    for text in texts:
        if entity1 in text:
            w1 += 1
        if entity2 in text:
            w2 += 1
        if entity1 in text and entity2 in text:
            w12 += 1
    try:
        p = np.log2((w12/tl) / ((w1/tl) * (w2/tl)))
        if p == -np.inf:
            p = 0
        pmi_value += p # 计算PMI
    except:
        pass
    return round(pmi_value, 2)

# %%
entitys_pmis = {}
idxs = df_entity['产品ID'].tolist()
entitys = df_entity['产品名称'].tolist()
for e1 in  range(len(entitys)-1):
    for e2 in  range(e1+1, len(entitys)):
        entitys_pmis[entitys[e1] + '-' + entitys[e2]] = [pmi(texts, entitys[e1], entitys[e2]), idxs[e1] + '-' + idxs[e2]]
# Out:
# D:\anaconda\envs\pytorch\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log2

# %%
# entitys_pmis
# Out:
# {'海滨公园-叉烧饭': [0, 'ID26-ID56'],
#  '海滨公园-脆皮热狗卷': [0, 'ID26-ID72'],
#  '海滨公园-榴莲千层': [0, 'ID26-ID54'],
#  '海滨公园-御水古温泉': [0, 'ID26-ID33'],
#  '海滨公园-大角湾': [0, 'ID26-ID27'],
#  '海滨公园-雅米乐园': [0, 'ID26-ID51'],
#  '海滨公园-甜点': [0, 'ID26-ID12'],
#  '海滨公园-蛋挞': [0, 'ID26-ID67'],
#  '海滨公园-文化广场': [0, 'ID26-ID6'],
#  '海滨公园-小东江': [0, 'ID26-ID9'],
#  '海滨公园-拉面': [0, 'ID26-ID65'],
#  '海滨公园-东南码头': [0, 'ID26-ID40'],
#  '海滨公园-骑楼': [6.05, 'ID26-ID31'],
#  '海滨公园-凉拌菜': [0, 'ID26-ID89'],
#  '海滨公园-甜品': [0, 'ID26-ID49'],
#  '海滨公园-UNPOCO柏蔻': [0, 'ID26-ID80'],
#  '海滨公园-沙滩': [3.98, 'ID26-ID5'],
#  '海滨公园-烧鸭饭': [0, 'ID26-ID57'],
#  '海滨公园-海滨公园': [9.05, 'ID26-ID26'],
#  '海滨公园-煲仔饭': [0, 'ID26-ID88'],
#  '海滨公园-北洛湾': [0, 'ID26-ID25'],
#  '海滨公园-面包': [0, 'ID26-ID11'],
#  '海滨公园-水东湾': [5.15, 'ID26-ID45'],
#  '海滨公园-炸鸡': [0, 'ID26-ID59'],
#  '海滨公园-火腿': [0, 'ID26-ID71'],
#  '海滨公园-肉松': [0, 'ID26-ID63'],
#  '海滨公园-东湖': [6.25, 'ID26-ID15'],
#  '海滨公园-I': [0, 'ID26-ID8'],
#  '海滨公园-黄油': [0, 'ID26-ID75'],
#  '海滨公园-三元塔': [0, 'ID26-ID32'],
#  '海滨公园-湖光岩': [5.05, 'ID26-ID36'],
#  '海滨公园-蔬菜': [0, 'ID26-ID58'],
#  '海滨公园-日式蟹肉卷': [0, 'ID26-ID78'],
#  '海滨公园-油条碎': [0, 'ID26-ID84'],
#  '海滨公园-牛肉': [2.5, 'ID26-ID66'],
#  '海滨公园-小炒': [0, 'ID26-ID50'],
#  '海滨公园-野菠萝公园': [0, 'ID26-ID38'],
#  '海滨公园-和牛盖饭': [0, 'ID26-ID77'],
#  '海滨公园-饮料': [0, 'ID26-ID16'],
#  '海滨公园-温德姆酒店': [0, 'ID26-ID39'],
#  '海滨公园-泡芙': [0, 'ID26-ID62'],
#  '海滨公园-牛排': [0, 'ID26-ID42'],
#  '海滨公园-牛肚': [0, 'ID26-ID74'],
#  '海滨公园-晏镜岭': [0, 'ID26-ID17'],
#  '海滨公园-刺身': [0, 'ID26-ID70'],
#  '海滨公园-自助菜': [0, 'ID26-ID85'],
#  '海滨公园-游乐场': [7.21, 'ID26-ID23'],
#  '海滨公园-中心广场': [0, 'ID26-ID3'],
#  '海滨公园-摩天轮': [6.55, 'ID26-ID24'],
#  '海滨公园-高钙大骨鸳鸯锅': [0, 'ID26-ID79'],
#  '海滨公园-天马山': [0, 'ID26-ID19'],
#  '海滨公园-赤坎老街': [8.05, 'ID26-ID48'],
#  '海滨公园-玉湖': [0, 'ID26-ID37'],
#  '海滨公园-菠萝皮': [0, 'ID26-ID87'],
#  '海滨公园-热狗': [0, 'ID26-ID46'],
#  '海滨公园-红树林': [6.15, 'ID26-ID10'],
#  '海滨公园-菠萝包': [0, 'ID26-ID86'],
#  '海滨公园-米饭': [0, 'ID26-ID61'],
#  '海滨公园-无花果': [0, 'ID26-ID82'],
#  '海滨公园-关东煮': [0, 'ID26-ID90'],
#  '海滨公园-荔枝': [0, 'ID26-ID13'],
#  '海滨公园-架海灯塔': [0, 'ID26-ID18'],
#  '海滨公园-望海楼': [0, 'ID26-ID41'],
#  '海滨公园-无花果萨拉米披萨': [0, 'ID26-ID81'],
#  '海滨公园-早茶': [0, 'ID26-ID7'],
#  '海滨公园-红树林栈道': [6.25, 'ID26-ID14'],
#  '海滨公园-榴莲蛋糕': [0, 'ID26-ID52'],
#  '海滨公园-炒乌冬': [0, 'ID26-ID68'],
#  '海滨公园-酱汁': [0, 'ID26-ID76'],
#  '海滨公园-奶油': [0, 'ID26-ID53'],
#  '海滨公园-博物馆': [3.44, 'ID26-ID20'],
#  '海滨公园-海鲜': [3.32, 'ID26-ID4'],
#  '海滨公园-海陵岛': [0, 'ID26-ID22'],
#  '海滨公园-高州仙人洞景区': [0, 'ID26-ID47'],
#  '海滨公园-湛江大桥': [0, 'ID26-ID44'],
#  '海滨公园-寿司': [0, 'ID26-ID55'],
#  '海滨公园-新湖公园': [0, 'ID26-ID43'],
#  '海滨公园-海滩': [0, 'ID26-ID1'],
#  '海滨公园-玻璃桥': [0, 'ID26-ID21'],
#  '海滨公园-第一滩': [0, 'ID26-ID2'],
#  '海滨公园-蜂蜜芥末': [0, 'ID26-ID60'],
#  '海滨公园-生蚝': [3.81, 'ID26-ID35'],
#  '海滨公园-十里军港': [7.47, 'ID26-ID30'],
#  '海滨公园-凤梨': [0, 'ID26-ID69'],
#  '海滨公园-炒牛河': [0, 'ID26-ID73'],
#  '海滨公园-露天矿生态公园': [0, 'ID26-ID28'],
#  '海滨公园-薯条': [0, 'ID26-ID64'],
#  '海滨公园-雷州古城': [0, 'ID26-ID34'],
#  '海滨公园-粗薯': [0, 'ID26-ID83'],
#  '海滨公园-露天矿': [3.47, 'ID26-ID29'],
#  '叉烧饭-脆皮热狗卷': [0, 'ID56-ID72'],
#  '叉烧饭-榴莲千层': [0, 'ID56-ID54'],
#  '叉烧饭-御水古温泉': [0, 'ID56-ID33'],
#  '叉烧饭-大角湾': [0, 'ID56-ID27'],
#  '叉烧饭-雅米乐园': [0, 'ID56-ID51'],
#  '叉烧饭-甜点': [0, 'ID56-ID12'],
#  '叉烧饭-蛋挞': [0, 'ID56-ID67'],
#  '叉烧饭-文化广场': [0, 'ID56-ID6'],
#  '叉烧饭-小东江': [0, 'ID56-ID9'],
#  '叉烧饭-拉面': [5.32, 'ID56-ID65'],
#  '叉烧饭-东南码头': [0, 'ID56-ID40'],
#  '叉烧饭-骑楼': [0, 'ID56-ID31'],
#  '叉烧饭-凉拌菜': [0, 'ID56-ID89'],
#  '叉烧饭-甜品': [0, 'ID56-ID49'],
#  '叉烧饭-UNPOCO柏蔻': [0, 'ID56-ID80'],
#  '叉烧饭-沙滩': [0, 'ID56-ID5'],
#  '叉烧饭-烧鸭饭': [6.82, 'ID56-ID57'],
#  '叉烧饭-海滨公园': [0, 'ID56-ID26'],
#  '叉烧饭-煲仔饭': [0, 'ID56-ID88'],
#  '叉烧饭-北洛湾': [0, 'ID56-ID25'],
#  '叉烧饭-面包': [0, 'ID56-ID11'],
#  '叉烧饭-水东湾': [0, 'ID56-ID45'],
#  '叉烧饭-炸鸡': [0, 'ID56-ID59'],
#  '叉烧饭-火腿': [0, 'ID56-ID71'],
#  '叉烧饭-肉松': [0, 'ID56-ID63'],
#  '叉烧饭-东湖': [0, 'ID56-ID15'],
#  '叉烧饭-I': [0, 'ID56-ID8'],
#  '叉烧饭-黄油': [0, 'ID56-ID75'],
#  '叉烧饭-叉烧饭': [9.32, 'ID56-ID56'],
#  '叉烧饭-三元塔': [0, 'ID56-ID32'],
#  '叉烧饭-湖光岩': [0, 'ID56-ID36'],
#  '叉烧饭-蔬菜': [0, 'ID56-ID58'],
#  '叉烧饭-日式蟹肉卷': [0, 'ID56-ID78'],
#  '叉烧饭-油条碎': [0, 'ID56-ID84'],
#  '叉烧饭-牛肉': [0, 'ID56-ID66'],
#  '叉烧饭-小炒': [0, 'ID56-ID50'],
#  '叉烧饭-野菠萝公园': [0, 'ID56-ID38'],
#  '叉烧饭-和牛盖饭': [0, 'ID56-ID77'],
#  '叉烧饭-饮料': [0, 'ID56-ID16'],
#  '叉烧饭-温德姆酒店': [0, 'ID56-ID39'],
#  '叉烧饭-泡芙': [0, 'ID56-ID62'],
#  '叉烧饭-牛排': [0, 'ID56-ID42'],
#  '叉烧饭-牛肚': [0, 'ID56-ID74'],
#  '叉烧饭-晏镜岭': [0, 'ID56-ID17'],
#  '叉烧饭-刺身': [0, 'ID56-ID70'],
#  '叉烧饭-自助菜': [0, 'ID56-ID85'],
#  '叉烧饭-游乐场': [0, 'ID56-ID23'],
#  '叉烧饭-中心广场': [0, 'ID56-ID3'],
#  '叉烧饭-摩天轮': [0, 'ID56-ID24'],
#  '叉烧饭-高钙大骨鸳鸯锅': [0, 'ID56-ID79'],
#  '叉烧饭-天马山': [0, 'ID56-ID19'],
#  '叉烧饭-赤坎老街': [0, 'ID56-ID48'],
#  '叉烧饭-玉湖': [0, 'ID56-ID37'],
#  '叉烧饭-菠萝皮': [0, 'ID56-ID87'],
#  '叉烧饭-热狗': [0, 'ID56-ID46'],
#  '叉烧饭-红树林': [0, 'ID56-ID10'],
#  '叉烧饭-菠萝包': [0, 'ID56-ID86'],
#  '叉烧饭-米饭': [0, 'ID56-ID61'],
#  '叉烧饭-无花果': [0, 'ID56-ID82'],
#  '叉烧饭-关东煮': [0, 'ID56-ID90'],
#  '叉烧饭-荔枝': [0, 'ID56-ID13'],
#  '叉烧饭-架海灯塔': [0, 'ID56-ID18'],
#  '叉烧饭-望海楼': [0, 'ID56-ID41'],
#  '叉烧饭-无花果萨拉米披萨': [0, 'ID56-ID81'],
#  '叉烧饭-早茶': [0, 'ID56-ID7'],
#  '叉烧饭-红树林栈道': [0, 'ID56-ID14'],
#  '叉烧饭-榴莲蛋糕': [0, 'ID56-ID52'],
#  '叉烧饭-炒乌冬': [0, 'ID56-ID68'],
#  '叉烧饭-酱汁': [0, 'ID56-ID76'],
#  '叉烧饭-奶油': [0, 'ID56-ID53'],
#  '叉烧饭-博物馆': [0, 'ID56-ID20'],
#  '叉烧饭-海鲜': [0, 'ID56-ID4'],
#  '叉烧饭-海陵岛': [0, 'ID56-ID22'],
#  '叉烧饭-高州仙人洞景区': [0, 'ID56-ID47'],
#  '叉烧饭-湛江大桥': [0, 'ID56-ID44'],
#  '叉烧饭-寿司': [0, 'ID56-ID55'],
#  '叉烧饭-新湖公园': [0, 'ID56-ID43'],
#  '叉烧饭-海滩': [0, 'ID56-ID1'],
#  '叉烧饭-玻璃桥': [0, 'ID56-ID21'],
#  '叉烧饭-第一滩': [0, 'ID56-ID2'],
#  '叉烧饭-蜂蜜芥末': [0, 'ID56-ID60'],
#  '叉烧饭-生蚝': [0, 'ID56-ID35'],
#  '叉烧饭-十里军港': [0, 'ID56-ID30'],
#  '叉烧饭-凤梨': [0, 'ID56-ID69'],
#  '叉烧饭-炒牛河': [0, 'ID56-ID73'],
#  '叉烧饭-露天矿生态公园': [0, 'ID56-ID28'],
#  '叉烧饭-薯条': [0, 'ID56-ID64'],
#  '叉烧饭-雷州古城': [0, 'ID56-ID34'],
#  '叉烧饭-粗薯': [0, 'ID56-ID83'],
#  '叉烧饭-露天矿': [0, 'ID56-ID29'],
#  '脆皮热狗卷-榴莲千层': [0, 'ID72-ID54'],
#  '脆皮热狗卷-御水古温泉': [0, 'ID72-ID33'],
#  '脆皮热狗卷-大角湾': [0, 'ID72-ID27'],
#  '脆皮热狗卷-雅米乐园': [0, 'ID72-ID51'],
#  '脆皮热狗卷-甜点': [0, 'ID72-ID12'],
#  '脆皮热狗卷-蛋挞': [0, 'ID72-ID67'],
#  '脆皮热狗卷-文化广场': [0, 'ID72-ID6'],
#  '脆皮热狗卷-小东江': [0, 'ID72-ID9'],
#  '脆皮热狗卷-拉面': [0, 'ID72-ID65'],
#  '脆皮热狗卷-东南码头': [0, 'ID72-ID40'],
#  '脆皮热狗卷-骑楼': [0, 'ID72-ID31'],
#  '脆皮热狗卷-凉拌菜': [0, 'ID72-ID89'],
#  '脆皮热狗卷-甜品': [0, 'ID72-ID49'],
#  '脆皮热狗卷-UNPOCO柏蔻': [0, 'ID72-ID80'],
#  '脆皮热狗卷-沙滩': [0, 'ID72-ID5'],
#  '脆皮热狗卷-烧鸭饭': [0, 'ID72-ID57'],
#  '脆皮热狗卷-海滨公园': [0, 'ID72-ID26'],
#  '脆皮热狗卷-煲仔饭': [0, 'ID72-ID88'],
#  '脆皮热狗卷-北洛湾': [0, 'ID72-ID25'],
#  '脆皮热狗卷-面包': [0, 'ID72-ID11'],
#  '脆皮热狗卷-水东湾': [0, 'ID72-ID45'],
#  '脆皮热狗卷-炸鸡': [0, 'ID72-ID59'],
#  '脆皮热狗卷-火腿': [0, 'ID72-ID71'],
#  '脆皮热狗卷-肉松': [8.32, 'ID72-ID63'],
#  '脆皮热狗卷-东湖': [0, 'ID72-ID15'],
#  '脆皮热狗卷-I': [0, 'ID72-ID8'],
#  '脆皮热狗卷-黄油': [0, 'ID72-ID75'],
#  '脆皮热狗卷-叉烧饭': [0, 'ID72-ID56'],
#  '脆皮热狗卷-三元塔': [0, 'ID72-ID32'],
#  '脆皮热狗卷-湖光岩': [0, 'ID72-ID36'],
#  '脆皮热狗卷-蔬菜': [0, 'ID72-ID58'],
#  '脆皮热狗卷-日式蟹肉卷': [0, 'ID72-ID78'],
#  '脆皮热狗卷-油条碎': [12.22, 'ID72-ID84'],
#  '脆皮热狗卷-牛肉': [0, 'ID72-ID66'],
#  '脆皮热狗卷-小炒': [0, 'ID72-ID50'],
#  '脆皮热狗卷-野菠萝公园': [0, 'ID72-ID38'],
#  '脆皮热狗卷-和牛盖饭': [0, 'ID72-ID77'],
#  '脆皮热狗卷-饮料': [0, 'ID72-ID16'],
#  '脆皮热狗卷-温德姆酒店': [0, 'ID72-ID39'],
#  '脆皮热狗卷-泡芙': [0, 'ID72-ID62'],
#  '脆皮热狗卷-牛排': [0, 'ID72-ID42'],
#  '脆皮热狗卷-牛肚': [0, 'ID72-ID74'],
#  '脆皮热狗卷-晏镜岭': [0, 'ID72-ID17'],
#  '脆皮热狗卷-刺身': [0, 'ID72-ID70'],
#  '脆皮热狗卷-自助菜': [0, 'ID72-ID85'],
#  '脆皮热狗卷-游乐场': [0, 'ID72-ID23'],
#  '脆皮热狗卷-中心广场': [0, 'ID72-ID3'],
#  '脆皮热狗卷-摩天轮': [0, 'ID72-ID24'],
#  '脆皮热狗卷-高钙大骨鸳鸯锅': [0, 'ID72-ID79'],
#  '脆皮热狗卷-天马山': [0, 'ID72-ID19'],
#  '脆皮热狗卷-赤坎老街': [0, 'ID72-ID48'],
#  '脆皮热狗卷-玉湖': [0, 'ID72-ID37'],
#  '脆皮热狗卷-菠萝皮': [0, 'ID72-ID87'],
#  '脆皮热狗卷-热狗': [10.42, 'ID72-ID46'],
#  '脆皮热狗卷-红树林': [0, 'ID72-ID10'],
#  '脆皮热狗卷-菠萝包': [0, 'ID72-ID86'],
#  '脆皮热狗卷-米饭': [6.22, 'ID72-ID61'],
#  '脆皮热狗卷-无花果': [0, 'ID72-ID82'],
#  '脆皮热狗卷-关东煮': [0, 'ID72-ID90'],
#  '脆皮热狗卷-荔枝': [0, 'ID72-ID13'],
#  '脆皮热狗卷-架海灯塔': [0, 'ID72-ID18'],
#  '脆皮热狗卷-望海楼': [0, 'ID72-ID41'],
#  '脆皮热狗卷-无花果萨拉米披萨': [0, 'ID72-ID81'],
#  '脆皮热狗卷-早茶': [0, 'ID72-ID7'],
#  '脆皮热狗卷-红树林栈道': [0, 'ID72-ID14'],
#  '脆皮热狗卷-榴莲蛋糕': [0, 'ID72-ID52'],
#  '脆皮热狗卷-炒乌冬': [0, 'ID72-ID68'],
#  '脆皮热狗卷-酱汁': [0, 'ID72-ID76'],
#  '脆皮热狗卷-奶油': [0, 'ID72-ID53'],
#  '脆皮热狗卷-博物馆': [0, 'ID72-ID20'],
#  '脆皮热狗卷-海鲜': [0, 'ID72-ID4'],
#  '脆皮热狗卷-海陵岛': [0, 'ID72-ID22'],
#  '脆皮热狗卷-高州仙人洞景区': [0, 'ID72-ID47'],
#  '脆皮热狗卷-湛江大桥': [0, 'ID72-ID44'],
#  '脆皮热狗卷-寿司': [0, 'ID72-ID55'],
#  '脆皮热狗卷-新湖公园': [0, 'ID72-ID43'],
#  '脆皮热狗卷-海滩': [0, 'ID72-ID1'],
#  '脆皮热狗卷-玻璃桥': [0, 'ID72-ID21'],
#  '脆皮热狗卷-第一滩': [0, 'ID72-ID2'],
#  '脆皮热狗卷-蜂蜜芥末': [0, 'ID72-ID60'],
#  '脆皮热狗卷-生蚝': [0, 'ID72-ID35'],
#  '脆皮热狗卷-十里军港': [0, 'ID72-ID30'],
#  '脆皮热狗卷-凤梨': [0, 'ID72-ID69'],
#  '脆皮热狗卷-炒牛河': [0, 'ID72-ID73'],
#  '脆皮热狗卷-露天矿生态公园': [0, 'ID72-ID28'],
#  '脆皮热狗卷-薯条': [0, 'ID72-ID64'],
#  '脆皮热狗卷-雷州古城': [0, 'ID72-ID34'],
#  '脆皮热狗卷-粗薯': [0, 'ID72-ID83'],
#  '脆皮热狗卷-露天矿': [0, 'ID72-ID29'],
#  '脆皮热狗卷-脆皮热狗卷': [12.22, 'ID72-ID72'],
#  '榴莲千层-御水古温泉': [0, 'ID54-ID33'],
#  '榴莲千层-大角湾': [0, 'ID54-ID27'],
#  '榴莲千层-雅米乐园': [0, 'ID54-ID51'],
#  '榴莲千层-甜点': [0, 'ID54-ID12'],
#  '榴莲千层-蛋挞': [0, 'ID54-ID67'],
#  '榴莲千层-文化广场': [0, 'ID54-ID6'],
#  '榴莲千层-小东江': [0, 'ID54-ID9'],
#  '榴莲千层-拉面': [0, 'ID54-ID65'],
#  '榴莲千层-东南码头': [0, 'ID54-ID40'],
#  '榴莲千层-骑楼': [0, 'ID54-ID31'],
#  '榴莲千层-凉拌菜': [0, 'ID54-ID89'],
#  '榴莲千层-甜品': [2.27, 'ID54-ID49'],
#  '榴莲千层-UNPOCO柏蔻': [0, 'ID54-ID80'],
#  '榴莲千层-沙滩': [0, 'ID54-ID5'],
#  '榴莲千层-烧鸭饭': [0, 'ID54-ID57'],
#  '榴莲千层-海滨公园': [0, 'ID54-ID26'],
#  '榴莲千层-煲仔饭': [0, 'ID54-ID88'],
#  '榴莲千层-北洛湾': [0, 'ID54-ID25'],
#  '榴莲千层-面包': [0, 'ID54-ID11'],
#  '榴莲千层-榴莲千层': [6.48, 'ID54-ID54'],
#  '榴莲千层-水东湾': [0, 'ID54-ID45'],
#  '榴莲千层-炸鸡': [0, 'ID54-ID59'],
#  '榴莲千层-火腿': [0, 'ID54-ID71'],
#  '榴莲千层-肉松': [0, 'ID54-ID63'],
#  '榴莲千层-东湖': [0, 'ID54-ID15'],
#  '榴莲千层-I': [0, 'ID54-ID8'],
#  '榴莲千层-黄油': [0, 'ID54-ID75'],
#  '榴莲千层-叉烧饭': [0, 'ID54-ID56'],
#  '榴莲千层-三元塔': [0, 'ID54-ID32'],
#  '榴莲千层-湖光岩': [0, 'ID54-ID36'],
#  '榴莲千层-蔬菜': [0, 'ID54-ID58'],
#  '榴莲千层-日式蟹肉卷': [0, 'ID54-ID78'],
#  '榴莲千层-油条碎': [0, 'ID54-ID84'],
#  '榴莲千层-牛肉': [0, 'ID54-ID66'],
#  '榴莲千层-小炒': [0, 'ID54-ID50'],
#  '榴莲千层-野菠萝公园': [0, 'ID54-ID38'],
#  '榴莲千层-和牛盖饭': [0, 'ID54-ID77'],
#  '榴莲千层-饮料': [0.84, 'ID54-ID16'],
#  '榴莲千层-温德姆酒店': [0, 'ID54-ID39'],
#  '榴莲千层-泡芙': [2.74, 'ID54-ID62'],
#  '榴莲千层-牛排': [0, 'ID54-ID42'],
#  '榴莲千层-牛肚': [0, 'ID54-ID74'],
#  '榴莲千层-晏镜岭': [0, 'ID54-ID17'],
#  '榴莲千层-刺身': [0, 'ID54-ID70'],
#  '榴莲千层-自助菜': [0, 'ID54-ID85'],
#  '榴莲千层-游乐场': [0, 'ID54-ID23'],
#  '榴莲千层-中心广场': [0, 'ID54-ID3'],
#  '榴莲千层-摩天轮': [0, 'ID54-ID24'],
#  '榴莲千层-高钙大骨鸳鸯锅': [0, 'ID54-ID79'],
#  '榴莲千层-天马山': [0, 'ID54-ID19'],
#  '榴莲千层-赤坎老街': [0, 'ID54-ID48'],
#  '榴莲千层-玉湖': [0, 'ID54-ID37'],
#  '榴莲千层-菠萝皮': [0, 'ID54-ID87'],
#  '榴莲千层-热狗': [0, 'ID54-ID46'],
#  '榴莲千层-红树林': [0, 'ID54-ID10'],
#  '榴莲千层-菠萝包': [0, 'ID54-ID86'],
#  '榴莲千层-米饭': [0, 'ID54-ID61'],
#  '榴莲千层-无花果': [0, 'ID54-ID82'],
#  '榴莲千层-关东煮': [0, 'ID54-ID90'],
#  '榴莲千层-荔枝': [0, 'ID54-ID13'],
#  '榴莲千层-架海灯塔': [0, 'ID54-ID18'],
#  '榴莲千层-望海楼': [0, 'ID54-ID41'],
#  '榴莲千层-无花果萨拉米披萨': [0, 'ID54-ID81'],
#  '榴莲千层-早茶': [0, 'ID54-ID7'],
#  '榴莲千层-红树林栈道': [0, 'ID54-ID14'],
#  '榴莲千层-榴莲蛋糕': [4.4, 'ID54-ID52'],
#  '榴莲千层-炒乌冬': [0, 'ID54-ID68'],
#  '榴莲千层-酱汁': [0, 'ID54-ID76'],
#  '榴莲千层-奶油': [1.6, 'ID54-ID53'],
#  '榴莲千层-博物馆': [0, 'ID54-ID20'],
#  '榴莲千层-海鲜': [0, 'ID54-ID4'],
#  '榴莲千层-海陵岛': [0, 'ID54-ID22'],
#  '榴莲千层-高州仙人洞景区': [0, 'ID54-ID47'],
#  '榴莲千层-湛江大桥': [0, 'ID54-ID44'],
#  '榴莲千层-寿司': [0, 'ID54-ID55'],
#  '榴莲千层-新湖公园': [0, 'ID54-ID43'],
#  '榴莲千层-海滩': [0, 'ID54-ID1'],
#  '榴莲千层-玻璃桥': [0, 'ID54-ID21'],
#  '榴莲千层-第一滩': [0, 'ID54-ID2'],
#  '榴莲千层-蜂蜜芥末': [0, 'ID54-ID60'],
#  '榴莲千层-生蚝': [0, 'ID54-ID35'],
#  '榴莲千层-十里军港': [0, 'ID54-ID30'],
#  '榴莲千层-凤梨': [0, 'ID54-ID69'],
#  '榴莲千层-炒牛河': [0, 'ID54-ID73'],
#  '榴莲千层-露天矿生态公园': [0, 'ID54-ID28'],
#  '榴莲千层-薯条': [0, 'ID54-ID64'],
#  '榴莲千层-雷州古城': [0, 'ID54-ID34'],
#  '榴莲千层-粗薯': [0, 'ID54-ID83'],
#  '榴莲千层-露天矿': [0, 'ID54-ID29'],
#  '榴莲千层-脆皮热狗卷': [0, 'ID54-ID72'],
#  '御水古温泉-大角湾': [0, 'ID33-ID27'],
#  '御水古温泉-雅米乐园': [0, 'ID33-ID51'],
#  '御水古温泉-甜点': [0, 'ID33-ID12'],
#  '御水古温泉-蛋挞': [0, 'ID33-ID67'],
#  '御水古温泉-文化广场': [0, 'ID33-ID6'],
#  '御水古温泉-小东江': [4.01, 'ID33-ID9'],
#  '御水古温泉-拉面': [0, 'ID33-ID65'],
#  '御水古温泉-东南码头': [0, 'ID33-ID40'],
#  '御水古温泉-骑楼': [7.05, 'ID33-ID31'],
#  '御水古温泉-凉拌菜': [0, 'ID33-ID89'],
#  '御水古温泉-甜品': [3.85, 'ID33-ID49'],
#  '御水古温泉-UNPOCO柏蔻': [0, 'ID33-ID80'],
#  '御水古温泉-沙滩': [4.65, 'ID33-ID5'],
#  '御水古温泉-烧鸭饭': [0, 'ID33-ID57'],
#  '御水古温泉-海滨公园': [0, 'ID33-ID26'],
#  '御水古温泉-煲仔饭': [0, 'ID33-ID88'],
#  '御水古温泉-北洛湾': [0, 'ID33-ID25'],
#  '御水古温泉-面包': [4.73, 'ID33-ID11'],
#  '御水古温泉-榴莲千层': [0, 'ID33-ID54'],
#  '御水古温泉-水东湾': [0, 'ID33-ID45'],
#  '御水古温泉-炸鸡': [0, 'ID33-ID59'],
#  '御水古温泉-火腿': [0, 'ID33-ID71'],
#  '御水古温泉-肉松': [0, 'ID33-ID63'],
#  '御水古温泉-东湖': [0, 'ID33-ID15'],
#  '御水古温泉-I': [5.35, 'ID33-ID8'],
#  '御水古温泉-黄油': [0, 'ID33-ID75'],
#  '御水古温泉-叉烧饭': [0, 'ID33-ID56'],
#  '御水古温泉-三元塔': [0, 'ID33-ID32'],
#  '御水古温泉-湖光岩': [5.05, 'ID33-ID36'],
#  '御水古温泉-蔬菜': [5.05, 'ID33-ID58'],
#  '御水古温泉-日式蟹肉卷': [0, 'ID33-ID78'],
#  '御水古温泉-油条碎': [0, 'ID33-ID84'],
#  '御水古温泉-牛肉': [0, 'ID33-ID66'],
#  '御水古温泉-小炒': [0, 'ID33-ID50'],
#  '御水古温泉-野菠萝公园': [0, 'ID33-ID38'],
#  '御水古温泉-和牛盖饭': [0, 'ID33-ID77'],
#  '御水古温泉-饮料': [0, 'ID33-ID16'],
#  '御水古温泉-温德姆酒店': [6.85, 'ID33-ID39'],
#  '御水古温泉-泡芙': [0, 'ID33-ID62'],
#  '御水古温泉-牛排': [0, 'ID33-ID42'],
#  '御水古温泉-牛肚': [0, 'ID33-ID74'],
#  '御水古温泉-晏镜岭': [5.89, 'ID33-ID17'],
#  '御水古温泉-刺身': [6.05, 'ID33-ID70'],
#  '御水古温泉-御水古温泉': [9.05, 'ID33-ID33'],
#  '御水古温泉-自助菜': [0, 'ID33-ID85'],
#  '御水古温泉-游乐场': [0, 'ID33-ID23'],
#  '御水古温泉-中心广场': [0, 'ID33-ID3'],
#  '御水古温泉-摩天轮': [0, 'ID33-ID24'],
#  '御水古温泉-高钙大骨鸳鸯锅': [0, 'ID33-ID79'],
#  '御水古温泉-天马山': [0, 'ID33-ID19'],
#  '御水古温泉-赤坎老街': [0, 'ID33-ID48'],
#  '御水古温泉-玉湖': [0, 'ID33-ID37'],
#  '御水古温泉-菠萝皮': [0, 'ID33-ID87'],
#  '御水古温泉-热狗': [0, 'ID33-ID46'],
#  '御水古温泉-红树林': [5.15, 'ID33-ID10'],
#  '御水古温泉-菠萝包': [0, 'ID33-ID86'],
#  '御水古温泉-米饭': [0, 'ID33-ID61'],
#  '御水古温泉-无花果': [0, 'ID33-ID82'],
#  '御水古温泉-关东煮': [0, 'ID33-ID90'],
#  '御水古温泉-荔枝': [4.1, 'ID33-ID13'],
#  '御水古温泉-架海灯塔': [0, 'ID33-ID18'],
#  '御水古温泉-望海楼': [0, 'ID33-ID41'],
#  '御水古温泉-无花果萨拉米披萨': [0, 'ID33-ID81'],
#  '御水古温泉-早茶': [0, 'ID33-ID7'],
#  '御水古温泉-红树林栈道': [0, 'ID33-ID14'],
#  '御水古温泉-榴莲蛋糕': [0, 'ID33-ID52'],
#  '御水古温泉-炒乌冬': [0, 'ID33-ID68'],
#  '御水古温泉-酱汁': [7.25, 'ID33-ID76'],
#  '御水古温泉-奶油': [0, 'ID33-ID53'],
#  '御水古温泉-博物馆': [5.03, 'ID33-ID20'],
#  '御水古温泉-海鲜': [4.54, 'ID33-ID4'],
#  '御水古温泉-海陵岛': [4.63, 'ID33-ID22'],
#  '御水古温泉-高州仙人洞景区': [0, 'ID33-ID47'],
#  '御水古温泉-湛江大桥': [0, 'ID33-ID44'],
#  '御水古温泉-寿司': [0, 'ID33-ID55'],
#  '御水古温泉-新湖公园': [0, 'ID33-ID43'],
#  '御水古温泉-海滩': [4.98, 'ID33-ID1'],
#  '御水古温泉-玻璃桥': [0, 'ID33-ID21'],
#  '御水古温泉-第一滩': [3.81, 'ID33-ID2'],
#  '御水古温泉-蜂蜜芥末': [0, 'ID33-ID60'],
#  '御水古温泉-生蚝': [0, 'ID33-ID35'],
#  '御水古温泉-十里军港': [0, 'ID33-ID30'],
#  '御水古温泉-凤梨': [0, 'ID33-ID69'],
#  '御水古温泉-炒牛河': [0, 'ID33-ID73'],
#  '御水古温泉-露天矿生态公园': [5.73, 'ID33-ID28'],
#  '御水古温泉-薯条': [0, 'ID33-ID64'],
#  '御水古温泉-雷州古城': [0, 'ID33-ID34'],
#  '御水古温泉-粗薯': [0, 'ID33-ID83'],
#  '御水古温泉-露天矿': [4.47, 'ID33-ID29'],
#  '御水古温泉-脆皮热狗卷': [0, 'ID33-ID72'],
#  '大角湾-雅米乐园': [0, 'ID27-ID51'],
#  '大角湾-甜点': [0, 'ID27-ID12'],
#  '大角湾-蛋挞': [0, 'ID27-ID67'],
#  '大角湾-文化广场': [0, 'ID27-ID6'],
#  '大角湾-小东江': [0, 'ID27-ID9'],
#  '大角湾-拉面': [0, 'ID27-ID65'],
#  '大角湾-东南码头': [0, 'ID27-ID40'],
#  '大角湾-骑楼': [0, 'ID27-ID31'],
#  '大角湾-凉拌菜': [0, 'ID27-ID89'],
#  '大角湾-甜品': [0, 'ID27-ID49'],
#  '大角湾-UNPOCO柏蔻': [0, 'ID27-ID80'],
#  '大角湾-沙滩': [5.12, 'ID27-ID5'],
#  '大角湾-烧鸭饭': [0, 'ID27-ID57'],
#  '大角湾-海滨公园': [0, 'ID27-ID26'],
#  '大角湾-煲仔饭': [0, 'ID27-ID88'],
#  '大角湾-北洛湾': [8.94, 'ID27-ID25'],
#  '大角湾-面包': [0, 'ID27-ID11'],
#  '大角湾-榴莲千层': [0, 'ID27-ID54'],
#  '大角湾-水东湾': [0, 'ID27-ID45'],
#  '大角湾-炸鸡': [0, 'ID27-ID59'],
#  '大角湾-火腿': [0, 'ID27-ID71'],
#  '大角湾-肉松': [0, 'ID27-ID63'],
#  '大角湾-东湖': [0, 'ID27-ID15'],
#  '大角湾-I': [0, 'ID27-ID8'],
#  '大角湾-黄油': [0, 'ID27-ID75'],
#  '大角湾-叉烧饭': [0, 'ID27-ID56'],
#  '大角湾-三元塔': [0, 'ID27-ID32'],
#  '大角湾-湖光岩': [0, 'ID27-ID36'],
#  '大角湾-蔬菜': [0, 'ID27-ID58'],
#  '大角湾-日式蟹肉卷': [0, 'ID27-ID78'],
#  '大角湾-油条碎': [0, 'ID27-ID84'],
#  '大角湾-牛肉': [2.97, 'ID27-ID66'],
#  '大角湾-小炒': [0, 'ID27-ID50'],
#  '大角湾-野菠萝公园': [0, 'ID27-ID38'],
#  '大角湾-和牛盖饭': [0, 'ID27-ID77'],
#  '大角湾-饮料': [2.88, 'ID27-ID16'],
#  '大角湾-温德姆酒店': [0, 'ID27-ID39'],
#  '大角湾-泡芙': [0, 'ID27-ID62'],
#  '大角湾-牛排': [0, 'ID27-ID42'],
#  '大角湾-牛肚': [0, 'ID27-ID74'],
#  '大角湾-晏镜岭': [0, 'ID27-ID17'],
#  '大角湾-刺身': [0, 'ID27-ID70'],
#  '大角湾-御水古温泉': [0, 'ID27-ID33'],
#  '大角湾-自助菜': [0, 'ID27-ID85'],
#  '大角湾-游乐场': [0, 'ID27-ID23'],
#  '大角湾-中心广场': [0, 'ID27-ID3'],
#  '大角湾-摩天轮': [0, 'ID27-ID24'],
#  '大角湾-高钙大骨鸳鸯锅': [0, 'ID27-ID79'],
#  '大角湾-天马山': [0, 'ID27-ID19'],
#  '大角湾-赤坎老街': [0, 'ID27-ID48'],
#  '大角湾-玉湖': [4.88, 'ID27-ID37'],
#  '大角湾-菠萝皮': [0, 'ID27-ID87'],
#  '大角湾-热狗': [0, 'ID27-ID46'],
#  '大角湾-红树林': [5.62, 'ID27-ID10'],
#  '大角湾-菠萝包': [0, 'ID27-ID86'],
#  '大角湾-米饭': [0, 'ID27-ID61'],
#  '大角湾-无花果': [0, 'ID27-ID82'],
#  '大角湾-关东煮': [0, 'ID27-ID90'],
#  '大角湾-荔枝': [0, 'ID27-ID13'],
#  '大角湾-架海灯塔': [0, 'ID27-ID18'],
#  '大角湾-望海楼': [0, 'ID27-ID41'],
#  '大角湾-无花果萨拉米披萨': [0, 'ID27-ID81'],
#  '大角湾-早茶': [4.94, 'ID27-ID7'],
#  '大角湾-红树林栈道': [0, 'ID27-ID14'],
#  '大角湾-榴莲蛋糕': [0, 'ID27-ID52'],
#  '大角湾-炒乌冬': [0, 'ID27-ID68'],
#  '大角湾-酱汁': [0, 'ID27-ID76'],
#  '大角湾-奶油': [0, 'ID27-ID53'],
#  '大角湾-大角湾': [9.52, 'ID27-ID27'],
#  '大角湾-博物馆': [3.91, 'ID27-ID20'],
#  '大角湾-海鲜': [4.2, 'ID27-ID4'],
#  '大角湾-海陵岛': [7.1, 'ID27-ID22'],
#  '大角湾-高州仙人洞景区': [0, 'ID27-ID47'],
#  '大角湾-湛江大桥': [0, 'ID27-ID44'],
#  '大角湾-寿司': [0, 'ID27-ID55'],
#  '大角湾-新湖公园': [0, 'ID27-ID43'],
#  '大角湾-海滩': [5.45, 'ID27-ID1'],
#  '大角湾-玻璃桥': [0, 'ID27-ID21'],
#  '大角湾-第一滩': [4.28, 'ID27-ID2'],
#  '大角湾-蜂蜜芥末': [0, 'ID27-ID60'],
#  '大角湾-生蚝': [0, 'ID27-ID35'],
#  '大角湾-十里军港': [0, 'ID27-ID30'],
#  '大角湾-凤梨': [0, 'ID27-ID69'],
#  '大角湾-炒牛河': [0, 'ID27-ID73'],
#  '大角湾-露天矿生态公园': [0, 'ID27-ID28'],
#  '大角湾-薯条': [0, 'ID27-ID64'],
#  '大角湾-雷州古城': [0, 'ID27-ID34'],
#  '大角湾-粗薯': [0, 'ID27-ID83'],
#  '大角湾-露天矿': [0, 'ID27-ID29'],
#  '大角湾-脆皮热狗卷': [0, 'ID27-ID72'],
#  '雅米乐园-甜点': [0, 'ID51-ID12'],
#  '雅米乐园-蛋挞': [0, 'ID51-ID67'],
#  '雅米乐园-文化广场': [0, 'ID51-ID6'],
#  '雅米乐园-小东江': [0, 'ID51-ID9'],
#  '雅米乐园-拉面': [0, 'ID51-ID65'],
#  '雅米乐园-东南码头': [0, 'ID51-ID40'],
#  '雅米乐园-骑楼': [0, 'ID51-ID31'],
#  '雅米乐园-凉拌菜': [0, 'ID51-ID89'],
#  '雅米乐园-甜品': [0, 'ID51-ID49'],
#  '雅米乐园-UNPOCO柏蔻': [0, 'ID51-ID80'],
#  '雅米乐园-沙滩': [0, 'ID51-ID5'],
#  '雅米乐园-烧鸭饭': [0, 'ID51-ID57'],
#  '雅米乐园-海滨公园': [0, 'ID51-ID26'],
#  '雅米乐园-煲仔饭': [0, 'ID51-ID88'],
#  '雅米乐园-北洛湾': [0, 'ID51-ID25'],
#  '雅米乐园-面包': [0, 'ID51-ID11'],
#  '雅米乐园-榴莲千层': [0, 'ID51-ID54'],
#  '雅米乐园-水东湾': [0, 'ID51-ID45'],
#  '雅米乐园-炸鸡': [0, 'ID51-ID59'],
#  '雅米乐园-火腿': [0, 'ID51-ID71'],
#  '雅米乐园-肉松': [0, 'ID51-ID63'],
#  '雅米乐园-东湖': [0, 'ID51-ID15'],
#  '雅米乐园-I': [0, 'ID51-ID8'],
#  '雅米乐园-黄油': [0, 'ID51-ID75'],
#  '雅米乐园-叉烧饭': [0, 'ID51-ID56'],
#  '雅米乐园-三元塔': [0, 'ID51-ID32'],
#  '雅米乐园-湖光岩': [0, 'ID51-ID36'],
#  '雅米乐园-蔬菜': [0, 'ID51-ID58'],
#  '雅米乐园-日式蟹肉卷': [0, 'ID51-ID78'],
#  '雅米乐园-油条碎': [0, 'ID51-ID84'],
#  '雅米乐园-牛肉': [0, 'ID51-ID66'],
#  '雅米乐园-小炒': [0, 'ID51-ID50'],
#  '雅米乐园-野菠萝公园': [0, 'ID51-ID38'],
#  '雅米乐园-和牛盖饭': [0, 'ID51-ID77'],
#  '雅米乐园-饮料': [0, 'ID51-ID16'],
#  '雅米乐园-温德姆酒店': [0, 'ID51-ID39'],
#  '雅米乐园-泡芙': [0, 'ID51-ID62'],
#  '雅米乐园-牛排': [0, 'ID51-ID42'],
#  '雅米乐园-牛肚': [0, 'ID51-ID74'],
#  '雅米乐园-晏镜岭': [0, 'ID51-ID17'],
#  '雅米乐园-刺身': [0, 'ID51-ID70'],
#  '雅米乐园-御水古温泉': [0, 'ID51-ID33'],
#  '雅米乐园-自助菜': [0, 'ID51-ID85'],
#  '雅米乐园-游乐场': [0, 'ID51-ID23'],
#  '雅米乐园-中心广场': [0, 'ID51-ID3'],
#  '雅米乐园-摩天轮': [0, 'ID51-ID24'],
#  '雅米乐园-高钙大骨鸳鸯锅': [0, 'ID51-ID79'],
#  '雅米乐园-天马山': [0, 'ID51-ID19'],
#  '雅米乐园-赤坎老街': [0, 'ID51-ID48'],
#  '雅米乐园-玉湖': [0, 'ID51-ID37'],
#  '雅米乐园-菠萝皮': [0, 'ID51-ID87'],
#  '雅米乐园-热狗': [0, 'ID51-ID46'],
#  '雅米乐园-红树林': [0, 'ID51-ID10'],
#  '雅米乐园-菠萝包': [0, 'ID51-ID86'],
#  '雅米乐园-米饭': [0, 'ID51-ID61'],
#  '雅米乐园-无花果': [0, 'ID51-ID82'],
#  '雅米乐园-关东煮': [0, 'ID51-ID90'],
#  '雅米乐园-荔枝': [0, 'ID51-ID13'],
#  '雅米乐园-架海灯塔': [0, 'ID51-ID18'],
#  '雅米乐园-望海楼': [0, 'ID51-ID41'],
#  '雅米乐园-无花果萨拉米披萨': [0, 'ID51-ID81'],
#  '雅米乐园-早茶': [0, 'ID51-ID7'],
#  '雅米乐园-红树林栈道': [0, 'ID51-ID14'],
#  '雅米乐园-榴莲蛋糕': [0, 'ID51-ID52'],
#  '雅米乐园-炒乌冬': [0, 'ID51-ID68'],
#  '雅米乐园-酱汁': [0, 'ID51-ID76'],
#  '雅米乐园-奶油': [0, 'ID51-ID53'],
#  '雅米乐园-大角湾': [0, 'ID51-ID27'],
#  '雅米乐园-博物馆': [0, 'ID51-ID20'],
#  '雅米乐园-海鲜': [0, 'ID51-ID4'],
#  '雅米乐园-海陵岛': [0, 'ID51-ID22'],
#  '雅米乐园-高州仙人洞景区': [0, 'ID51-ID47'],
#  '雅米乐园-湛江大桥': [0, 'ID51-ID44'],
#  '雅米乐园-寿司': [0, 'ID51-ID55'],
#  '雅米乐园-新湖公园': [0, 'ID51-ID43'],
#  '雅米乐园-海滩': [0, 'ID51-ID1'],
#  '雅米乐园-玻璃桥': [0, 'ID51-ID21'],
#  '雅米乐园-第一滩': [0, 'ID51-ID2'],
#  '雅米乐园-蜂蜜芥末': [0, 'ID51-ID60'],
#  '雅米乐园-生蚝': [0, 'ID51-ID35'],
#  '雅米乐园-十里军港': [0, 'ID51-ID30'],
#  '雅米乐园-凤梨': [0, 'ID51-ID69'],
#  '雅米乐园-炒牛河': [0, 'ID51-ID73'],
#  '雅米乐园-露天矿生态公园': [0, 'ID51-ID28'],
#  '雅米乐园-薯条': [0, 'ID51-ID64'],
#  '雅米乐园-雷州古城': [0, 'ID51-ID34'],
#  '雅米乐园-粗薯': [0, 'ID51-ID83'],
#  '雅米乐园-雅米乐园': [11.64, 'ID51-ID51'],
#  '雅米乐园-露天矿': [0, 'ID51-ID29'],
#  '雅米乐园-脆皮热狗卷': [0, 'ID51-ID72'],
#  '甜点-蛋挞': [0, 'ID12-ID67'],
#  '甜点-文化广场': [0, 'ID12-ID6'],
#  '甜点-小东江': [0, 'ID12-ID9'],
#  '甜点-拉面': [0, 'ID12-ID65'],
#  '甜点-东南码头': [0, 'ID12-ID40'],
#  '甜点-骑楼': [0, 'ID12-ID31'],
#  '甜点-凉拌菜': [0, 'ID12-ID89'],
#  '甜点-甜品': [5.56, 'ID12-ID49'],
#  '甜点-UNPOCO柏蔻': [0, 'ID12-ID80'],
#  '甜点-沙滩': [2.36, 'ID12-ID5'],
#  '甜点-烧鸭饭': [0, 'ID12-ID57'],
#  '甜点-海滨公园': [0, 'ID12-ID26'],
#  '甜点-煲仔饭': [0, 'ID12-ID88'],
#  '甜点-北洛湾': [0, 'ID12-ID25'],
#  '甜点-面包': [0, 'ID12-ID11'],
#  '甜点-榴莲千层': [0, 'ID12-ID54'],
#  '甜点-水东湾': [0, 'ID12-ID45'],
#  '甜点-炸鸡': [0, 'ID12-ID59'],
#  '甜点-火腿': [0, 'ID12-ID71'],
#  '甜点-肉松': [0, 'ID12-ID63'],
#  '甜点-东湖': [0, 'ID12-ID15'],
#  '甜点-I': [0, 'ID12-ID8'],
#  '甜点-黄油': [0, 'ID12-ID75'],
#  '甜点-叉烧饭': [0, 'ID12-ID56'],
#  '甜点-三元塔': [0, 'ID12-ID32'],
#  '甜点-湖光岩': [0, 'ID12-ID36'],
#  '甜点-蔬菜': [0, 'ID12-ID58'],
#  '甜点-日式蟹肉卷': [0, 'ID12-ID78'],
#  '甜点-油条碎': [0, 'ID12-ID84'],
#  '甜点-甜点': [9.77, 'ID12-ID12'],
#  '甜点-牛肉': [0, 'ID12-ID66'],
#  '甜点-小炒': [0, 'ID12-ID50'],
#  '甜点-野菠萝公园': [0, 'ID12-ID38'],
#  '甜点-和牛盖饭': [0, 'ID12-ID77'],
#  '甜点-饮料': [3.12, 'ID12-ID16'],
#  '甜点-温德姆酒店': [5.24, 'ID12-ID39'],
#  '甜点-泡芙': [3.7, 'ID12-ID62'],
#  '甜点-牛排': [3.73, 'ID12-ID42'],
#  '甜点-牛肚': [0, 'ID12-ID74'],
#  '甜点-晏镜岭': [0, 'ID12-ID17'],
#  '甜点-刺身': [0, 'ID12-ID70'],
#  '甜点-御水古温泉': [0, 'ID12-ID33'],
#  '甜点-自助菜': [0, 'ID12-ID85'],
#  '甜点-游乐场': [0, 'ID12-ID23'],
#  '甜点-中心广场': [0, 'ID12-ID3'],
#  '甜点-摩天轮': [0, 'ID12-ID24'],
#  '甜点-高钙大骨鸳鸯锅': [0, 'ID12-ID79'],
#  '甜点-天马山': [0, 'ID12-ID19'],
#  '甜点-赤坎老街': [0, 'ID12-ID48'],
#  '甜点-玉湖': [0, 'ID12-ID37'],
#  '甜点-菠萝皮': [0, 'ID12-ID87'],
#  '甜点-热狗': [0, 'ID12-ID46'],
#  '甜点-红树林': [0, 'ID12-ID10'],
#  '甜点-菠萝包': [0, 'ID12-ID86'],
#  '甜点-米饭': [0, 'ID12-ID61'],
#  '甜点-无花果': [0, 'ID12-ID82'],
#  '甜点-关东煮': [0, 'ID12-ID90'],
#  '甜点-荔枝': [0, 'ID12-ID13'],
#  '甜点-架海灯塔': [0, 'ID12-ID18'],
#  '甜点-望海楼': [0, 'ID12-ID41'],
#  '甜点-无花果萨拉米披萨': [0, 'ID12-ID81'],
#  '甜点-早茶': [0, 'ID12-ID7'],
#  '甜点-红树林栈道': [0, 'ID12-ID14'],
#  '甜点-榴莲蛋糕': [0, 'ID12-ID52'],
#  '甜点-炒乌冬': [0, 'ID12-ID68'],
#  '甜点-酱汁': [0, 'ID12-ID76'],
#  '甜点-奶油': [0, 'ID12-ID53'],
#  '甜点-大角湾': [0, 'ID12-ID27'],
#  '甜点-博物馆': [0, 'ID12-ID20'],
#  '甜点-海鲜': [4.03, 'ID12-ID4'],
#  '甜点-海陵岛': [4.34, 'ID12-ID22'],
#  '甜点-高州仙人洞景区': [0, 'ID12-ID47'],
#  '甜点-湛江大桥': [0, 'ID12-ID44'],
#  '甜点-寿司': [0, 'ID12-ID55'],
#  '甜点-新湖公园': [0, 'ID12-ID43'],
#  '甜点-海滩': [3.11, 'ID12-ID1'],
#  '甜点-玻璃桥': [0, 'ID12-ID21'],
#  '甜点-第一滩': [0, 'ID12-ID2'],
#  '甜点-蜂蜜芥末': [0, 'ID12-ID60'],
#  '甜点-生蚝': [4.52, 'ID12-ID35'],
#  '甜点-十里军港': [0, 'ID12-ID30'],
#  '甜点-凤梨': [0, 'ID12-ID69'],
#  '甜点-炒牛河': [0, 'ID12-ID73'],
#  '甜点-露天矿生态公园': [0, 'ID12-ID28'],
#  '甜点-薯条': [0, 'ID12-ID64'],
#  '甜点-雷州古城': [0, 'ID12-ID34'],
#  '甜点-粗薯': [0, 'ID12-ID83'],
#  '甜点-雅米乐园': [0, 'ID12-ID51'],
#  '甜点-露天矿': [0, 'ID12-ID29'],
#  '甜点-脆皮热狗卷': [0, 'ID12-ID72'],
#  '蛋挞-文化广场': [0, 'ID67-ID6'],
#  '蛋挞-小东江': [0, 'ID67-ID9'],
#  '蛋挞-拉面': [0, 'ID67-ID65'],
#  '蛋挞-东南码头': [0, 'ID67-ID40'],
#  '蛋挞-骑楼': [0, 'ID67-ID31'],
#  '蛋挞-凉拌菜': [6.95, 'ID67-ID89'],
#  '蛋挞-甜品': [4.06, 'ID67-ID49'],
#  '蛋挞-UNPOCO柏蔻': [0, 'ID67-ID80'],
#  '蛋挞-沙滩': [0, 'ID67-ID5'],
#  '蛋挞-烧鸭饭': [0, 'ID67-ID57'],
#  '蛋挞-海滨公园': [0, 'ID67-ID26'],
#  '蛋挞-煲仔饭': [0, 'ID67-ID88'],
#  '蛋挞-北洛湾': [0, 'ID67-ID25'],
#  '蛋挞-面包': [3.95, 'ID67-ID11'],
#  '蛋挞-榴莲千层': [0, 'ID67-ID54'],
#  '蛋挞-水东湾': [0, 'ID67-ID45'],
#  '蛋挞-炸鸡': [0, 'ID67-ID59'],
#  '蛋挞-火腿': [0, 'ID67-ID71'],
#  '蛋挞-肉松': [0, 'ID67-ID63'],
#  '蛋挞-东湖': [0, 'ID67-ID15'],
#  '蛋挞-I': [0, 'ID67-ID8'],
#  '蛋挞-黄油': [0, 'ID67-ID75'],
#  '蛋挞-叉烧饭': [0, 'ID67-ID56'],
#  '蛋挞-三元塔': [0, 'ID67-ID32'],
#  '蛋挞-湖光岩': [0, 'ID67-ID36'],
#  '蛋挞-蔬菜': [0, 'ID67-ID58'],
#  '蛋挞-日式蟹肉卷': [0, 'ID67-ID78'],
#  '蛋挞-油条碎': [0, 'ID67-ID84'],
#  '蛋挞-甜点': [0, 'ID67-ID12'],
#  '蛋挞-牛肉': [0, 'ID67-ID66'],
#  '蛋挞-小炒': [5.95, 'ID67-ID50'],
#  '蛋挞-野菠萝公园': [0, 'ID67-ID38'],
#  '蛋挞-和牛盖饭': [0, 'ID67-ID77'],
#  '蛋挞-饮料': [1.63, 'ID67-ID16'],
#  '蛋挞-温德姆酒店': [0, 'ID67-ID39'],
#  '蛋挞-泡芙': [6.11, 'ID67-ID62'],
#  '蛋挞-牛排': [0.65, 'ID67-ID42'],
#  '蛋挞-牛肚': [0, 'ID67-ID74'],
#  '蛋挞-晏镜岭': [0, 'ID67-ID17'],
#  '蛋挞-刺身': [0, 'ID67-ID70'],
#  '蛋挞-御水古温泉': [0, 'ID67-ID33'],
#  '蛋挞-自助菜': [0, 'ID67-ID85'],
#  '蛋挞-游乐场': [0, 'ID67-ID23'],
#  '蛋挞-中心广场': [0, 'ID67-ID3'],
#  '蛋挞-摩天轮': [0, 'ID67-ID24'],
#  '蛋挞-高钙大骨鸳鸯锅': [0, 'ID67-ID79'],
#  '蛋挞-天马山': [0, 'ID67-ID19'],
#  '蛋挞-赤坎老街': [0, 'ID67-ID48'],
#  '蛋挞-玉湖': [0, 'ID67-ID37'],
#  '蛋挞-菠萝皮': [0, 'ID67-ID87'],
#  '蛋挞-热狗': [0, 'ID67-ID46'],
#  '蛋挞-红树林': [0, 'ID67-ID10'],
#  '蛋挞-菠萝包': [0, 'ID67-ID86'],
#  '蛋挞-米饭': [0, 'ID67-ID61'],
#  '蛋挞-无花果': [0, 'ID67-ID82'],
#  '蛋挞-关东煮': [7.27, 'ID67-ID90'],
#  '蛋挞-荔枝': [3.32, 'ID67-ID13'],
#  '蛋挞-架海灯塔': [0, 'ID67-ID18'],
#  '蛋挞-望海楼': [0, 'ID67-ID41'],
#  '蛋挞-无花果萨拉米披萨': [0, 'ID67-ID81'],
#  '蛋挞-早茶': [3.69, 'ID67-ID7'],
#  '蛋挞-红树林栈道': [0, 'ID67-ID14'],
#  '蛋挞-榴莲蛋糕': [0, 'ID67-ID52'],
#  '蛋挞-炒乌冬': [0, 'ID67-ID68'],
#  '蛋挞-酱汁': [0, 'ID67-ID76'],
#  '蛋挞-奶油': [1.06, 'ID67-ID53'],
#  '蛋挞-大角湾': [0, 'ID67-ID27'],
#  '蛋挞-博物馆': [0, 'ID67-ID20'],
#  '蛋挞-海鲜': [0.95, 'ID67-ID4'],
#  '蛋挞-海陵岛': [0, 'ID67-ID22'],
#  '蛋挞-高州仙人洞景区': [0, 'ID67-ID47'],
#  '蛋挞-湛江大桥': [0, 'ID67-ID44'],
#  '蛋挞-寿司': [1.99, 'ID67-ID55'],
#  '蛋挞-新湖公园': [0, 'ID67-ID43'],
#  '蛋挞-海滩': [0, 'ID67-ID1'],
#  '蛋挞-玻璃桥': [0, 'ID67-ID21'],
#  '蛋挞-第一滩': [0, 'ID67-ID2'],
#  '蛋挞-蜂蜜芥末': [0, 'ID67-ID60'],
#  '蛋挞-生蚝': [3.02, 'ID67-ID35'],
#  '蛋挞-十里军港': [0, 'ID67-ID30'],
#  '蛋挞-凤梨': [0, 'ID67-ID69'],
#  '蛋挞-炒牛河': [0, 'ID67-ID73'],
#  '蛋挞-露天矿生态公园': [0, 'ID67-ID28'],
#  '蛋挞-薯条': [0, 'ID67-ID64'],
#  '蛋挞-蛋挞': [8.27, 'ID67-ID67'],
#  '蛋挞-雷州古城': [0, 'ID67-ID34'],
#  '蛋挞-粗薯': [0, 'ID67-ID83'],
#  '蛋挞-雅米乐园': [0, 'ID67-ID51'],
#  '蛋挞-露天矿': [0, 'ID67-ID29'],
#  '蛋挞-脆皮热狗卷': [0, 'ID67-ID72'],
#  '文化广场-小东江': [4.6, 'ID6-ID9'],
#  '文化广场-拉面': [0, 'ID6-ID65'],
#  '文化广场-东南码头': [0, 'ID6-ID40'],
#  '文化广场-骑楼': [0, 'ID6-ID31'],
#  '文化广场-凉拌菜': [0, 'ID6-ID89'],
#  '文化广场-甜品': [0, 'ID6-ID49'],
#  '文化广场-UNPOCO柏蔻': [0, 'ID6-ID80'],
#  '文化广场-沙滩': [0, 'ID6-ID5'],
#  '文化广场-烧鸭饭': [0, 'ID6-ID57'],
#  '文化广场-海滨公园': [0, 'ID6-ID26'],
#  '文化广场-煲仔饭': [0, 'ID6-ID88'],
#  '文化广场-北洛湾': [0, 'ID6-ID25'],
#  '文化广场-面包': [0, 'ID6-ID11'],
#  '文化广场-榴莲千层': [0, 'ID6-ID54'],
#  '文化广场-水东湾': [0, 'ID6-ID45'],
#  '文化广场-炸鸡': [0, 'ID6-ID59'],
#  '文化广场-火腿': [0, 'ID6-ID71'],
#  '文化广场-肉松': [0, 'ID6-ID63'],
#  '文化广场-东湖': [0, 'ID6-ID15'],
#  '文化广场-I': [0, 'ID6-ID8'],
#  '文化广场-黄油': [0, 'ID6-ID75'],
#  '文化广场-叉烧饭': [0, 'ID6-ID56'],
#  '文化广场-三元塔': [0, 'ID6-ID32'],
#  '文化广场-湖光岩': [0, 'ID6-ID36'],
#  '文化广场-蔬菜': [0, 'ID6-ID58'],
#  '文化广场-日式蟹肉卷': [0, 'ID6-ID78'],
#  '文化广场-油条碎': [0, 'ID6-ID84'],
#  '文化广场-甜点': [0, 'ID6-ID12'],
#  '文化广场-牛肉': [0, 'ID6-ID66'],
#  '文化广场-小炒': [0, 'ID6-ID50'],
#  '文化广场-野菠萝公园': [0, 'ID6-ID38'],
#  '文化广场-和牛盖饭': [0, 'ID6-ID77'],
#  '文化广场-饮料': [0, 'ID6-ID16'],
#  '文化广场-温德姆酒店': [0, 'ID6-ID39'],
#  '文化广场-泡芙': [0, 'ID6-ID62'],
#  '文化广场-牛排': [0, 'ID6-ID42'],
#  '文化广场-文化广场': [8.64, 'ID6-ID6'],
#  '文化广场-牛肚': [0, 'ID6-ID74'],
#  '文化广场-晏镜岭': [0, 'ID6-ID17'],
#  '文化广场-刺身': [0, 'ID6-ID70'],
#  '文化广场-御水古温泉': [0, 'ID6-ID33'],
#  '文化广场-自助菜': [0, 'ID6-ID85'],
#  '文化广场-游乐场': [0, 'ID6-ID23'],
#  '文化广场-中心广场': [0, 'ID6-ID3'],
#  '文化广场-摩天轮': [0, 'ID6-ID24'],
#  '文化广场-高钙大骨鸳鸯锅': [0, 'ID6-ID79'],
#  '文化广场-天马山': [0, 'ID6-ID19'],
#  '文化广场-赤坎老街': [0, 'ID6-ID48'],
#  '文化广场-玉湖': [0, 'ID6-ID37'],
#  '文化广场-菠萝皮': [0, 'ID6-ID87'],
#  '文化广场-热狗': [0, 'ID6-ID46'],
#  '文化广场-红树林': [0, 'ID6-ID10'],
#  '文化广场-菠萝包': [0, 'ID6-ID86'],
#  '文化广场-米饭': [0, 'ID6-ID61'],
#  '文化广场-无花果': [0, 'ID6-ID82'],
#  '文化广场-关东煮': [0, 'ID6-ID90'],
#  '文化广场-荔枝': [0, 'ID6-ID13'],
#  '文化广场-架海灯塔': [0, 'ID6-ID18'],
#  '文化广场-望海楼': [0, 'ID6-ID41'],
#  '文化广场-无花果萨拉米披萨': [0, 'ID6-ID81'],
#  '文化广场-早茶': [0, 'ID6-ID7'],
#  '文化广场-红树林栈道': [0, 'ID6-ID14'],
#  '文化广场-榴莲蛋糕': [0, 'ID6-ID52'],
#  '文化广场-炒乌冬': [0, 'ID6-ID68'],
#  '文化广场-酱汁': [0, 'ID6-ID76'],
#  '文化广场-奶油': [0, 'ID6-ID53'],
#  '文化广场-大角湾': [0, 'ID6-ID27'],
#  '文化广场-博物馆': [0, 'ID6-ID20'],
#  '文化广场-海鲜': [0, 'ID6-ID4'],
#  '文化广场-海陵岛': [0, 'ID6-ID22'],
#  '文化广场-高州仙人洞景区': [0, 'ID6-ID47'],
#  '文化广场-湛江大桥': [0, 'ID6-ID44'],
#  '文化广场-寿司': [0, 'ID6-ID55'],
#  '文化广场-新湖公园': [0, 'ID6-ID43'],
#  '文化广场-海滩': [0, 'ID6-ID1'],
#  '文化广场-玻璃桥': [0, 'ID6-ID21'],
#  '文化广场-第一滩': [0, 'ID6-ID2'],
#  '文化广场-蜂蜜芥末': [0, 'ID6-ID60'],
#  '文化广场-生蚝': [0, 'ID6-ID35'],
#  '文化广场-十里军港': [0, 'ID6-ID30'],
#  '文化广场-凤梨': [0, 'ID6-ID69'],
#  '文化广场-炒牛河': [0, 'ID6-ID73'],
#  '文化广场-露天矿生态公园': [0, 'ID6-ID28'],
#  '文化广场-薯条': [0, 'ID6-ID64'],
#  '文化广场-蛋挞': [0, 'ID6-ID67'],
#  '文化广场-雷州古城': [0, 'ID6-ID34'],
#  '文化广场-粗薯': [0, 'ID6-ID83'],
#  '文化广场-雅米乐园': [0, 'ID6-ID51'],
#  '文化广场-露天矿': [4.05, 'ID6-ID29'],
#  '文化广场-脆皮热狗卷': [0, 'ID6-ID72'],
#  '小东江-拉面': [0, 'ID9-ID65'],
#  '小东江-东南码头': [0, 'ID9-ID40'],
#  '小东江-骑楼': [5.18, 'ID9-ID31'],
#  '小东江-凉拌菜': [0, 'ID9-ID89'],
#  '小东江-小东江': [8.18, 'ID9-ID9'],
#  '小东江-甜品': [0, 'ID9-ID49'],
#  '小东江-UNPOCO柏蔻': [0, 'ID9-ID80'],
#  '小东江-沙滩': [0.78, 'ID9-ID5'],
#  '小东江-烧鸭饭': [0, 'ID9-ID57'],
#  '小东江-海滨公园': [0, 'ID9-ID26'],
#  '小东江-煲仔饭': [0, 'ID9-ID88'],
#  '小东江-北洛湾': [0, 'ID9-ID25'],
#  '小东江-面包': [3.86, 'ID9-ID11'],
#  '小东江-榴莲千层': [0, 'ID9-ID54'],
#  '小东江-水东湾': [4.27, 'ID9-ID45'],
#  '小东江-炸鸡': [0, 'ID9-ID59'],
#  '小东江-火腿': [0, 'ID9-ID71'],
#  '小东江-肉松': [0, 'ID9-ID63'],
#  '小东江-东湖': [5.37, 'ID9-ID15'],
#  '小东江-I': [5.48, 'ID9-ID8'],
#  '小东江-黄油': [0, 'ID9-ID75'],
#  '小东江-叉烧饭': [0, 'ID9-ID56'],
#  '小东江-三元塔': [0, 'ID9-ID32'],
#  '小东江-湖光岩': [0, 'ID9-ID36'],
#  '小东江-蔬菜': [4.18, 'ID9-ID58'],
#  '小东江-日式蟹肉卷': [0, 'ID9-ID78'],
#  '小东江-油条碎': [0, 'ID9-ID84'],
#  '小东江-甜点': [0, 'ID9-ID12'],
#  '小东江-牛肉': [1.63, 'ID9-ID66'],
#  '小东江-小炒': [0, 'ID9-ID50'],
#  '小东江-野菠萝公园': [0, 'ID9-ID38'],
#  '小东江-和牛盖饭': [0, 'ID9-ID77'],
#  '小东江-饮料': [0, 'ID9-ID16'],
#  '小东江-温德姆酒店': [0, 'ID9-ID39'],
#  '小东江-泡芙': [0, 'ID9-ID62'],
#  '小东江-牛排': [0, 'ID9-ID42'],
#  '小东江-文化广场': [4.6, 'ID9-ID6'],
#  '小东江-牛肚': [7.01, 'ID9-ID74'],
#  '小东江-晏镜岭': [0, 'ID9-ID17'],
#  '小东江-刺身': [0, 'ID9-ID70'],
#  '小东江-御水古温泉': [4.01, 'ID9-ID33'],
#  '小东江-自助菜': [0, 'ID9-ID85'],
#  '小东江-游乐场': [4.01, 'ID9-ID23'],
#  '小东江-中心广场': [0, 'ID9-ID3'],
#  '小东江-摩天轮': [7.26, 'ID9-ID24'],
#  '小东江-高钙大骨鸳鸯锅': [0, 'ID9-ID79'],
#  '小东江-天马山': [4.48, 'ID9-ID19'],
#  '小东江-赤坎老街': [0, 'ID9-ID48'],
#  '小东江-玉湖': [3.54, 'ID9-ID37'],
#  '小东江-菠萝皮': [0, 'ID9-ID87'],
#  '小东江-热狗': [0, 'ID9-ID46'],
#  '小东江-红树林': [4.27, 'ID9-ID10'],
#  '小东江-菠萝包': [0, 'ID9-ID86'],
#  '小东江-米饭': [0, 'ID9-ID61'],
#  '小东江-无花果': [0, 'ID9-ID82'],
#  '小东江-关东煮': [0, 'ID9-ID90'],
#  '小东江-荔枝': [6.23, 'ID9-ID13'],
#  '小东江-架海灯塔': [0, 'ID9-ID18'],
#  '小东江-望海楼': [0, 'ID9-ID41'],
#  '小东江-无花果萨拉米披萨': [0, 'ID9-ID81'],
#  '小东江-早茶': [0, 'ID9-ID7'],
#  '小东江-红树林栈道': [5.37, 'ID9-ID14'],
#  '小东江-榴莲蛋糕': [0, 'ID9-ID52'],
#  '小东江-炒乌冬': [0, 'ID9-ID68'],
#  '小东江-酱汁': [5.37, 'ID9-ID76'],
#  '小东江-奶油': [0, 'ID9-ID53'],
#  '小东江-大角湾': [0, 'ID9-ID27'],
#  '小东江-博物馆': [4.89, 'ID9-ID20'],
#  '小东江-海鲜': [3.18, 'ID9-ID4'],
#  '小东江-海陵岛': [0, 'ID9-ID22'],
#  '小东江-高州仙人洞景区': [0, 'ID9-ID47'],
#  '小东江-湛江大桥': [0, 'ID9-ID44'],
#  '小东江-寿司': [0, 'ID9-ID55'],
#  '小东江-新湖公园': [6.6, 'ID9-ID43'],
#  '小东江-海滩': [1.52, 'ID9-ID1'],
#  '小东江-玻璃桥': [0, 'ID9-ID21'],
#  '小东江-第一滩': [2.93, 'ID9-ID2'],
#  '小东江-蜂蜜芥末': [0, 'ID9-ID60'],
#  '小东江-生蚝': [0, 'ID9-ID35'],
#  '小东江-十里军港': [0, 'ID9-ID30'],
#  '小东江-凤梨': [5.86, 'ID9-ID69'],
#  '小东江-炒牛河': [0, 'ID9-ID73'],
#  '小东江-露天矿生态公园': [4.86, 'ID9-ID28'],
#  '小东江-薯条': [0, 'ID9-ID64'],
#  '小东江-蛋挞': [0, 'ID9-ID67'],
#  '小东江-雷州古城': [0, 'ID9-ID34'],
#  '小东江-粗薯': [0, 'ID9-ID83'],
#  '小东江-雅米乐园': [0, 'ID9-ID51'],
#  '小东江-露天矿': [5.92, 'ID9-ID29'],
#  '小东江-脆皮热狗卷': [0, 'ID9-ID72'],
#  '拉面-东南码头': [0, 'ID65-ID40'],
#  '拉面-骑楼': [0, 'ID65-ID31'],
#  '拉面-凉拌菜': [0, 'ID65-ID89'],
#  '拉面-小东江': [0, 'ID65-ID9'],
#  '拉面-甜品': [0, 'ID65-ID49'],
#  '拉面-UNPOCO柏蔻': [0, 'ID65-ID80'],
#  '拉面-沙滩': [0, 'ID65-ID5'],
#  '拉面-烧鸭饭': [0, 'ID65-ID57'],
#  '拉面-海滨公园': [0, 'ID65-ID26'],
#  '拉面-煲仔饭': [0, 'ID65-ID88'],
#  ...}

# %% [markdown]
# ### word2vec词向量相似度

# %%
all_entity.head()
# Out:
#            实体
# 0         炒乌冬
# 1        凤凰酒店
# 2        兰州拉面
# 3          甜品
# 4  中国第一滩一家人公寓

# %%
# 分词
with open('data/myworddict.txt', 'w+', newline='', encoding='utf-8') as fp:
    for e in all_entity['实体'].tolist():
        fp.write(e)
        fp.write('\r')

# %%
# 停用词
with open('data/stopword.txt', encoding='utf-8') as fp:
    words = fp.readlines()
    stopwords = [s.replace('\n', '').strip() for s in words] + ['\n', ' ', '茂名', '茂名市', '广东', '广东省', '中国',
                '国家', '全国', '哒']

# %%
jieba.load_userdict('data/myworddict.txt')
text_cut = list(map(jieba.lcut, texts))
text_stop = [[w for w in tc if w not in stopwords] for tc in text_cut]
text_stop
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\HTHDS\AppData\Local\Temp\jieba.cache
# Loading model cost 0.901 seconds.
# Prefix dict has been built successfully.
# [['放鸡岛',
#   '放鸡岛',
#   '原名',
#   '湾',
#   '舟岛',
#   '又名',
#   '汾洲岛',
#   '位于',
#   '电',
#   '白区',
#   '博贺镇',
#   '东南',
#   '14.5',
#   '公里',
#   '岛屿',
#   '岛上',
#   '最高点',
#   '高',
#   '122',
#   '米',
#   '面积',
#   '1.9',
#   '平方公里',
#   '海岛',
#   '惠州',
#   '巽',
#   '寮',
#   '湾',
#   '惠州',
#   '巽',
#   '寮',
#   '湾',
#   '读',
#   'x',
#   'ù',
#   'nli',
#   'á',
#   'ow',
#   'ā',
#   'n',
#   '位于',
#   '惠州市',
#   '巽',
#   '寮',
#   '湾',
#   '绵延',
#   '11',
#   '公里',
#   '海滩',
#   '沙质',
#   '洁白',
#   '细幼',
#   '形',
#   '白金',
#   '海沙',
#   '含硅量',
#   '达',
#   '99%',
#   '世界',
#   '罕见',
#   '海水',
#   '更是',
#   '青翠',
#   '碧绿',
#   '原生态',
#   '级',
#   '水质',
#   '更属',
#   '国内',
#   '罕有',
#   '海滩',
#   '百米',
#   '水深',
#   '超过',
#   '米',
#   '属',
#   '全世界',
#   '顶级',
#   '天然',
#   '海水浴场',
#   '空气',
#   '负氧离子',
#   '含量',
#   '达',
#   '65856',
#   'm3',
#   '高于',
#   '三亚',
#   '国内',
#   '顶级',
#   '天然',
#   '氧吧'],
#  ['位于',
#   '西部',
#   '简称',
#   '粤西',
#   '介绍',
#   '说',
#   '湛江',
#   '旁',
#   '广西',
#   '很近',
#   '哈哈哈哈',
#   '说',
#   '潮汕',
#   '美食',
#   '聚集地',
#   '去过',
#   '汕头',
#   '发现',
#   '粤东',
#   '粤西',
#   '美食',
#   '地方',
#   '东西',
#   '好吃',
#   '分散',
#   '当地人',
#   '很难',
#   '找到',
#   '帖子',
#   '外面',
#   '太',
#   '想念',
#   '家里',
#   '家乡',
#   '美食',
#   '解解馋',
#   '有缘',
#   '见到',
#   '当做',
#   '美食',
#   '科普',
#   '贴',
#   '美食',
#   'List',
#   '早餐',
#   '牛腩',
#   '粉',
#   '早茶',
#   '国际',
#   '大酒店',
#   '熹龙',
#   '华海',
#   '石墨',
#   '肠粉',
#   '捞粉',
#   '猪杂',
#   '汤',
#   '食惯',
#   '嘴',
#   '点心',
#   '籺',
#   '发',
#   '籺',
#   '簸箕',
#   '炊',
#   '凉粉',
#   '甜',
#   '豆花',
#   '电城',
#   '蚝',
#   '炸',
#   '陈皮',
#   '鸡翅',
#   '豆芽',
#   '粉',
#   '化州',
#   '糖水',
#   '主食',
#   '海鲜',
#   '陈村',
#   '绉',
#   '记',
#   '化州',
#   '香油',
#   '鸡',
#   '农家乐',
#   '四海一家',
#   '水东',
#   '鸭',
#   '粥',
#   '水东',
#   '芥菜',
#   '猪红',
#   '麦菜',
#   '煲',
#   '杂鱼',
#   '煲',
#   '白切',
#   '鸡',
#   '水土',
#   '鸡',
#   '黄鳝',
#   '粥',
#   '隔',
#   '水蒸',
#   '鸡',
#   '宵夜',
#   '烧生',
#   '蚝',
#   '化州',
#   '牛杂',
#   '17',
#   '中',
#   '15',
#   '中',
#   '炒',
#   '田螺',
#   '沙煲',
#   '粉',
#   '水果',
#   '香蕉',
#   '荔枝',
#   '龙眼',
#   '三华',
#   '李',
#   '黄皮',
#   '杨桃',
#   '菠萝蜜',
#   '早餐',
#   '早餐',
#   '选择',
#   '爸妈',
#   '喜欢',
#   '早上',
#   '一碗',
#   '白粥',
#   '配',
#   '一条',
#   '香',
#   '煎',
#   '海鱼',
#   '萝卜干',
#   '煎蛋',
#   '喜欢',
#   '牛腩',
#   '粉',
#   '肠粉',
#   '周末',
#   '时间',
#   '充足',
#   '喝个',
#   '早茶',
#   '说',
#   '早晨',
#   '挺',
#   '悠闲',
#   '早茶',
#   '喜欢',
#   '早茶',
#   '小时候',
#   '喜欢',
#   '一车',
#   '车',
#   '各式各样',
#   '糕点',
#   '喜欢',
#   '喝茶',
#   '吃',
#   '东西',
#   '喝',
#   '家人',
#   '聊天',
#   '感觉',
#   '喝',
#   '早茶',
#   '小时',
#   '午饭',
#   '不用',
#   '吃',
#   '早茶',
#   '必点',
#   '青',
#   '红椒',
#   '蒸',
#   '凤爪',
#   '软烂',
#   '好吃',
#   '蒸',
#   '排骨',
#   '清蒸',
#   '豉油',
#   '鲍汁',
#   '凤爪',
#   '有嚼头',
#   '蒸',
#   '凤爪',
#   '口感',
#   '煎',
#   '饺',
#   '蒸',
#   '金钱',
#   '肚',
#   '虾饺',
#   '蛋挞',
#   '反正',
#   '推车',
#   '挑',
#   '顺眼',
#   '吃',
#   '传统',
#   '茶楼',
#   '推车',
#   '推车',
#   '食材',
#   '蒸点',
#   '烘焙',
#   '糕点',
#   '粥',
#   '凉拌菜',
#   '茶楼',
#   '推车',
#   '只能',
#   '菜单',
#   '看着',
#   '菜名',
#   '点菜',
#   '没意思',
#   '发现',
#   '城市',
#   '早茶',
#   '点心',
#   '稍微',
#   'PS',
#   '早茶',
#   '要点',
#   '茶',
#   '🍵',
#   '茶',
#   '一壶',
#   '壶',
#   '茶',
#   '持续',
#   '泡',
#   '久',
#   '那种',
#   '早茶',
#   '人头',
#   '算茶',
#   '位费',
#   '要点',
#   '一小包',
#   '茶',
#   '茶壶',
#   '泡',
#   '说',
#   '样子',
#   '我家',
#   '点',
#   '普洱',
#   '红茶',
#   '养胃',
#   '喜欢',
#   '普洱',
#   '味道',
#   '加点',
#   '菊花',
#   '👇',
#   '喜欢',
#   '拖车',
#   '形式',
#   '点菜',
#   '方式',
#   '每台',
#   '小车',
#   '种类',
#   '食物',
#   '看着',
#   '食物',
#   '选',
#   '喜欢',
#   '喜欢',
#   '笼子',
#   '热',
#   '哈哈哈',
#   '早茶',
#   '纸',
#   '踢',
#   '√',
#   '喜欢',
#   '冷冰冰',
#   '点菜',
#   '方式',
#   '👇',
#   '蒸',
#   '排骨',
#   '必点',
#   '👇',
#   '酱油',
#   '王',
#   '排骨',
#   '好吃',
#   '👇',
#   '我弟',
#   '喜欢',
#   '蒸',
#   '金钱',
#   '肚',
#   '👇',
#   '喝茶',
#   '喝',
#   '聊',
#   '👇',
#   '服务员',
#   '大堂',
#   '经理',
#   '帮忙',
#   '拿菜',
#   '👇',
#   '糯米鸡',
#   '👇',
#   '爱',
#   '凤爪',
#   '从小到大',
#   '早茶',
#   '必点',
#   '👇',
#   '包点',
#   '妈',
#   '必点',
#   '东西',
#   '👇',
#   '茶',
#   '吃腻',
#   '杯',
#   '茶',
#   '再战',
#   '小时',
#   '👇',
#   '早茶',
#   '猪杂',
#   '粥',
#   '新鲜',
#   '猪杂',
#   '煮粥',
#   '特别',
#   '鲜甜',
#   '👇',
#   '啊啊啊',
#   '爱',
#   '烤鸡',
#   '翅',
#   '小孩',
#   '爱',
#   '玩意儿',
#   '每次',
#   '点',
#   '吃',
#   '👇',
#   '蛋挞',
#   '葡挞',
#   '要点',
#   '👇',
#   '煎',
#   '饺',
#   '韭菜',
#   '马蹄',
#   '猪肉',
#   '馅',
#   '煎',
#   '香',
#   '早茶',
#   '必点'],
#  ['行程',
#   '总览',
#   '地点',
#   '时间',
#   '天',
#   '游玩',
#   '时间',
#   '约',
#   '天半',
#   '交通',
#   '大巴车',
#   '高铁',
#   '公交车',
#   '网约车',
#   '共享',
#   '单车',
#   '步行',
#   '住宿',
#   '蹭',
#   '朋友家',
#   '线路',
#   'DAY1',
#   '高州',
#   '博物馆',
#   '高州',
#   '市区',
#   '冼',
#   '太庙',
#   '鉴江',
#   'DAY2',
#   '露天矿',
#   '生态',
#   '公园',
#   '博物馆',
#   '红树林',
#   '小东江',
#   'DAY3',
#   '石油化工',
#   '学院',
#   '学院',
#   '回程',
#   '说',
#   '不以',
#   '旅游',
#   '而出名',
#   '要说',
#   '玩',
#   '掰',
#   '指头',
#   '数出',
#   '放鸡岛',
#   '第一',
#   '滩',
#   '仙人洞',
#   '御水古',
#   '温泉',
#   '此前',
#   '介绍',
#   '值得',
#   '一游',
#   '地方',
#   '景点',
#   '未',
#   '行程',
#   '中',
#   '涉及',
#   '原因',
#   '面积',
#   '下辖',
#   '区',
#   '县级市',
#   '公共交通',
#   '不算',
#   '发达',
#   '景点',
#   '市区',
#   '远',
#   '自驾',
#   '包车',
#   '前往',
#   '确实',
#   '费心',
#   '费力',
#   '既然如此',
#   '选择',
#   '地方',
#   '知名',
#   '景点',
#   '遗憾',
#   '来到',
#   '新',
#   '城市',
#   '新鲜',
#   '山川',
#   '湖海',
#   '跋山涉水',
#   '游法',
#   '穿梭',
#   '市井',
#   '小巷',
#   '体会',
#   '生活',
#   '未尝',
#   '美好',
#   '经历',
#   '深圳',
#   '出发',
#   '常规',
#   '线路',
#   '三种',
#   '高铁',
#   '火车',
#   '汽车',
#   '大巴',
#   '高铁',
#   '最快',
#   '约',
#   '3.5',
#   '小时',
#   '深圳',
#   '往返',
#   '班次',
#   '一班',
#   '早上',
#   '点多',
#   '最早',
#   '一班',
#   '火车',
#   '最慢',
#   '约',
#   '小时',
#   '班次',
#   '少',
#   '时间',
#   '不赶',
#   '抢个',
#   '晚上',
#   '出发',
#   '卧铺',
#   '睡',
#   '一晚',
#   '第二天',
#   '一早',
#   '到达',
#   '不错',
#   '很难',
#   '抢',
#   '票',
#   '大巴',
#   '两者之间',
#   '小时',
#   '班次',
#   '乘坐',
#   '舒适度',
#   '不及',
#   '高铁',
#   '火车',
#   'PS',
#   '差钱',
#   '选择',
#   '先',
#   '深圳',
#   '坐',
#   '高铁',
#   '广州',
#   '南站',
#   '广州',
#   '南站',
#   '坐',
#   '高铁',
#   '广州',
#   '前往',
#   '班次',
#   '非',
#   '假日',
#   '期间',
#   '愁',
#   '买不到',
#   '票',
#   'DAY1',
#   '高州',
#   '行',
#   '周五',
#   '下午',
#   '工作',
#   '已毕',
#   '提前',
#   '一点儿',
#   '单位',
#   '开溜',
#   '坐',
#   '大巴',
#   '迎着',
#   '落日',
#   '出发',
#   '路程',
#   '晚上',
#   '10',
#   '点多',
#   '时方',
#   '抵达',
#   '汽车站',
#   '下车',
#   '打个',
#   '滴滴',
#   '拼车',
#   '快车',
#   '便宜',
#   '找',
#   '朋友',
#   '朋友',
#   '汇合',
#   '打车',
#   '一家',
#   '烧烤店',
#   '吃些',
#   '烧烤',
#   '喝点',
#   '小酒',
#   '叙叙旧',
#   '回',
#   '朋友家',
#   '洗漱',
#   '休息',
#   '等待',
#   '明早',
#   '第一天',
#   '旅程',
#   '到来',
#   '早上',
#   '天气',
#   '甚',
#   '朋友',
#   '吃个',
#   '早餐',
#   '捞粉',
#   '当地人',
#   '常吃',
#   '早餐',
#   '薄薄的',
#   '细河',
#   '粉淋上',
#   '酱汁',
#   '搭配',
#   '简单',
#   '味道',
#   '河粉',
#   '滑溜',
#   '口感',
#   '酱汁',
#   '香溢',
#   '味道',
#   '相得益彰',
#   '吃',
#   '完',
#   '意犹未尽',
#   '吃',
#   '完',
#   '早餐',
#   '顺风',
#   '车',
#   '前往',
#   '高州',
#   '高州',
#   '提',
#   '下辖',
#   '区',
#   '县级市',
#   '便是',
#   '高州市',
#   '其离',
#   '茂南区',
#   '区',
#   '尚有',
#   '一段距离',
#   '公交',
#   '达',
#   '路途遥远',
#   '耗费',
#   '时间',
#   '长',
#   '打个',
#   '顺风',
#   '车',
#   '选择',
#   '坐火车',
#   '火车站',
#   '高州',
#   '火车站',
#   '来往',
#   '班次',
#   '朋友',
#   '忘记',
#   '身份证',
#   '只好',
#   '作罢',
#   '来到',
#   '高州',
#   '鉴',
#   '江边',
#   '上下车',
#   '鉴江',
#   '粤西',
#   '沿海',
#   '最长',
#   '一条',
#   '独流',
#   '入海',
#   '河流',
#   '原本',
#   '打算',
#   '先',
#   '高州',
#   '博物馆',
#   '时',
#   '已近',
#   '中午',
#   '博物馆',
#   '闭门谢客',
#   '只好',
#   '先去',
#   '吃',
#   '午饭',
#   '晚点',
#   '朋友',
#   '推荐',
#   '来到',
#   '一处',
#   '酒店',
#   '餐馆',
#   '就餐',
#   '点',
#   '几样',
#   '特色',
#   '菜肴',
#   '发生',
#   '插曲',
#   '点',
#   '黑豆',
#   '羊腩',
#   '煲',
#   '帮忙',
#   '记单',
#   '服务员',
#   '要点',
#   '道菜',
#   '点点头',
#   '菜点',
#   '完后',
#   '服务员',
#   '道菜',
#   '问',
#   '一遍',
#   '感到',
#   '奇怪',
#   '点点头',
#   '一会',
#   '另一名',
#   '工作人员',
#   '跑',
#   '道菜',
#   '这下',
#   '搞',
#   '我俩',
#   '懵',
#   '逼',
#   '道菜',
#   '暗藏',
#   '玄机',
#   '店家',
#   '反反复复',
#   '确认',
#   '菜单',
#   '这道',
#   '菜名',
#   '研究',
#   '半天',
#   '道',
#   '道',
#   '朋友',
#   '问',
#   '高州',
#   '同事',
#   '答',
#   '曰',
#   '店家',
#   '再三',
#   '确认',
#   '是因为',
#   '道菜',
#   '价格',
#   '高',
#   '50',
#   '元',
#   '平时',
#   '点',
#   '点',
#   '肯定',
#   '确认',
#   '咯',
#   '连续',
#   '确认',
#   '几次',
#   '答',
#   '曰',
#   '是因为',
#   '高州',
#   '淳朴',
#   '操作',
#   '插曲',
#   '中午',
#   '吃饭',
#   '点',
#   '菜',
#   '很快',
#   '煎煮',
#   '籺',
#   'h',
#   'é',
#   '特色小吃',
#   '籺',
#   '一种',
#   '传统',
#   '特色',
#   '食品',
#   '用米',
#   '麦粒',
#   '粗粮',
#   '主料',
#   '加',
#   '辅料',
#   '制作',
#   '而成',
#   '表皮',
#   '较厚',
#   '咬起来',
#   '韧道',
#   '里',
#   '面包',
#   '韭菜',
#   '虾米',
#   '绿豆',
#   '多种',
#   '馅料',
#   '口感',
#   '层次',
#   '细嚼慢咽',
#   '越嚼',
#   '越香',
#   '吃',
#   '完后',
#   '博物馆',
#   '开门',
#   '时间',
#   '先',
#   '走走',
#   '找个',
#   '地方',
#   '歇息',
#   '桂圆',
#   '路',
#   '桂圆',
#   '龙眼',
#   '早',
#   '汉朝',
#   '高州',
#   '桂圆',
#   '便是',
#   '朝廷',
#   '贡品',
#   '广西',
#   '博白县',
#   '高州市',
#   '福建',
#   '莆田市',
#   '桂圆',
#   '产区',
#   '这三大',
#   '产地',
#   '盛产',
#   '桂圆',
#   '正宗',
#   '中午',
#   '烈日炎炎',
#   '走',
#   '不多时',
#   '找到',
#   '一家',
#   '咖啡馆',
#   '喝咖啡',
#   '聊聊天',
#   '消磨',
#   '时间',
#   '时间',
#   '启程',
#   '前往',
#   '博物馆',
#   '高州市',
#   '博物馆',
#   '博物馆',
#   '两层',
#   '一层',
#   '展列',
#   '东西',
#   '民国',
#   '改革开放',
#   '二层',
#   '追溯到',
#   '过往',
#   '几个',
#   '朝代',
#   '一层',
#   '东西',
#   '旧',
#   '熟悉',
#   '感',
#   '老式',
#   '电话机',
#   '缝纫机',
#   '手电筒',
#   '物事',
#   '农民',
#   '干',
#   '农活',
#   '照片',
#   '小时候',
#   '接触',
#   '经历',
#   '看着',
#   '依稀',
#   '回',
#   '想起',
#   '童年时期',
#   '外公',
#   '外婆',
#   '生活',
#   '零碎',
#   '片段',
#   '一层',
#   '完',
#   '天',
#   '降',
#   '大雨',
#   '七八',
#   '月份',
#   '天气',
#   '说变',
#   '变',
#   '适才',
#   '晴空万里',
#   '一言不合',
#   '大雨',
#   '侵袭',
#   '眼下',
#   '博物馆',
#   '未',
#   '走',
#   '完',
#   '不在意',
#   '施施然',
#   '二层',
#   '二层',
#   '展列',
#   '物品',
#   '旧',
#   '古代',
#   '所用',
#   '陶罐',
#   '雕塑',
#   '饰品',
#   '另有',
#   '几幅',
#   '插画',
#   '介绍',
#   '古时',
#   '名人',
#   '潘',
#   '两晋',
#   '时期',
#   '道士',
#   '这座',
#   '城市',
#   '名即',
#   '名字',
#   '命名',
#   '冼',
#   '夫人',
#   '南朝',
#   '巾帼英雄',
#   '逛',
#   '完',
#   '博物馆',
#   '眼看',
#   '雨',
#   '坐在',
#   '凳子',
#   '等候',
#   '雨停',
#   '也许',
#   '昨天',
#   '休息',
#   '缘故',
#   '博物馆',
#   '幽静',
#   '坐',
#   '坐',
#   '倒',
#   '睡着',
#   '博物馆',
#   '睡',
#   '充满',
#   '知识',
#   '气息',
#   '历史',
#   '气息',
#   '觉',
#   '只能',
#   '说',
#   '真香',
#   '醒来',
#   '雨',
#   '停',
#   '走走',
#   '路过',
#   '高州',
#   '火车站',
#   '老旧',
#   '政府',
#   '翻新',
#   '告示',
#   '说',
#   '有意思',
#   '告示',
#   '面子',
#   '缝纫机',
#   '家里',
#   '时而',
#   '还会',
#   '外婆',
#   '妈妈',
#   '有用',
#   '时过境迁',
#   '机器',
#   '手艺',
#   '城里',
#   '不见踪影',
#   '老家',
#   '极少',
#   '见到',
#   '时',
#   '感到',
#   '怀旧',
#   '社会',
#   '发展',
#   '日新月异',
#   '老一辈',
#   '赖以为生',
#   '手艺',
#   '机器',
#   '也许',
#   '最终',
#   '消逝',
#   '时代',
#   '变迁',
#   '中',
#   '路过',
#   '鉴江',
#   '大江',
#   '总让',
#   '感到',
#   '心旷神怡',
#   '市井',
#   '一角',
#   '两边',
#   '骑',
#   '楼林立',
#   '边上',
#   '店铺',
#   '卖',
#   '各式各样',
#   '商品',
#   '间',
#   '商场',
#   '大红纸',
#   '黑字',
#   '老板',
#   '吆喝',
#   '写',
#   '整一个',
#   '概括',
#   '两字',
#   '血亏',
#   '老板',
#   '血亏',
#   '甩卖',
#   '清仓',
#   '甩卖',
#   '跳楼价',
#   '甩卖',
#   '挥泪',
#   '甩卖',
#   '听',
#   '老板',
#   '卖力',
#   '吆喝',
#   '想',
#   '说',
#   '这年头',
#   '赚钱',
#   '不易',
#   '想着',
#   '想着',
#   '想到',
#   '浙江',
#   '温州',
#   '皮革厂',
#   '逃跑',
#   '黄鹤',
#   '小姨子',
#   '东西',
#   '卖不卖',
#   '说',
#   '黄鹤',
#   '小姨子',
#   '故事',
#   '却是',
#   '人尽皆知',
#   '只能',
#   '说',
#   '广告',
#   '打得',
#   '太值',
#   '朋友',
#   '高州',
#   '熟',
#   '有名',
#   '景点',
#   '远',
#   '开车',
#   '难以',
#   '前往',
#   '市区',
#   '转',
#   '转',
#   '不知去向',
#   '迷茫',
#   '感',
#   '幸好',
#   '高州',
#   '同事',
#   '妹子',
#   '有空',
#   '转转',
#   '吃',
#   '妹子',
#   '起飞',
#   '薯',
#   '包',
#   '籺',
#   '又称',
#   '姨',
#   '包',
#   '籺',
#   '高州',
#   '著名',
#   '传统',
#   '小吃',
#   '清朝',
#   '上百年',
#   '历史',
#   '蕃薯粉',
#   '做成',
#   '内里',
#   '包裹',
#   '猪肉',
#   '花生',
#   '多种',
#   '馅料',
#   '香',
#   '爽脆',
#   '滑口',
#   '薯',
#   '包',
#   '籺',
#   '淋上',
#   '酱油',
#   '醋',
#   '吃',
#   '我选',
#   '加',
#   '酱油',
#   '当地人',
#   '喜欢',
#   '加醋',
#   '想来',
#   '加粗',
#   '口味',
#   '变得',
#   '酸酸甜甜',
#   '味道',
#   '层次',
#   '诱人',
#   '加',
#   '酱油',
#   '薯',
#   '包',
#   '籺'],
#  ['前言',
#   '几分钟',
#   '真的',
#   '吃',
#   '不遍',
#   '题目',
#   '噱头',
#   '🔥',
#   '🔥',
#   '第一次',
#   '写',
#   '家乡',
#   '游记',
#   '店',
#   '好吃',
#   '推荐',
#   '评论',
#   '留下',
#   '喜欢',
#   '店',
#   '到时候',
#   '研究',
#   '文化底蕴',
#   '城市',
#   '物价',
#   '高',
#   '工资',
#   '低',
#   '依然',
#   '年轻一代',
#   '留守',
#   '原因',
#   '篇文章',
#   '老板',
#   '机会',
#   '希望',
#   '多一点',
#   '回来',
#   '投资',
#   '家乡',
#   '城市',
#   '营销',
#   '策略',
#   '人才辈出',
#   '家乡',
#   '越来越',
#   '🇨',
#   '🇳',
#   '✌',
#   '️',
#   '😊',
#   '😊',
#   '家宴',
#   '大排档',
#   '文明',
#   '中路',
#   '号',
#   '供水',
#   '大楼',
#   '对面',
#   '这家',
#   '店',
#   '适合',
#   '朋友',
#   '小聚',
#   '上次',
#   '哥哥',
#   '娜娜',
#   '22',
#   '气质',
#   '吃',
#   '人均',
#   '50',
#   '推荐',
#   '手',
#   '撕',
#   '鸡',
#   '哥哥',
#   '点',
#   '猪尾',
#   '炒鸡',
#   '肾气',
#   '质点',
#   '小米',
#   '糕',
#   '家常菜',
#   '环境',
#   '添记',
#   '新鲜',
#   '猪杂',
#   '粥',
#   '双山',
#   '二路',
#   '号',
#   '首层',
#   '18',
#   '号',
#   '这家',
#   '店',
#   '表弟',
#   '吃',
#   '夜宵',
#   '晚上',
#   '点到',
#   '凌晨',
#   '点',
#   '海鲜类',
#   '吃',
#   '推荐',
#   '脆皖',
#   '鱼',
#   '粥',
#   '鱼',
#   '粥',
#   '真的',
#   '粥',
#   '这家',
#   '店',
#   '偏',
#   '潮汕',
#   '风味',
#   '吃',
#   '小龙虾',
#   '人均',
#   '50',
#   '重庆',
#   '小天鹅',
#   '火锅',
#   '文光',
#   '中路',
#   '68',
#   '号',
#   '天一',
#   '国际',
#   '黑卡',
#   '活动',
#   '一段时间',
#   '搞',
#   '活动',
#   '五折',
#   '吃',
#   '高颜值',
#   '火锅',
#   '黑卡',
#   '期间',
#   '五折',
#   '人均',
#   '50',
#   '拥有',
#   '汤底',
#   '推荐',
#   '玉米',
#   '汁',
#   '虾',
#   '滑',
#   '莴笋',
#   '🙈',
#   '🙈',
#   '🙈',
#   '🙈',
#   '😘',
#   '😘',
#   '😘',
#   '😘',
#   '胡桃',
#   '里',
#   '音乐',
#   '酒馆',
#   '新福',
#   '三路',
#   '10',
#   '号',
#   '首层',
#   '胡桃',
#   '里',
#   '遍布全国',
#   '城市',
#   '文艺',
#   '小酒馆',
#   '代表',
#   '这家',
#   '店',
#   '做',
#   '营销',
#   '成功',
#   '一间',
#   '生日',
#   '聚会',
#   '情侣',
#   '约会',
#   '兄弟',
#   'p',
#   '酒',
#   '姐妹',
#   '聚会',
#   '单身',
#   '狗',
#   '想',
#   '艳遇',
#   '地方',
#   '适合',
#   '营销',
#   '成功',
#   '质量',
#   '服务',
#   '真的',
#   '火',
#   '一张',
#   '图',
#   '吃',
#   '大碗',
#   '饭',
#   '推荐',
#   '菜式',
#   '地方',
#   '团购',
#   '😊',
#   '😊',
#   '😊',
#   '😊',
#   '莫叔',
#   '牛杂',
#   '这是',
#   '一家',
#   '故事',
#   '老店',
#   '有人',
#   '强烈推荐',
#   '人均',
#   '真的',
#   '人去',
#   '吃',
#   '位置',
#   '路边',
#   '位置',
#   '几样',
#   '菜',
#   '招牌',
#   '推荐',
#   '😋',
#   '😋',
#   '🔥',
#   '🔥',
#   '😂',
#   '😂',
#   '😊',
#   '😊',
#   '😊'],
#  ['原本',
#   '广州',
#   '交通',
#   '稍差',
#   '适合',
#   '周末',
#   '二日游',
#   '江湛',
#   '铁路',
#   '开通',
#   '交通',
#   '不成问题',
#   '本来',
#   '设计',
#   '一家',
#   '三口',
#   '放鸡岛',
#   '年底',
#   '海岛',
#   '最佳',
#   '时节',
#   '眼看',
#   '之行',
#   '推到',
#   '明年',
#   '想想',
#   '思路',
#   '灵活',
#   '一点',
#   '区',
#   '没什么',
#   '古迹',
#   '自然风光',
#   '下属',
#   '高州',
#   '化州',
#   '一点',
#   '二者',
#   '市区',
#   '三十多公里',
#   '人去',
#   '奔波',
#   '正好',
#   '地级市',
#   '空白',
#   '补上',
#   '携带',
#   '十年',
#   '尼康',
#   'D60',
#   '镜头',
#   '18',
#   '55mm',
#   '标准',
#   '镜头',
#   '换算',
#   '成全',
#   '画幅',
#   '27',
#   '82.5',
#   'mm',
#   '故障',
#   '镜头',
#   '里',
#   '进',
#   '点',
#   '水汽',
#   '一般性',
#   '对焦',
#   '不成问题',
#   '精准',
#   '对焦',
#   '墙上',
#   '小字',
#   '模糊',
#   'P',
#   'S',
#   '程序',
#   '曝光',
#   '补偿',
#   '值设',
#   '前提',
#   '拍',
#   '照片',
#   '偏暗',
#   '全程',
#   '只能',
#   'M',
#   '模式',
#   '快门',
#   '干脆',
#   '尼康',
#   '广州',
#   '特约',
#   '维修点',
#   '拒绝',
#   '提供',
#   '维修服务',
#   '即便如此',
#   '不想',
#   '依赖',
#   '尼康',
#   'D750',
#   '隔',
#   '几个',
#   'D60',
#   '潮州',
#   '汕尾',
#   '红海湾',
#   '游览',
#   '期待值',
#   '高',
#   '拍摄',
#   '效果',
#   '高',
#   '地方',
#   'D60',
#   '依然',
#   '表现',
#   '期待值',
#   '高',
#   '高州',
#   '化州',
#   '力',
#   '高州',
#   '电白',
#   '三地',
#   '混乱',
#   '关系',
#   '现今',
#   '地级市',
#   '辖区',
#   '明清两代',
#   '高',
#   '州府',
#   '吴川',
#   '石城',
#   '现名',
#   '廉江',
#   '二县',
#   '改',
#   '湛江市',
#   '高州',
#   '电白',
#   '三地',
#   '关系',
#   '混乱',
#   '估计',
#   '无出其右',
#   '查阅',
#   '北宋',
#   '时期',
#   '太平',
#   '寰宇',
#   '记',
#   '明',
#   '一统',
#   '志',
#   '清',
#   '一统',
#   '志',
#   '大型',
#   '地理',
#   '书籍',
#   '总算',
#   '理出',
#   '一条',
#   '线索',
#   '便是',
#   '南朝梁',
#   '清末',
#   '高州',
#   '隋末唐',
#   '短暂',
#   '废除',
#   '之外',
#   '州府',
#   '级',
#   '行政',
#   '单位',
#   '相当于',
#   '地级市',
#   '电白',
#   '南朝梁',
#   '陈',
#   '时期',
#   '短暂',
#   '地当过',
#   '郡',
#   '之外',
#   '隋朝',
#   '县级',
#   '单位',
#   '隋朝',
#   '县级',
#   '单位',
#   '唐太宗',
#   '五代',
#   '南汉',
#   '段时间',
#   '县属',
#   '潘州',
#   '高州',
#   '时间',
#   '高州',
#   '唐代宗',
#   '清末',
#   '高州',
#   '治所',
#   '电白',
#   '两县',
#   '之间',
#   '迁来',
#   '迁',
#   '中华人民共和国',
#   '成立',
#   '县',
#   '改名',
#   '高州县',
#   '电白县',
#   '茂南区',
#   '成立',
#   '地级市',
#   '高州',
#   '之间',
#   '地位',
#   '正好',
#   '颠倒',
#   '南朝梁',
#   '高州',
#   '名称',
#   '这片',
#   '土地',
#   '汉代',
#   '属',
#   '合浦',
#   '郡',
#   '高凉县',
#   '三国',
#   '时期',
#   '吴国',
#   '南朝',
#   '宋齐',
#   '属',
#   '高凉',
#   '郡',
#   '梁武帝',
#   '大通',
#   '二年',
#   '528',
#   '设置',
#   '高州',
#   '这是',
#   '历史',
#   '第一次',
#   '高州',
#   '之名',
#   '州',
#   '郡',
#   '高',
#   '一级',
#   '行政区划',
#   '高州',
#   '管辖',
#   '高凉',
#   '海昌',
#   '郡',
#   '州治',
#   '高凉',
#   '郡',
#   '郡',
#   '治',
#   '思平县',
#   '江门',
#   '恩平',
#   '梁武帝',
#   '中大通',
#   '元年',
#   '529',
#   '海昌',
#   '郡',
#   '分置',
#   '电白',
#   '郡',
#   '这是',
#   '历史',
#   '第一次',
#   '电白',
#   '地名',
#   '郡治',
#   '高州县',
#   '长坡',
#   '镇',
#   '旧城',
#   '村',
#   '属',
#   '高州',
#   '管辖',
#   '隋平陈',
#   '文帝',
#   '开皇',
#   '十年',
#   '590',
#   '高凉',
#   '郡',
#   '电白',
#   '郡',
#   '废',
#   '电白',
#   '郡',
#   '降级',
#   '电白县',
#   '县治',
#   '高州县',
#   '长坡',
#   '镇',
#   '旧城',
#   '村',
#   '电白',
#   '县级',
#   '行政',
#   '单位',
#   '高州',
#   '尚存',
#   '好景不长',
#   '隋炀帝',
#   '大业',
#   '三年',
#   '607',
#   '年',
#   '废',
#   '高州',
#   '重设',
#   '高凉',
#   '郡',
#   '治所',
#   '高凉县',
#   '隋',
#   '置',
#   '县',
#   '年份',
#   '不详',
#   '这是',
#   '历史',
#   '第一次',
#   '地名',
#   '治所',
#   '高州县',
#   '城区',
#   '之名',
#   '来源于',
#   '西晋时期',
#   '著名',
#   '道士',
#   '潘',
#   '之名',
#   '1950',
#   '年代',
#   '县',
#   '县级',
#   '行政',
#   '单位',
#   '县城',
#   '高州县',
#   '城内',
#   '时',
#   '电白',
#   '二县',
#   '皆',
#   '属',
#   '高凉',
#   '郡',
#   '治所',
#   '现今',
#   '高州县',
#   '境内',
#   '唐高祖',
#   '武德',
#   '四年',
#   '621',
#   '废高凉',
#   '郡',
#   '电白',
#   '隶属',
#   '广州',
#   '武德',
#   '六年',
#   '623',
#   '复置',
#   '高州',
#   '治所',
#   '高凉县',
#   '江门',
#   '恩平',
#   '电白县',
#   '皆',
#   '属',
#   '高州',
#   '清末',
#   '高州',
#   '州府',
#   '级',
#   '行政',
#   '单位',
#   '相当于',
#   '地级市',
#   '电白县',
#   '高州',
#   '县则',
#   '脱离',
#   '高州',
#   '高州',
#   '太宗',
#   '贞观',
#   '元年',
#   '627',
#   '县',
#   '改属',
#   '南宕州',
#   '暂',
#   '脱离',
#   '高州',
#   '管辖',
#   '北宋',
#   '初年',
#   '投入',
#   '高州',
#   '怀抱',
#   '贞观',
#   '八年',
#   '634',
#   '高州',
#   '分置',
#   '潘州',
#   '州治',
#   '县',
#   '县',
#   '南宕州',
#   '改属',
#   '潘州',
#   '潘州',
#   '之名',
#   '来源于',
#   '道士',
#   '潘',
#   '姓',
#   '贞观',
#   '二十三年',
#   '649',
#   '高州',
#   '治所',
#   '高凉县',
#   '江门',
#   '恩平',
#   '移到',
#   '良德县',
#   '县治',
#   '高州',
#   '县境',
#   '北部',
#   '东岸',
#   '镇良德墟',
#   '旁',
#   '高州',
#   '治所',
#   '稳定',
#   '高州县',
#   '境内',
#   '唐玄宗',
#   '天宝',
#   '元年',
#   '742',
#   '全国性',
#   '州',
#   '改郡',
#   '浪潮',
#   '中',
#   '高州',
#   '改名',
#   '高凉',
#   '郡',
#   '潘州',
#   '改名',
#   '为南',
#   '潘郡',
#   '唐肃宗',
#   '乾元',
#   '元年',
#   '758',
#   '新一轮',
#   '郡',
#   '改回州',
#   '浪潮',
#   '中',
#   '恢复',
#   '高州',
#   '潘州',
#   '名称',
#   '皆',
#   '属',
#   '岭南',
#   '道',
#   '唐代',
#   '宗大历',
#   '十一年',
#   '776',
#   '高州',
#   '治所',
#   '从良',
#   '德县',
#   '县治',
#   '高州',
#   '县境',
#   '北部',
#   '东岸',
#   '镇良德墟',
#   '旁',
#   '移到',
#   '电白县',
#   '县治',
#   '高州县',
#   '长坡',
#   '镇',
#   '旧城',
#   '村',
#   '潘州',
#   '治所',
#   '县',
#   '五代',
#   '时期',
#   '高州',
#   '潘州',
#   '属',
#   '南汉',
#   '907',
#   '年',
#   '县',
#   '改称',
#   '越裳',
#   '县',
#   '923',
#   '年',
#   '复称',
#   '县',
#   '宋太祖',
#   '开宝',
#   '五年',
#   '972',
#   '年',
#   '潘州',
#   '并入',
#   '高州',
#   '属',
#   '广南西',
#   '路',
#   '广西',
#   '县',
#   '改属',
#   '高州',
#   '清末',
#   '属',
#   '高州',
#   '宋真宗',
#   '景德',
#   '三年',
#   '1006',
#   '高州',
#   '州治',
#   '电白县',
#   '迁',
#   '县',
#   '自此',
#   '高州',
#   '治所',
#   '电白',
#   '两县',
#   '之间',
#   '地迁',
#   '迁',
#   '元世祖',
#   '至元',
#   '十五年',
#   '1278',
#   '高州',
#   '改名',
#   '高州',
#   '路',
#   '安抚司',
#   '治所',
#   '迁',
#   '电白县',
#   '至元',
#   '十七年',
#   '1280',
#   '改称',
#   '高州',
#   '路总管',
#   '府',
#   '属',
#   '湖广',
#   '行',
#   '中书省',
#   '海北',
#   '海南',
#   '道',
#   '元成宗',
#   '大德',
#   '八年',
#   '1304',
#   '高州',
#   '路',
#   '治所',
#   '电白县',
#   '城徙',
#   '治',
#   '县',
#   '元顺帝',
#   '至正',
#   '十五年',
#   '1355',
#   '高州',
#   '路',
#   '治所',
#   '县城',
#   '迁回',
#   '电白县',
#   '城',
#   '明太祖',
#   '洪武',
#   '元年',
#   '1368',
#   '高州',
#   '路',
#   '改为',
#   '高',
#   '州府',
#   '属',
#   '布政使',
#   '司',
#   '府治',
#   '迁往',
#   '县',
#   '情况',
#   '沿续',
#   '清朝',
#   '灭亡',
#   '明宪宗',
#   '成化',
#   '四年',
#   '1648',
#   '电白县',
#   '治迁',
#   '神电卫',
#   '电白县',
#   '电',
#   '城镇',
#   '县城',
#   '降格',
#   '电白',
#   '堡',
#   '中华民国',
#   '成立',
#   '取消',
#   '府',
#   '一级',
#   '行政',
#   '单位',
#   '高',
#   '州府',
#   '历史',
#   '名词',
#   '县',
#   '中华人民共和国',
#   '成立',
#   '1950',
#   '年',
#   '电白县',
#   '城从',
#   '电',
#   '城镇',
#   '迁往',
#   '水东',
#   '镇',
#   '1958',
#   '年',
#   '11',
#   '县',
#   '信宜县',
#   '合并',
#   '为茂信',
#   '县',
#   '12',
#   '月茂信',
#   '县',
#   '改称',
#   '高州县',
#   '县城',
#   '原',
#   '县城',
#   '1961',
#   '年',
#   '高州县',
#   '分',
#   '高州',
#   '信宜',
#   '两县',
#   '高州县',
#   '隶属',
#   '湛江',
#   '专区',
#   '原',
#   '县',
#   '改名',
#   '高州县',
#   '新',
#   '悄悄地',
#   '筹备',
#   '1958',
#   '年',
#   '26',
#   '成立',
#   '工矿区',
#   '市',
#   '管辖',
#   '原',
#   '县',
#   '南部',
#   '区域',
#   '这块',
#   '区域',
#   '称为',
#   '茂南区',
#   '1959',
#   '年',
#   '县级市',
#   '1975',
#   '年',
#   '升格',
#   '地级市',
#   '1983',
#   '年',
#   '实行',
#   '市管县',
#   '体制',
#   '地级市',
#   '辖',
#   '电白',
#   '高州',
#   '信宜',
#   '化州',
#   '四县',
#   '清朝',
#   '灭亡',
#   '一百多年',
#   '高州',
#   '两地',
#   '地位',
#   '发生',
#   '乾坤',
#   '挪移',
#   '变化',
#   '高州',
#   '中',
#   '从府级',
#   '行政',
#   '单位',
#   '降',
#   '县级',
#   '异地',
#   '重建',
#   '方式',
#   '县级',
#   '逆袭',
#   '市级',
#   '翻身',
#   '做',
#   '主人',
#   '角度',
#   '高州',
#   '纯属',
#   '坑',
#   '高州县',
#   '县级市',
#   '辖区',
#   '相当于',
#   '县',
#   '高州县',
#   '城区',
#   '县',
#   '县城',
#   '说',
#   '高州',
#   '不仅如此',
#   '高州',
#   '历史',
#   '个府',
#   '历史',
#   '文化',
#   '高州',
#   '首选',
#   '之地',
#   '区',
#   '茂南区',
#   '没什么',
#   '历史',
#   '文化',
#   '传统',
#   '弄',
#   '半天',
#   '结论',
#   '1950',
#   '年代',
#   '主政者',
#   '行政区划',
#   '命名',
#   '欠考虑',
#   '县',
#   '更名',
#   '高州县',
#   '多此一举',
#   '地位',
#   '颠倒',
#   '称呼',
#   '混淆',
#   '县',
#   '名称',
#   '保留',
#   '新',
#   '石油化工',
#   '城市',
#   '命名',
#   '高州市',
#   '这样的话',
#   '地名',
#   '继承',
#   '关系',
#   '顺畅',
#   '古代',
#   '府城',
#   '建',
#   '某县',
#   '城里',
#   '县城',
#   '称为',
#   '附',
#   '郭县',
#   '中华人民共和国',
#   '成立',
#   '喜欢',
#   '附',
#   '郭县',
#   '地级市',
#   '市区',
#   '府城',
#   '中',
#   '剥离',
#   '开来',
#   '做法',
#   '两种',
#   '思路',
#   '府城',
#   '动',
#   '附',
#   '郭县',
#   '赶到',
#   '新区',
#   '情况',
#   '常见',
#   '广州',
#   '韶州',
#   '肇庆',
#   '潮州',
#   '惠州',
#   '广州',
#   '府',
#   '城内',
#   '两个',
#   '县',
#   '番禺县',
#   '城',
#   '赶到',
#   '南部',
#   '远郊区',
#   '市桥',
#   '镇',
#   '南海县',
#   '赶到',
#   '桂',
#   '城镇',
#   '被划',
#   '佛山市',
#   '韶州',
#   '府',
#   '附',
#   '郭县',
#   '曲江县',
#   '赶到',
#   '马坝',
#   '镇',
#   '肇庆',
#   '府',
#   '附',
#   '郭县',
#   '高要县',
#   '赶到',
#   '西江',
#   '南岸',
#   '南岸',
#   '镇',
#   '潮州',
#   '府',
#   '附',
#   '郭县',
#   '海阳县',
#   '民国',
#   '年间',
#   '更名',
#   '潮安县',
#   '建国',
#   '赶到',
#   '庵',
#   '埠',
#   '镇',
#   '惠州',
#   '府',
#   '附',
#   '郭县',
#   '归善',
#   '县',
#   '民国时期',
#   '改名',
#   '惠阳县',
#   '建国',
#   '赶到',
#   '淡水镇',
#   '附',
#   '郭县',
#   '不动',
#   '新市区',
#   '古代',
#   '廉',
#   '州府',
#   '北海市',
#   '附',
#   '郭县',
#   '合浦',
#   '未',
#   '更名',
#   '未',
#   '挪动',
#   '廉州',
#   '撤销',
#   '恢复',
#   '港口',
#   '地区',
#   '新',
#   '成立',
#   '北海市',
#   '高',
#   '州府',
#   '附',
#   '郭',
#   '县',
#   '分离',
#   '方式',
#   '第二种',
#   '另立',
#   '新市区',
#   '本来',
#   '县',
#   '原处',
#   '高州',
#   '命名',
#   '新',
#   '市区',
#   '实在',
#   '不行',
#   '新',
#   '市区',
#   '换个',
#   '名字',
#   '行',
#   '市县',
#   '易名',
#   '方法',
#   '实属',
#   '智',
#   '11',
#   '24',
#   '广州',
#   '南',
#   '早',
#   '上乘',
#   '07',
#   'D7489',
#   '次',
#   '前往',
#   '10',
#   '33',
#   '到达',
#   ...],
#  ['村',
#   '书记',
#   '主任',
#   '代表',
#   '演讲',
#   '孙波',
#   '讲话',
#   '演讲',
#   '地点',
#   '广播',
#   '电视台',
#   '嘉宾',
#   '签到',
#   '村',
#   '代表',
#   '抽签',
#   '村',
#   '代表',
#   '演讲',
#   '评委会',
#   '前会村',
#   '代表',
#   '演讲',
#   '主持人',
#   '巫帅',
#   '主持',
#   '市',
#   '电视台',
#   '巫帅'],
#  ['2018',
#   '几个',
#   '小时',
#   '故事',
#   '酒',
#   '浪漫',
#   '海岸',
#   '大同',
#   '荔园',
#   '群',
#   '獒',
#   '环绕',
#   '时光',
#   '午后',
#   '咖啡馆',
#   '下班',
#   '失眠',
#   '夜里',
#   '翻开',
#   '书',
#   '身边',
#   '朋友',
#   '三杯',
#   '两盏',
#   '碰着',
#   '杯',
#   '三言两语',
#   '自说自话',
#   '故事',
#   '美好',
#   '还好',
#   '世界',
#   '美好',
#   '世界',
#   '故事',
#   '世界',
#   '似曾相识',
#   '触摸',
#   '不到',
#   '夜里',
#   '酒',
#   '早上',
#   '花儿',
#   '平淡',
#   '真实',
#   '美好',
#   '残酷',
#   '2018',
#   '故事',
#   '愿有',
#   '世界',
#   '永远',
#   '温暖',
#   '无所畏惧',
#   '迎接',
#   '2019',
#   '致敬',
#   '2018',
#   '吊椅',
#   '休闲',
#   '听且',
#   '乐',
#   '小东江',
#   '畔',
#   '云卷云舒',
#   '鳄',
#   '天下',
#   '牙签',
#   '鸟',
#   '高佬',
#   '獒',
#   '苑',
#   '故事',
#   '听',
#   '狗爷',
#   '题记',
#   '时间',
#   '总能',
#   '忘',
#   '事',
#   '发生',
#   '不朽',
#   '狗爷',
#   '狗',
#   '故事',
#   '村里',
#   '年轻人',
#   '有人',
#   '忘记',
#   '高佬',
#   '群',
#   '獒',
#   '故事',
#   '说',
#   '刻骨铭心',
#   '怀念',
#   '高佬',
#   '大富',
#   '大贵',
#   '咖啡',
#   '老二',
#   '黑三',
#   '老四',
#   '水妹',
#   '花王',
#   '岁末年初',
#   '大妹',
#   '生',
#   '六六',
#   '归一',
#   '2018',
#   '20',
#   '獒',
#   '大妹',
#   '生子',
#   '六得',
#   '名字',
#   '村子',
#   '时间',
#   '长',
#   '名字',
#   '有人',
#   '问过',
#   '说',
#   '记不清',
#   '炸弹',
#   '炸得',
#   '脑袋',
#   '不好',
#   '说',
#   '东北',
#   '参加',
#   '远征军',
#   '回来',
#   '老家',
#   '没人',
#   '落',
#   '老人',
#   '村里',
#   '五保户',
#   '无儿无女',
#   '终身',
#   '未娶',
#   '小时候',
#   '狗爷',
#   '贬称',
#   '因缘',
#   '东北',
#   '农村',
#   '土地',
#   '肥沃',
#   '邻里',
#   '和睦',
#   '人心',
#   '向善',
#   '谁家',
#   '有个',
#   '活儿',
#   '帮忙',
#   '盖房子',
#   '娶媳妇',
#   '乡里乡亲',
#   '如果说',
#   '和谐',
#   '记忆里',
#   '和谐',
#   '一幕',
#   '狗爷',
#   '记性',
#   '特别',
#   '村里',
#   '账',
#   '算不清',
#   '请',
#   '狗爷',
#   '算账',
#   '算盘',
#   '轻轻松松',
#   '理清',
#   '账目',
#   '狗爷',
#   '村里',
#   '最有',
#   '威望',
#   '谁家',
#   '有个',
#   '红白喜事',
#   '请',
#   '狗爷',
#   '坐',
#   '坐',
#   '得知',
#   '狗爷',
#   '当年',
#   '参军',
#   '军队',
#   '里',
#   '后勤',
#   '负责',
#   '统计',
#   '作战',
#   '物资',
#   '柴米油盐',
#   '狗爷',
#   '一批',
#   '军人',
#   '里',
#   '唯一',
#   '私塾',
#   '战友',
#   '家里',
#   '写信',
#   '事',
#   '狗爷',
#   '帮忙',
#   '记得',
#   '狗爷',
#   '出神',
#   '中午',
#   '吃',
#   '午饭',
#   '狗爷',
#   '喜欢',
#   '房子',
#   '一侧',
#   '面向',
#   '太阳',
#   '沉沉',
#   '睡',
#   '听见',
#   '大叫',
#   '趴下',
#   '快撤',
#   '顶顶',
#   '小时候',
#   '并不知道',
#   '狗爷',
#   '旁边',
#   '笑',
#   '说',
#   '说胡话',
#   '哪是',
#   '胡话',
#   '狗爷',
#   '梦里',
#   '回到',
#   '那片',
#   '战场',
#   '兄弟',
#   '出生入死',
#   '每次',
#   '狗爷',
#   '醒过来',
#   '目光',
#   '呆滞',
#   '看着',
#   '远处',
#   '半晌',
#   '干裂',
#   '手',
#   '慢慢',
#   '擦掉',
#   '眼睛',
#   '里',
#   '流出',
#   '浑浊',
#   '泪水',
#   '懂',
#   '孤独',
#   '说说话',
#   '读',
#   '木工',
#   '坊',
#   '豆豆',
#   '撒提',
#   '2018',
#   '26',
#   '读',
#   '木工',
#   '坊',
#   '黄金海岸',
#   '东方',
#   '神犬',
#   '2018',
#   '黄金海岸',
#   '廖静',
#   '美术馆',
#   '狗爷',
#   '年纪',
#   '身体',
#   '硬朗',
#   '夏天',
#   '狗爷',
#   '河里',
#   '抓鱼',
#   '狗爷',
#   '猛子',
#   '蹿出',
#   '几米远',
#   '回来',
#   '腰间',
#   '渔网',
#   '里',
#   '肯定',
#   '装满',
#   '鱼',
#   '物资',
#   '匮乏',
#   '三月不知肉味',
#   '年代',
#   '狗爷',
#   '无疑',
#   '成',
#   '孩子',
#   '眼里',
#   '神',
#   '捉到',
#   '鱼',
#   '狗爷',
#   '放在',
#   '水缸',
#   '里养',
#   '一部分',
#   '一部分',
#   '送给',
#   '乡亲们',
#   '留下',
#   '一部分',
#   '犒劳',
#   '说',
#   '犒劳',
#   '瓜分',
#   '狗爷',
#   '吃',
#   '不到',
#   '笑眯眯',
#   '看着',
#   '一年',
#   '大旱',
#   '连续',
#   '三个',
#   '滴雨未下',
#   '地里',
#   '庄稼',
#   '枯死',
#   '村民',
#   '急得',
#   '不行',
#   '狗爷',
#   '村里',
#   '壮劳力',
#   '围着',
#   '村子',
#   '走',
#   '好几圈',
#   '终于',
#   '地方',
#   '选好',
#   '点',
#   '狗爷',
#   '挖井',
#   '村里人',
#   '半信半疑',
#   '老头子',
#   '选',
#   '地方',
#   '旱得',
#   '土地',
#   '开裂',
#   '水',
#   '狗爷',
#   '不作声',
#   '兜里',
#   '拿出',
#   '烟袋',
#   '烟袋锅',
#   '轻轻地',
#   '敲打',
#   '装',
#   '点儿',
#   '烟叶',
#   '蹲',
#   '地上',
#   '抽',
#   '两口',
#   '慢悠悠',
#   '地说',
#   '狗崽子',
#   '爷',
#   '坑',
#   '害',
#   '挖',
#   '众人',
#   '见狗爷',
#   '说',
#   '嘀咕',
#   '甩开膀子',
#   '干',
#   '挖',
#   '两天',
#   '两夜',
#   '大家伙儿',
#   '筋疲力尽',
#   '不见',
#   '出水',
#   '心急',
#   '地方',
#   '选错',
#   '人群',
#   '里',
#   '嘀咕',
#   '不该',
#   '糟老头子',
#   '费',
#   '力气',
#   '歇',
#   '狗爷',
#   '远处',
#   '窝棚',
#   '走',
#   '问',
#   '挖',
#   '米',
#   '转身',
#   '回',
#   '屋子里',
#   '端',
#   '盆水',
#   '竹竿',
#   '慢慢',
#   '浇',
#   '五分钟',
#   '出水',
#   '半个',
#   '小时',
#   '接近',
#   '十米',
#   '井',
#   '快满',
#   '一半',
#   '大伙',
#   '惊叹不已',
#   '狗爷',
#   '拿个',
#   '瓜瓢',
#   '舀',
#   '一瓢',
#   '水喝',
#   '转身',
#   '走',
#   '那口',
#   '井救',
#   '村里',
#   '老少',
#   '庄稼活',
#   '十里',
#   '八村',
#   '求水',
#   '路过',
#   '狗爷',
#   '家',
#   '千恩万谢',
#   '随手',
#   '鸡蛋',
#   '几个',
#   '土豆',
#   '送',
#   '猪肉',
#   '反正',
#   '狗爷',
#   '家',
#   '那段',
#   '日子',
#   '丰盛',
#   '村里',
#   '东边',
#   '那口井',
#   '出水',
#   '没人',
#   '家里',
#   '装上',
#   '自来水',
#   '没人',
#   '想',
#   '费劲',
#   '挑水',
#   '狗爷',
#   '打井',
#   '全是',
#   '当年',
#   '部队',
#   '里',
#   '练就',
#   '本事',
#   '野外',
#   '作战',
#   '找水',
#   '大同',
#   '荔园',
#   '高佬',
#   '獒',
#   '苑',
#   '2018',
#   '17',
#   '高佬',
#   '獒',
#   '苑',
#   '听',
#   '村里',
#   '问狗爷',
#   '找个',
#   '老伴',
#   '狗爷',
#   '说',
#   '年轻',
#   '时有',
#   '喜欢',
#   '姑娘',
#   '读书',
#   '打仗',
#   '扔下',
#   '笔杆子',
#   '参军',
#   '走',
#   '姑娘',
#   '说会',
#   '狗爷',
#   '回来',
#   '当兵',
#   '两年',
#   '回家',
#   '探',
#   '亲',
#   '姑娘',
#   '走',
#   '第二年',
#   '生病',
#   '去世',
#   '高烧',
#   '退',
#   '十里',
#   '八村',
#   '大夫',
#   '办法',
#   '活活',
#   '病死',
#   '说法',
#   '撑死',
#   '重感冒',
#   '肺炎',
#   '国弱',
#   '人命',
#   '贱',
#   '自此',
#   '狗爷',
#   '回过',
#   '东北',
#   '父母',
#   '早就',
#   '走',
#   '家里',
#   '牵挂',
#   '打仗',
#   '分心',
#   '一段',
#   '狗爷',
#   '一心',
#   '求死',
#   '战场',
#   '拼命',
#   '毫发无损',
#   '说',
#   '子弹',
#   '不要命',
#   '远征军',
#   '结束',
#   '狗爷',
#   '放弃',
#   '留在',
#   '军队',
#   '机会',
#   '徒步走',
#   '回',
#   '东北',
#   '所说',
#   '整整',
#   '走',
#   '三年',
#   '当年',
#   '生活',
#   '村子',
#   '早就',
#   '荒',
#   '连人',
#   '往东',
#   '走',
#   '碰见',
#   '村子',
#   '村里人',
#   '看狗爷',
#   '可怜',
#   '一碗',
#   '稀饭',
#   '好身',
#   '板子',
#   '留在',
#   '村子',
#   '里',
#   '打零工',
#   '盖',
#   '盖房子',
#   '慢慢',
#   '村里',
#   '出钱',
#   '狗爷',
#   '盖',
#   '房子',
#   '有人',
#   '说合',
#   '亲事',
#   '但狗爷',
#   '执意',
#   '不见',
#   '说',
#   '多活',
#   '兄弟',
#   '多享',
#   '福气',
#   '想法',
#   '兄弟',
#   '用命',
#   '换来',
#   '忘',
#   '时间',
#   '长',
#   '村里人',
#   '狗爷',
#   '脾气',
#   '提及',
#   '此事',
#   '狗爷',
#   '心软',
#   '但命',
#   '硬',
#   '十里',
#   '八村',
#   '走街串巷',
#   '要饭',
#   '狗爷',
#   '点儿',
#   '几毛钱',
#   '俩',
#   '鸡蛋',
#   '村里',
#   '劝',
#   '过得',
#   '对付',
#   '干吗',
#   '还给',
#   '这时候',
#   '狗爷',
#   '说',
#   '活着',
#   '没个',
#   '难处',
#   '是从',
#   '吃糠咽菜',
#   '死人',
#   '堆里',
#   '爬出来',
#   '自然',
#   '常人',
#   '想得',
#   '通透',
#   '活得',
#   '明白',
#   '说',
#   '越来越',
#   '小孩',
#   '狗爷',
#   '弄弄',
#   '花草',
#   '房前',
#   '屋后',
#   '遇见',
#   '一群',
#   '说',
#   '那天',
#   '狗爷',
#   '园子',
#   '里',
#   '除草',
#   '外面',
#   '跑过来',
#   '几只',
#   '狗',
#   '身上',
#   '伤',
#   '狗爷',
#   '连忙',
#   '几只',
#   '狗',
#   '赶进',
#   '院子',
#   '定神一看',
#   '三只',
#   '大狗',
#   '两只',
#   '小狗',
#   '后腿',
#   '有伤',
#   '毛上',
#   '透',
#   '血迹',
#   '狗爷',
#   '心疼',
#   '找',
#   '干净',
#   '布条',
#   '草药',
#   '狗',
#   '包扎',
#   '狗',
#   '好像',
#   '听懂',
#   '话',
#   '躺',
#   '不动',
#   '跑',
#   '狗爷',
#   '包扎',
#   '狗爷',
#   '悉心照料',
#   '几条',
#   '狗',
#   '恢复',
#   '很快',
#   '平日',
#   '里',
#   '围着',
#   '狗爷',
#   '撒欢儿',
#   '狗爷',
#   '走',
#   '几条',
#   '狗',
#   '跟着',
#   '狗爷',
#   '走',
#   '还给',
#   '名字',
#   '大叫',
#   '木生',
#   '老二',
#   '虎子',
#   '老三',
#   '成子',
#   '老四',
#   '亮子',
#   '老五',
#   '刚子',
#   '问过',
#   '狗爷',
#   '为啥',
#   '狗',
#   '名字',
#   '狗爷',
#   '说',
#   '几个',
#   '名字',
#   '兄弟',
#   '名字',
#   '早',
#   '死',
#   '战场',
#   '留个',
#   '念',
#   '想',
#   '脑袋',
#   '不好',
#   '记不住',
#   '东西',
#   '投胎',
#   '陪',
#   '狗爷',
#   '平时',
#   '称',
#   '三爷',
#   '记忆',
#   '排行',
#   '老三',
#   '几个',
#   '兄弟',
#   '死',
#   '狗爷',
#   '几只',
#   '狗',
#   '村子',
#   '里安',
#   '家',
#   '村民',
#   '安全感',
#   '增加',
#   '平时',
#   '村里',
#   '进',
#   '山里',
#   '野兽',
#   '狼',
#   '野猪',
#   '村子',
#   '受过',
#   '祸害',
#   '平时',
#   '狗爷',
#   '拴着',
#   '村子',
#   '里野',
#   '谁家',
#   '扔',
#   '点儿',
#   '吃',
#   '一来二去',
#   '五只',
#   '狗',
#   '村子',
#   '熟悉',
#   '冬天',
#   '五只',
#   '狗',
#   '负责',
#   '拉着',
#   '孩子',
#   '坐',
#   '雪橇',
#   '一年',
#   '夏季',
#   '正好',
#   '赶上',
#   '几十年',
#   '不遇',
#   '大雨',
#   '村口',
#   '桥',
#   '冲毁',
#   '外面',
#   '进不来',
#   '出不去',
#   '愁得',
#   '不行',
#   '狗爷',
#   '木生',
#   '虎子',
#   '脖子',
#   '挂',
#   '绳子',
#   '打算',
#   '游',
#   '对面',
#   '绳子',
#   '交给',
#   '对面',
#   '物资',
#   '东西',
#   '能运',
#   '面对',
#   '湍急',
#   '水流',
#   '过低',
#   '温度',
#   '宽阔',
#   '水面',
#   '狗爷',
#   '担心',
#   '村里',
#   '老老少少',
#   '狗爷',
#   '没得',
#   '选择',
#   '木生',
#   '虎子',
#   '跳入',
#   '水中',
#   '奋力',
#   '对面',
#   '游',
#   '几次',
#   '差点儿',
#   '水',
#   '冲走',
#   '还好',
#   '几块',
#   '石头',
#   '跳上去',
#   '歇歇',
#   '前前后后',
#   '休息',
#   '三次',
#   '总算',
#   '游到',
#   '对面',
#   '绑',
#   '绳子',
#   '狗爷',
#   '站',
#   '河',
#   '对岸',
#   '喊',
#   '好样',
#   '木生',
#   '好样',
#   '虎子',
#   '丢脸',
#   '狗爷',
#   '想起',
#   '峥嵘岁月',
#   '半个',
#   '桥',
#   '终于',
#   '修好',
#   '狗爷',
#   '对面',
#   '接木',
#   '生',
#   '虎子',
#   '回家',
#   '对岸',
#   '半个',
#   '倒',
#   '遭罪',
#   '先前',
#   '胖',
#   '狗爷',
#   '两条',
#   '狗',
#   '欢叫',
#   '跑',
#   '上前',
#   '使劲',
#   '摇尾巴',
#   '狗爷',
#   '拍',
#   '木生',
#   '虎子',
#   '脑袋',
#   '说',
#   '俩',
#   '村里',
#   '立功',
#   '走',
#   '回家',
#   '吃',
#   '肉',
#   '狗爷',
#   '特地去',
#   '集市',
#   '里',
#   '买',
#   '两斤',
#   '猪肉',
#   '木生',
#   '虎子',
#   '吃',
#   '肉香',
#   '飘',
#   '远',
#   '孩子',
#   '闻着',
#   '味儿',
#   '跑',
#   '狗爷',
#   '定会',
#   '分',
#   '哭闹',
#   '说狗爷',
#   '糟蹋',
#   '东西',
#   '狗',
#   '吃',
#   '吃',
#   '狗爷',
#   '无奈',
#   '地说',
#   '几条',
#   '狗',
#   '命',
#   '上次',
#   '渡河',
#   '木生',
#   '虎子',
#   '拼了命',
#   '村子',
#   '说不上',
#   '被困',
#   '多久',
#   '吃',
#   '点儿',
#   '肉',
#   '不行',
#   '说不出',
#   ...],
#  ['相册',
#   '中',
#   '放鸡岛',
#   '照片',
#   '景色',
#   '历历在目',
#   '景色',
#   '记录下来',
#   '宣传',
#   '宣传',
#   '家乡',
#   '景色',
#   '噢',
#   '口误',
#   '邻县',
#   '失礼',
#   '失礼',
#   '那要',
#   '去年',
#   '国庆节',
#   '说起',
#   '国庆',
#   '星期',
#   '法定',
#   '假日',
#   '家里',
#   '家',
#   '更是',
#   '几个',
#   '萝卜头',
#   '回齐',
#   '一年',
#   '新年',
#   '聚齐',
#   '国庆',
#   '在家',
#   '面对',
#   '生活',
#   '二十多年',
#   '生活',
#   '环境',
#   '没什么',
#   '新奇',
#   '可言',
#   '吃饭',
#   '唠唠',
#   '家常',
#   '老姐',
#   '提议',
#   '说',
#   '周边',
#   '赞成',
#   '老爸',
#   '老妈',
#   '意见',
#   '两',
#   '老姐',
#   '找到',
#   '放鸡岛',
#   '一听',
#   '不想',
#   '脑海',
#   '里',
#   '浮现',
#   '乡下',
#   '地方',
#   '放鸡岛',
#   '鸡',
#   '奇特',
#   '地方',
#   '种类',
#   '鸡',
#   '老姐',
#   '说',
#   '游记',
#   '很漂亮',
#   '景色',
#   '本来',
#   '想着',
#   '不去',
#   '家里人',
#   '呆',
#   '在家',
#   '没意思',
#   '自驾游',
#   '出行',
#   '咯',
#   '去年',
#   '照片',
#   '好看',
#   '删掉',
#   '留下来',
#   '好看',
#   '开',
#   '小时',
#   '车到',
#   '旅游景点',
#   '放鸡岛',
#   '岛',
#   '自然',
#   '海',
#   '排队',
#   '坐船',
#   '买票',
#   '好多',
#   '隔壁',
#   '县',
#   '远道而来',
#   '心想',
#   '好看',
#   '疑问',
#   '船',
#   '一个多',
#   '小时',
#   '目的地',
#   '船',
#   '景点',
#   '分布图',
#   '卖',
#   '泳衣',
#   '潜水',
#   '物具',
#   '分布图',
#   '五六个',
#   '景点',
#   '两条路线',
#   '第一',
#   '徒步',
#   '旅游',
#   '风景',
#   '车',
#   '自然',
#   '搭车',
#   '国庆节',
#   '室外',
#   '30',
#   '多度',
#   '高温',
#   '想想',
#   '走路',
#   '人多',
#   '坐车',
#   '排队',
#   '温高人',
#   '心情',
#   '烦躁',
#   '第一个',
#   '景点',
#   '时',
#   '真的',
#   '出乎意料',
#   '很漂亮',
#   '放鸡岛',
#   '海上',
#   '度假',
#   '公园',
#   '这是',
#   '半山腰',
#   '景点',
#   '排队',
#   '坐车',
#   '地方',
#   '以小',
#   '动物',
#   '样式',
#   '遮风挡雨',
#   '地方',
#   '大自然',
#   '味道',
#   '地方',
#   '体现',
#   '景色',
#   '海边',
#   '亮点',
#   '海边',
#   '天空',
#   '潜水',
#   '物具',
#   '海水',
#   '玩玩',
#   '父母',
#   '出门在外',
#   '事',
#   '老爸',
#   '不让',
#   '说',
#   '海边',
#   '长大',
#   '潜',
#   '水',
#   '说',
#   '太',
#   '好像',
#   '粑',
#   '粑',
#   '麻麻',
#   '做',
#   '冒险',
#   '事',
#   '想',
#   '体会',
#   '生活',
#   '世上',
#   '观念',
#   '不停',
#   '变化',
#   '人生',
#   '走一遭',
#   '规规矩矩',
#   '封建',
#   '稳定',
#   '思想',
#   '早就',
#   '过滤',
#   '过滤',
#   '奈何',
#   '奈何',
#   '所处',
#   '环境',
#   '年龄',
#   '掣肘',
#   '更是',
#   '担忧',
#   '更想',
#   '父母',
#   '明白',
#   '担忧',
#   '希望',
#   '父母',
#   '成',
#   '背后',
#   '强大',
#   '支撑',
#   '想起',
#   '大学毕业',
#   '时',
#   '伙伴',
#   '说',
#   '说',
#   '毕业',
#   '工作',
#   '身边',
#   '做',
#   '事',
#   '支持',
#   '眼泪',
#   '直流',
#   '所知',
#   '毕业',
#   '工作',
#   '选择',
#   '不知',
#   '前路',
#   '艰险',
#   '背后',
#   '一股',
#   '力量',
#   '更是',
#   '向前走',
#   '无畏',
#   '无惧',
#   '话题',
#   '扯远',
#   '放鸡岛',
#   '海上',
#   '度假',
#   '公园',
#   '找到',
#   '一张',
#   '人景照',
#   '去年',
#   '挺',
#   '瘦',
#   '放鸡岛',
#   '生态旅游',
#   '国际',
#   '度假区',
#   '酒店',
#   '这是',
#   '半山腰',
#   '海景',
#   '天气',
#   '热',
#   '天空',
#   '蔚蓝',
#   '白云',
#   '稀少',
#   '挡不住',
#   '紫外线',
#   '汗流',
#   '直',
#   '四面',
#   '海边',
#   '海边',
#   '吹过来',
#   '风',
#   '凉爽',
#   '余',
#   '夹带',
#   '咸淡',
#   '味道',
#   '夏日',
#   '味道',
#   '逛',
#   '完后',
#   '排队',
#   '上车',
#   '一站',
#   '山顶',
#   '山顶',
#   '标志',
#   '八爪',
#   '鱼',
#   '石头',
#   '砌成',
#   '噢',
#   '旁边',
#   '观音像',
#   '高',
#   '麻麻',
#   '自然',
#   '拜',
#   '一拜',
#   '保佑',
#   '平安',
#   '健康',
#   '赚大钱',
#   '时间',
#   '中午',
#   '太阳',
#   '正猛',
#   '一个四岁',
#   '布丁',
#   '跑来跑去',
#   '满头',
#   '汗',
#   '老爸',
#   '布丁',
#   '乘凉',
#   '老姐',
#   '逛逛',
#   '还好',
#   '老姐',
#   '逛',
#   '景色',
#   '超级',
#   '漂亮',
#   '仙境',
#   '偷拍',
#   '一张',
#   '手机',
#   '弱弱',
#   '拍',
#   '两',
#   '张全景',
#   '一张',
#   '合照',
#   '这片',
#   '海',
#   '草原',
#   '真的',
#   '舒适',
#   '透气',
#   '太阳',
#   '猛',
#   '看过',
#   '游记',
#   '人会',
#   '说',
#   '太阳',
#   '猛',
#   '景色',
#   '美',
#   '值得',
#   '一趟',
#   '太阳',
#   '值得',
#   '晒',
#   '晒太阳',
#   '晒',
#   '龇牙咧嘴',
#   '笑容',
#   '勉强',
#   '深圳',
#   '鹿嘴',
#   '山庄',
#   '很漂亮',
#   '可鹿',
#   '嘴',
#   '山庄',
#   '奇观',
#   '壮观',
#   '恬静',
#   '平静',
#   '清澈',
#   '海面',
#   '潜水',
#   '不错',
#   '太阳',
#   '晒',
#   '完',
#   '涂',
#   '身上',
#   '防晒霜',
#   '休息',
#   '喝水',
#   '补',
#   '防晒',
#   '杯水',
#   '太阳',
#   '底下',
#   '显得',
#   '解渴',
#   '小道消息',
#   '透露',
#   '杯中',
#   '杯',
#   '柠乐',
#   '20',
#   '元',
#   '休息',
#   '完下',
#   '一站',
#   '拜佛',
#   '祈福',
#   '爸妈',
#   '带有',
#   '疲意',
#   '人多',
#   '站',
#   '坐到',
#   '一站',
#   '这站',
#   '水上',
#   '游乐园',
#   '吃',
#   '午饭',
#   '地方',
#   '下午',
#   '15',
#   '点多',
#   '吃完饭',
#   '布丁',
#   '想',
#   '玩水',
#   '天气',
#   '太热',
#   '太阳',
#   '猛',
#   '衣服',
#   '没带',
#   '只能',
#   '圈',
#   '身边',
#   '爸妈',
#   '5D',
#   '影画',
#   '两老特',
#   '新奇',
#   '开心',
#   '想到',
#   '三维空间',
#   '厦门',
#   '玩过',
#   '惊人',
#   '震感',
#   '想想',
#   '心有',
#   '触动',
#   '扯远',
#   '下山',
#   '下山',
#   '路',
#   '停歇',
#   '偷偷',
#   '拍',
#   '几张',
#   '漂亮',
#   '说',
#   '真的',
#   '很美下',
#   '山到',
#   '凉亭',
#   '再歇会',
#   '观',
#   '海景',
#   '太阳',
#   '西斜',
#   '打着',
#   '伞',
#   '放鸡岛',
#   '生态旅游',
#   '国际',
#   '度假区',
#   '酒店'],
#  ['28',
#   '傍晚',
#   '孩子',
#   '学校',
#   '放假',
#   '一家',
#   '三口',
#   '整理行装',
#   '杭州',
#   '出发',
#   '为期',
#   '18',
#   '天',
#   '总',
#   '行程',
#   '5000',
#   '公里',
#   '南国',
#   '之旅',
#   '鹰潭',
#   '龙虎山',
#   '1.29',
#   '1.30',
#   '老公',
#   '开车',
#   '坐在',
#   '副驾驶',
#   '一路',
#   '搜',
#   '攻略',
#   '搜',
#   '酒店',
#   '29',
#   '下午',
#   '到达',
#   '江西',
#   '鹰潭',
#   '龙虎山',
#   '入住',
#   '仙',
#   '水岩',
#   '景区',
#   '门口',
#   '龙虎',
#   '客栈',
#   '龙虎',
#   '客栈',
#   '规模',
#   '不小',
#   '开',
#   '二十年',
#   '房间',
#   '顶楼',
#   '房顶',
#   '玻璃窗',
#   '打开',
#   '夜观',
#   '星星',
#   '孩子',
#   '兴奋',
#   '一阵子',
#   '饥肠辘辘',
#   '晒',
#   '午后',
#   '阳光',
#   '老板',
#   '家',
#   '餐厅',
#   '吃',
#   '特色美食',
#   '板栗',
#   '烧鸡',
#   '味道',
#   '不错',
#   '30',
#   '上午',
#   '花',
#   '200',
#   '元',
#   '钱',
#   '客栈',
#   '老板',
#   '开车',
#   '龙虎山',
#   '走马观花',
#   '游',
#   '一圈',
#   '龙虎山',
#   '道教',
#   '发祥地',
#   '丹霞地貌',
#   '代表',
#   '象鼻山',
#   '天师',
#   '庙',
#   '无蚊村',
#   '仙',
#   '水岩',
#   '升棺',
#   '表演',
#   '说实话',
#   '景点',
#   '走',
#   '栈道',
#   '鸟瞰',
#   '龙虎山',
#   '全景',
#   '效果',
#   '无蚊村',
#   '蚊子',
#   '奥秘',
#   '香樟',
#   '桉树',
#   '甚',
#   '好奇',
#   '龙虎山',
#   '陡峭',
#   '挺拔',
#   '岩壁',
#   '光滑',
#   '高不可攀',
#   '岩下',
#   '便是',
#   '泸溪',
#   '河',
#   '崖壁',
#   '遍布',
#   '一百多',
#   '座',
#   '两千五百多年',
#   '古越',
#   '民族',
#   '悬棺',
#   '升棺',
#   '千古',
#   '之谜',
#   '升棺',
#   '表演',
#   '今人',
#   '模拟',
#   '场景',
#   '中午',
#   '12',
#   '点',
#   '下午',
#   '点',
#   '点',
#   '各有',
#   '一场',
#   '演员',
#   '悬崖',
#   '纵横',
#   '飞跃',
#   '如履平地',
#   '令人惊叹',
#   '所用',
#   '滑轮组',
#   '悬崖',
#   '滑轮',
#   '位置',
#   '棺木',
#   '准确',
#   '送入',
#   '崖洞',
#   '技术',
#   '古人',
#   '困难',
#   '龙虎山',
#   '龙虎山',
#   '无蚊村',
#   '龙虎山',
#   '悬棺',
#   '韶关',
#   '丹霞山',
#   '1.31',
#   '2.1',
#   '丹霞地貌',
#   '典型',
#   '代表',
#   '莫过于',
#   '韶关',
#   '丹霞山',
#   '丹霞地貌',
#   '丹霞山',
#   '命名',
#   '第二站',
#   '自然',
#   '丹霞山',
#   '31',
#   '中午',
#   '到达',
#   '丹霞山',
#   '地质公园',
#   '入住',
#   '维也纳',
#   '酒店',
#   '景区',
#   '门口',
#   '小小的',
#   '惊喜',
#   '前台',
#   '接待',
#   '热情周到',
#   '房间',
#   '不算',
#   '很大',
#   '装修',
#   '新',
#   '干净',
#   '精致',
#   '设计',
#   '感',
#   '中午',
#   '景区',
#   '门口',
#   '菊姐',
#   '酒楼',
#   '用餐',
#   '点',
#   '招牌菜',
#   '香茅',
#   '鸭',
#   '清蒸',
#   '河鱼',
#   '一品',
#   '茄子',
#   '味道',
#   '实在',
#   '吃不完',
#   '老板娘',
#   '商量',
#   '帮忙',
#   '存好',
#   '香茅',
#   '鸭',
#   '晚饭',
#   '吃',
#   '老板娘',
#   '热情',
#   '答应',
#   '下午',
#   '景区',
#   '景区',
#   '工作人员',
#   '热情',
#   '不厌其烦',
#   '介绍',
#   '买票',
#   '一同',
#   '观光车',
#   '送到',
#   '阳',
#   '元山',
#   '留下',
#   '联系电话',
#   '阳',
#   '元山',
#   '不高',
#   '花',
#   '十几分钟',
#   '浏览',
#   '阳元石',
#   '乘坐',
#   '观光车',
#   '当天',
#   '一班',
#   '竹筏',
#   '游览',
#   '丹霞山',
#   '其时',
#   '夕阳西下',
#   '彩霞满天',
#   '锦江',
#   '波光粼粼',
#   '微风',
#   '徐徐',
#   '令人',
#   '神清气爽',
#   '竹筏',
#   '观看',
#   '丹霞山',
#   '轻松',
#   '高效',
#   '偷懒',
#   '成功',
#   '窃喜',
#   '第二天',
#   '故伎重演',
#   '上午',
#   '游水',
#   '丹霞',
#   '景点',
#   '单独',
#   '买票',
#   '游览',
#   '锦江',
#   '上游',
#   '昨天',
#   '竹筏',
#   '游',
#   '下游',
#   '群象',
#   '过江',
#   '观音',
#   '送子',
#   '金龟',
#   '朝圣',
#   '指琴',
#   '魔',
#   '造型',
#   '栩栩如生',
#   '船上',
#   '导游',
#   '热情',
#   '讲解',
#   '听得',
#   '趣味',
#   '游船',
#   '喜头村',
#   '靠岸',
#   '供',
#   '游客',
#   '自由',
#   '上岸',
#   '游玩',
#   '岛上',
#   '风景',
#   '生态',
#   '茶园',
#   '高处',
#   '观',
#   '锦江',
#   '风景',
#   '绝佳',
#   '磨磨蹭蹭',
#   '下午',
#   '三点',
#   '坐',
#   '索道',
#   '长老',
#   '峰',
#   '上山',
#   '走',
#   '二十分钟',
#   '舵石',
#   '鸟瞰',
#   '丹霞山',
#   '漂亮',
#   '锦江',
#   '确如',
#   '一根',
#   '锦带',
#   '点缀',
#   '观景台',
#   '建在',
#   '绝壁',
#   '脚下',
#   '万丈深渊',
#   '真的',
#   '战战兢兢',
#   '拍',
#   '照片',
#   '赶紧',
#   '溜之大吉',
#   '韶音',
#   '亭',
#   '对面',
#   '僧帽',
#   '峰',
#   '景观',
#   '不错',
#   '开阔',
#   '千峰万壑',
#   '尽收眼底',
#   '小朋友',
#   '兴冲冲',
#   '打开',
#   '无人机',
#   '过瘾',
#   '赶不上',
#   '索道',
#   '末班车',
#   '景点',
#   '只好',
#   '放弃',
#   '丹霞山',
#   '丹霞山',
#   '丹霞山',
#   '丹霞山',
#   '丹霞山',
#   '丹霞山',
#   '下山',
#   '彩霞满天',
#   '字',
#   '美',
#   '热带',
#   '农业',
#   '公园',
#   '2.2',
#   '2.3',
#   '告别',
#   '丹霞山',
#   '出发',
#   '高速',
#   '惊鸿一瞥',
#   '路边',
#   '有个',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '牌子',
#   '临时',
#   '起意',
#   '一转',
#   '车头',
#   '高速',
#   '没想到',
#   '收获',
#   '意外',
#   '惊喜',
#   '兜兜',
#   '转转',
#   '找到',
#   '公园',
#   '门口',
#   '正欲',
#   '买票',
#   '参观',
#   '热带作物',
#   '热情',
#   '售票员',
#   '告诉',
#   '公园',
#   '里',
#   '绿',
#   '湖湾',
#   '酒店',
#   '入住',
#   '免',
#   '公园',
#   '门票',
#   '晚上',
#   '灯光',
#   '秀',
#   '说',
#   '住',
#   '公园',
#   '门口',
#   '水果店',
#   '想',
#   '买点',
#   '水果',
#   '解解馋',
#   '奈何',
#   '店主',
#   '零卖',
#   '看着',
#   '一大',
#   '袋',
#   '一大',
#   '箱',
#   '番石榴',
#   '为难',
#   '旁边',
#   '买',
#   '水果',
#   '小伙',
#   '热情',
#   '地请',
#   '吃',
#   '刚买',
#   '再三',
#   '推辞',
#   '机会',
#   '第一次',
#   '番石榴',
#   '绿',
#   '湖湾',
#   '酒店',
#   '招待所',
#   '感觉',
#   '干净',
#   '宽敞',
#   '房间',
#   '阳台',
#   '舒服',
#   '悠哉悠哉',
#   '开启',
#   '疗养',
#   '模式',
#   '酒店',
#   '提供',
#   '山地车',
#   '免费',
#   '出租',
#   '本想',
#   '一家',
#   '三口',
#   '骑出去',
#   '溜达',
#   '一圈',
#   '无奈',
#   '车子',
#   '太高',
#   '三个',
#   '倒',
#   '两个',
#   '骑不上',
#   '只好',
#   '放弃',
#   '5000',
#   '亩',
#   '农业',
#   '公园',
#   '真够',
#   '品种',
#   '热带',
#   '水果',
#   '园区',
#   '三个',
#   '犹如',
#   '刘姥姥',
#   '进',
#   '大观园',
#   '第一次',
#   '菠萝蜜',
#   '长',
#   '树上',
#   '第一次',
#   '旅人',
#   '蕉',
#   '狐尾',
#   '椰子',
#   '锦屏',
#   '藤',
#   '说不出',
#   '惊奇',
#   '兴奋',
#   '小朋友',
#   '演示',
#   '无人机',
#   '锦屏',
#   '藤下',
#   '超低空',
#   '飞行',
#   '拍摄',
#   '整理',
#   '上传',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '广垦',
#   '热带',
#   '农业',
#   '公园',
#   '三亚',
#   '天涯海角',
#   '2.5',
#   '一路',
#   '向南',
#   '渡过',
#   '琼州海峡',
#   '三亚',
#   '吃',
#   '年夜饭',
#   '那首',
#   '著名',
#   '歌',
#   '感觉',
#   '三亚',
#   '天涯海角',
#   '打卡',
#   '大年初一',
#   '出发',
#   '三亚',
#   '阳光',
#   '耀眼',
#   '万里无云',
#   '阴凉',
#   '地方',
#   '清风徐来',
#   '惬意',
#   '进门',
#   '见到',
#   '沙滩',
#   '第一眼',
#   '天涯海角',
#   '迫不及待',
#   '拍照',
#   '发现',
#   '粗砂',
#   '中',
#   '夹杂着',
#   '无数',
#   '贝壳',
#   '碎屑',
#   '脚湿',
#   '找',
#   '不到',
#   '地儿',
#   '冲洗',
#   '一瘸一拐',
#   '甚',
#   '狼狈',
#   '前车之鉴',
#   '南天一',
#   '柱',
#   '矜持',
#   '远远',
#   '一眼',
#   '作罢',
#   '往前走',
#   '参观',
#   '圣旨',
#   '博物馆',
#   '天涯',
#   '石',
#   '海角',
#   '石',
#   '发现',
#   '两处',
#   '岩石',
#   '高大',
#   '壮观',
#   '实在',
#   '应',
#   '错过',
#   '颠颠',
#   '跑',
#   '跟前',
#   '沙子',
#   '细腻',
#   '受罪',
#   '海滩',
#   '边有',
#   '乘坐',
#   '快艇',
#   '项目',
#   '工作人员',
#   '陪同',
#   '一人',
#   '收费',
#   '160',
#   '公里',
#   '胆子',
#   '没敢',
#   '小朋友',
#   '体验',
#   '一把',
#   '蓝天',
#   '碧海',
#   '乘风破浪',
#   '不快',
#   '天涯海角',
#   '天涯海角',
#   '天涯海角',
#   '天涯海角',
#   '东方',
#   '2.6',
#   '2.7',
#   '告别',
#   '三亚',
#   '转向',
#   '西海岸',
#   '东方',
#   '市',
#   '先',
#   '探访',
#   '江边',
#   '乡白查',
#   '村',
#   '黎族',
#   '传统',
#   '古村',
#   '晚上',
#   '赶到',
#   '东方',
#   '市',
#   '天黑',
#   '地图',
#   '搜白查',
#   '村',
#   '酒店',
#   '暂时',
#   '乐东',
#   '镇上',
#   '住',
#   '酒店',
#   '条件',
#   '享用',
#   '五指山',
#   '黄牛',
#   '煲',
#   '斋菜',
#   '煲',
#   '两道',
#   '海南',
#   '名菜',
#   '味道',
#   '不错',
#   '服务员',
#   '淳朴',
#   '饿',
#   '急',
#   '点到',
#   '第三个',
#   '菜',
#   '提醒',
#   '份量',
#   '北国',
#   '风范',
#   '第二个',
#   '菜',
#   '上午',
#   '前往',
#   '白查',
#   '村',
#   '白查',
#   '村',
#   '八十',
#   '来间',
#   '屋子',
#   '茅草',
#   '顶',
#   '泥巴',
#   '拌',
#   '稻草',
#   '墙',
#   '风味',
#   '拙朴',
#   '白查',
#   '村',
#   '现已',
#   '无人居住',
#   '两个',
#   '阿姨',
#   '卖',
#   '椰子',
#   '10',
#   '块',
#   '小朋友',
#   '热得',
#   '够呛',
#   '买',
#   '解渴',
#   '白查',
#   '村',
#   '一路',
#   '闲逛',
#   '大广坝',
#   '挂满',
#   '枝头',
#   '芒果',
#   '灿若云霞',
#   '木棉花',
#   '田里',
#   '发呆',
#   '忘',
#   '打滚',
#   '肥猪',
#   '路上',
#   '旁若无人',
#   '闲逛',
#   '牛群',
#   '羊群',
#   '一切都是',
#   '富有',
#   '生气',
#   '一路',
#   '前行',
#   '远远',
#   '俄贤岭',
#   '巍峨',
#   '几道',
#   '山脉',
#   '犹如',
#   '龙脊',
#   '搜',
#   '介绍',
#   '好像',
#   '风景',
#   '挺',
#   '想',
#   '路刚',
#   '修好',
#   '狭窄',
#   '空无一人',
#   '连绵不断',
#   '下坡',
#   '像是',
#   '过山车',
#   '杭州',
#   '杨公堤',
#   '小朋友',
#   '坐得',
#   '过瘾',
#   '路上',
#   '见到',
#   '黎族',
#   '新村',
#   '达',
#   '俄村',
#   '统一规划',
#   '黄色',
#   '墙壁',
#   '饰以',
#   '青砖',
#   '红色',
#   '花纹',
#   '好容易',
#   '俄贤岭',
#   '山脚',
#   '发现',
#   '车窗',
#   '锁',
#   '自然',
#   '爬山',
#   '只好',
#   '灰溜溜',
#   '地走了',
#   '时值',
#   '春节',
#   '好多',
#   '饭馆',
#   '营业',
#   '夕阳西下',
#   '路边',
#   '一家',
#   '黎族',
#   '饭馆',
#   '吃',
#   '饭',
#   '饭馆',
#   '门口',
#   '火红',
#   '三角梅',
#   '长成',
#   '美的',
#   '拱门',
#   '地上',
#   '放着',
#   '一大堆',
#   '铁皮',
#   '石斛',
#   '树上',
#   '出名',
#   '兰花',
#   '旁边',
#   '密密麻麻',
#   '结满',
#   '果实',
#   '木瓜树',
#   '南国',
#   '一切都是',
#   '新鲜',
#   '东方',
#   '市区',
#   '住',
#   '一夜',
#   '距离',
#   '海滩',
#   '百米',
#   '之遥',
#   '上午',
#   '海滩',
#   '海鲜',
#   '码头',
#   '逛逛',
#   '买',
#   '海鲜',
#   '加工',
#   '车上',
#   '享用',
#   '发现',
#   '新大陆',
#   '烤乳猪',
#   '特别',
#   '好吃',
#   '皮脆',
#   '肉',
#   '嫩',
#   '骨',
#   '酥',
#   '买',
#   '两斤',
#   '嫌',
#   '过瘾',
#   '回去',
#   '买',
#   '半只',
#   '前一天',
#   '田里',
#   '路上',
#   '散步',
#   '肥猪',
#   '理所当然',
#   '联想',
#   '好吃',
#   '大广坝',
#   '水库',
#   '旅游区',
#   '东方',
#   '市',
#   '海鲜',
#   '码头',
#   '儋州',
#   '石花',
#   '水洞',
#   '2.8',
#   '东方',
#   '市',
#   '出发',
#   '前往',
#   '儋州',
#   '石花',
#   '水洞',
#   '原先',
#   '搜到',
#   '雅星',
#   '镇',
#   '八一',
#   '迎宾馆',
#   '下单',
#   '客满',
#   '入住',
#   '只得',
#   '找',
#   '另一家',
#   '号称',
#   '新装修',
#   '逸景',
#   '酒店',
#   '这趟',
#   '旅行',
#   '糟糕',
#   '体验',
#   '大堂',
#   '电梯',
#   '满地',
#   '垃圾',
#   '脏得',
#   '无与伦比',
#   '房间',
#   '打扫',
#   '奇葩',
#   '抽水马桶',
#   '垫圈',
#   '勉强',
#   '住',
#   '一夜',
#   '落荒而逃',
#   '号',
#   '上午',
#   '前往',
#   '石花',
#   '水洞',
#   '石花',
#   '水洞',
#   '我国',
#   '开发',
#   '纬度',
#   '最低',
#   '天然',
#   '溶洞',
#   '金华',
#   '双龙洞',
#   '喀斯特地貌',
#   '石花',
#   '水洞',
#   '长',
#   '5000',
#   '米',
#   '开放',
#   '900',
#   '米',
#   '旱洞',
#   '水洞',
#   '长',
#   '550',
#   '米',
#   '350',
#   '米',
#   '曲折',
#   '蜿蜒',
#   '游览',
#   '一个多',
#   ...],
#  ['题记',
#   '走过',
#   '二年',
#   '专职',
#   '乡',
#   '旅',
#   '路途',
#   '高佬',
#   '悄悄的',
#   '告诉',
#   '活下去',
#   '真的',
#   '王道',
#   '2019',
#   '28',
#   '廿三',
#   '细数',
#   '一月',
#   '行程',
#   '小年',
#   '美言',
#   '猪事',
#   '顺利',
#   '一月份',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11727258',
#   'html2019',
#   '28',
#   '投保',
#   '百万',
#   '红色',
#   '福特车',
#   '细数',
#   '二月',
#   '激情',
#   '乡',
#   '旅行',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11976034',
#   'html2019',
#   '30',
#   '阳春',
#   '三月',
#   '天',
#   '高佬',
#   '乡',
#   '旅路',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '12205534',
#   'html',
#   '众多',
#   '社会名流',
#   '出席',
#   '晚会',
#   '鬓发',
#   '斑白',
#   '巴基斯坦',
#   '影坛',
#   '老将',
#   '雷利',
#   '拄着',
#   '柺',
#   '杖',
#   '蹒跚',
#   '走上台',
#   '就座',
#   '主持人',
#   '开口',
#   '问道',
#   '医生',
#   '常去',
#   '病人',
#   '常去',
#   '医生',
#   '医生',
#   '活下去',
#   '台下',
#   '爆发',
#   '热烈',
#   '掌声',
#   '主持人',
#   '问',
#   '请教',
#   '医院',
#   '药师',
#   '药物',
#   '服用',
#   '方法',
#   '我常向',
#   '药师',
#   '请教',
#   '药物',
#   '服用',
#   '方法',
#   '药师',
#   '赚钱',
#   '活下去',
#   '台下',
#   '一阵',
#   '掌声',
#   '吃药',
#   '我常',
#   '药',
#   '扔掉',
#   '活下去',
#   '台下',
#   '哄堂大笑',
#   '主持人',
#   '说',
#   '谢谢您',
#   '接受',
#   '采访',
#   '老人',
#   '答道',
#   '客气',
#   '活下去',
#   '台下',
#   '掌声',
#   '欢呼声',
#   '经久不息',
#   '笑话',
#   '曾排',
#   '世界',
#   '第一',
#   '笑',
#   '活下去',
#   '高佬',
#   '顺祝',
#   '蜂友们',
#   '生活',
#   '愉快',
#   '开心',
#   '生活',
#   '2019',
#   '汇集',
#   '专家',
#   '座谈',
#   '精品',
#   '新理念',
#   '创建',
#   '全域',
#   '旅游',
#   '示范区',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11979542',
#   'html2019',
#   '北部湾',
#   '牵手',
#   '文创',
#   '街',
#   '推介',
#   '海口',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11983206',
#   'html3',
#   '2019',
#   '南越',
#   '印象',
#   '袂',
#   '花顿',
#   '标年例',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11987578',
#   'html2019',
#   '大同',
#   '人荟晟源',
#   '阜',
#   '康庄',
#   '全猪',
#   '宴',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11994938',
#   'html3',
#   '2019',
#   '大同世界',
#   '家',
#   '味道',
#   '古郡',
#   '水城',
#   '水上',
#   '设备',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11998218',
#   'html2019',
#   '化州',
#   '仔',
#   '浪漫',
#   '木屋',
#   '风情园',
#   '沙院',
#   '咸田',
#   '咸水',
#   '温泉水',
#   '东芥',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '11997594',
#   'html3',
#   '2019',
#   '荔枝',
#   '湾',
#   '花开',
#   '招蜂',
#   '露天矿',
#   '馆藏',
#   '引客',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '12003562',
#   'html3',
#   '2019',
#   '大同',
#   '六六',
#   '茶',
#   '饮',
#   '共庆',
#   '高佬',
#   '生日',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '12017834',
#   'html3',
#   '2019',
#   '惊蛰',
#   '游园',
#   '孵化',
#   '创新',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '12023542',
#   'html3',
#   '2019',
#   '平乐',
#   '塘雨',
#   '中食',
#   '年',
#   '例八坊',
#   '村',
#   '夜里',
#   '拍',
#   '民宿',
#   'http',
#   'www',
#   'mafengwo',
#   'cn',
#   'i',
#   '12030202',
#   'html'],
#  ['前序',
#   '平常',
#   '周末',
#   '三家',
#   '溜',
#   '娃',
#   '三月',
#   '清明',
#   '长假',
#   '2019',
#   '年',
#   '日至',
#   '不想',
#   '辜负',
#   '假期',
#   '三家',
#   '商量',
#   '旅游',
#   '溜',
#   '娃',
#   '原',
#   '计划',
#   '路线',
#   '杭州',
#   '乌镇',
#   '苏州',
#   '机票',
#   '涨价',
#   '太高',
#   '火车票',
#   '刷票',
#   '长时间',
#   '刷到',
#   '临近',
#   '假期',
#   '改了',
#   '路线',
#   '自驾游',
#   '柳州',
#   '浪漫',
#   '海岸',
#   '阳江市',
#   '海陵',
#   '岛',
#   '柳州',
#   '浪漫',
#   '海岸',
#   '飞猪',
#   '上订',
#   '温德姆',
#   '酒店',
#   '豪庭房',
#   '三间',
#   '738',
#   '元',
#   '间',
#   '三间',
#   '2000',
#   '多满减',
#   '优惠',
#   '200',
#   '元',
#   '套餐',
#   '含',
#   '门票',
#   '晚餐',
#   '早餐',
#   '房型',
#   '庭院',
#   '一楼',
#   '孩子',
#   '庭院',
#   '玩',
#   '泥巴',
#   '石子',
#   '事实证明',
#   '孩子',
#   '确实',
#   '爱玩',
#   '庭院',
#   '石子',
#   '浪漫',
#   '海岸',
#   '温德姆',
#   '酒店',
#   '浪漫',
#   '海岸',
#   '温德姆',
#   '酒店',
#   '鹿鹿',
#   '早上',
#   '起床',
#   '跑',
#   '庭院',
#   '里',
#   '小桶',
#   '铲子',
#   '挖沙',
#   '工具',
#   '玩',
#   '庭院',
#   '小石子',
#   '萌萌',
#   '晚上',
#   '回来',
#   '玩',
#   '游泳',
#   '回来',
#   '退房',
#   '三个',
#   '小孩子',
#   '玩',
#   '一轮',
#   '浪漫',
#   '海岸',
#   '温德姆',
#   '酒店',
#   '浪漫',
#   '海岸',
#   '温德姆',
#   '酒店',
#   '酒店',
#   '晚餐',
#   '选',
#   '西餐',
#   '望海',
#   '餐厅',
#   '牛排',
#   '实在',
#   '好吃',
#   '羊排',
#   '好点',
#   '海鲜',
#   '甜点',
#   '同志',
#   '认可',
#   '早餐',
#   '好吃',
#   '东西',
#   '认可',
#   '早餐',
#   '儿童',
#   '游乐',
#   '地方',
#   '孩子',
#   '放在',
#   '大人',
#   '好吃',
#   '东西',
#   '浪漫',
#   '海岸',
#   '沙子',
#   '海水',
#   '不行',
#   '太黑',
#   '浪漫',
#   '海岸',
#   '国际',
#   '旅游',
#   '度假区',
#   '浪漫',
#   '海岸',
#   '国际',
#   '旅游',
#   '度假区',
#   '浪漫',
#   '海岸',
#   '国际',
#   '旅游',
#   '度假区',
#   '浪漫',
#   '海岸',
#   '国际',
#   '旅游',
#   '度假区',
#   '浪漫',
#   '海岸',
#   '国际',
#   '旅游',
#   '度假区',
#   '傍晚',
#   '风太大',
#   '海风',
#   '吹',
#   '满脸',
#   '沙子',
#   '冷',
#   '回',
#   '酒店',
#   '休息',
#   '洗澡',
#   '天',
#   '没圈',
#   '黑',
#   '小朋友',
#   '走走',
#   '逛逛',
#   '逛',
#   '地方',
#   '挺',
#   '第二天',
#   '早上',
#   '起床',
#   '阳光',
#   '意外',
#   '明媚',
#   '不错',
#   '天气',
#   '睡',
#   '九点',
#   '洗漱',
#   '望海',
#   '餐厅',
#   '吃',
#   '自助',
#   '早餐',
#   '早餐',
#   '出乎',
#   '意料',
#   '找到',
#   '喜欢',
#   '品种',
#   '吃',
#   '舒服',
#   '明媚',
#   '阳光',
#   '海边',
#   '孩子',
#   '游泳',
#   '孩子',
#   '期待已久',
#   '乐',
#   '开了花',
#   '酒店',
#   '游泳池',
#   '泳池',
#   '房',
#   '阳江市',
#   '海陵',
#   '岛',
#   '中午',
#   '12',
#   '点',
#   '退',
#   '温德姆',
#   '酒店',
#   '房',
#   '海陵',
#   '岛',
#   '走走',
#   '黄金海岸',
#   '140',
#   '多公里',
#   '开车',
#   '两个',
#   '小时',
#   '抵达',
#   '海陵',
#   '岛',
#   '订',
#   '十里',
#   '银滩',
#   '景区',
#   '海陵',
#   '岛南',
#   '海湾',
#   '花园',
#   '豪华',
#   '全',
#   '海景',
#   '三房一厅',
#   '一厨',
#   '四卫',
#   '公寓',
#   '600',
#   '客厅',
#   '三个',
#   '房间',
#   '阳台',
#   '阳台',
#   '无敌',
#   '海景',
#   '公寓',
#   '度假',
#   '心旷神怡',
#   '有种',
#   '想',
#   '常住',
#   '度假',
#   '冲动',
#   '可惜',
#   '假期',
#   '租个',
#   '公寓',
#   '住',
#   '十来天',
#   '完美',
#   '记得',
#   '防晒霜',
#   '没带',
#   '两天',
#   '脸上',
#   '一堆',
#   '斑',
#   '跳跃',
#   '入住',
#   '收拾',
#   '行李',
#   '孩子',
#   '吃',
#   '东西',
#   '自带',
#   '电磁炉',
#   '电',
#   '煎锅',
#   '炒锅',
#   '煮',
#   '锅',
#   '砧板',
#   '面条',
#   '白菜',
#   '胡萝卜',
#   '鸡蛋',
#   '孩子',
#   '煮',
#   '鸡蛋',
#   '番茄',
#   '面',
#   '顺便',
#   '派',
#   '三个',
#   '娃爸',
#   '开车',
#   '海鲜',
#   '市场',
#   '买',
#   '晚餐',
#   '菜',
#   '喂饱',
#   '孩子',
#   '下楼',
#   '看海',
#   '捡',
#   '贝壳',
#   '完美',
#   '度假',
#   '模式',
#   '傍晚',
#   '孩子',
#   '沙滩',
#   '捡',
#   '贝壳',
#   '玩得',
#   '开心',
#   '离开',
#   '气温',
#   '渐降',
#   '孩子',
#   '衣服',
#   '海水',
#   '打湿',
#   '回去',
#   '热水澡',
#   '换衣服',
#   '捡',
#   '贝壳',
#   '游戏',
#   '暂时',
#   '结束',
#   '晚餐',
#   '煮',
#   '海鲜',
#   '烙饼',
#   '吃饱喝足',
#   '洗好',
#   '澡',
#   '陪',
#   '孩子',
#   '床上',
#   '学',
#   '英语',
#   '22',
#   '点',
#   '分开',
#   '各回',
#   '房间',
#   '睡觉',
#   '第二天',
#   '早上',
#   '煮',
#   '面条',
#   '烙',
#   '酸奶',
#   '鸡蛋',
#   '烙饼',
#   '大人',
#   '小孩',
#   '吃饱',
#   '开车',
#   '海滩',
#   '玩',
#   '三位',
#   '娃爸',
#   '海鲜',
#   '市场',
#   '时',
#   '沙滩',
#   '事实证明',
#   '海滩',
#   '楼下',
#   '贝壳',
#   '小孩',
#   '捡',
#   '玩',
#   '楼下',
#   '沙滩',
#   '美丽',
#   '甚',
#   '贝壳',
#   '捡',
#   '丢',
#   '沙滩',
#   '一场',
#   '贝类',
#   '逃生',
#   '表演',
#   '贝类',
#   '伸出',
#   '腿',
#   '快速',
#   '陷进',
#   '沙子',
#   '超棒',
#   '中午',
#   '回家',
#   '煮',
#   '洋葱',
#   '白菜',
#   '胡萝卜',
#   '炒面',
#   '孩子',
#   '吃',
#   '大人',
#   '炒面',
#   '孩子',
#   '配料',
#   '咖喱',
#   '美味',
#   '再来',
#   '一锅',
#   '海底',
#   '捞',
#   '火锅',
#   '底料',
#   '红薯',
#   '粉',
#   '差点',
#   '醋',
#   '重庆',
#   '酸辣粉',
#   '还给',
#   '力',
#   '午休',
#   '休',
#   '四点',
#   '娃',
#   '不醒',
#   '太早',
#   '没落',
#   '山',
#   '孩子',
#   '下楼',
#   '玩',
#   '海水',
#   '捡',
#   '贝壳'],
#  ['春节',
#   '热爱',
#   '旅行',
#   '一家子',
#   '希望',
#   '走走',
#   '工作',
#   '春节',
#   '闲着',
#   '2012',
#   '年',
#   '衡山',
#   '广州',
#   '2013',
#   '年',
#   '崇左',
#   '南宁',
#   '林',
#   '2014',
#   '年',
#   '西双版纳',
#   '2015',
#   '年',
#   '罗平',
#   '兴义',
#   '2016',
#   '年',
#   '防城港',
#   '东兴',
#   '怀孕',
#   '生',
#   '孩子',
#   '打破',
#   '规律',
#   '细数',
#   '连续',
#   '三个',
#   '春',
#   '节假日',
#   '出门',
#   '远行',
#   '种种原因',
#   '注定',
#   '春节',
#   '远行',
#   '即便如此',
#   '打算',
#   '周边',
#   '走走看看',
#   '枉费',
#   '一段',
#   '假期',
#   '时光',
#   '水东',
#   '城里',
#   '味儿',
#   '收拾',
#   '行囊',
#   '踏着',
#   '清晨',
#   '阳光',
#   '出发',
#   '驱车',
#   '两',
#   '小时',
#   '到达',
#   '水东',
#   '第一站',
#   '选择',
#   '这家',
#   '地道',
#   '鸭',
#   '粥',
#   '店',
#   '先',
#   '饱餐一顿',
#   '这家',
#   '位于',
#   '水东',
#   '老城区',
#   '里',
#   '兴记',
#   '鸭',
#   '粥',
#   '店',
#   '店铺',
#   '总共',
#   '三层楼',
#   '饭点',
#   '时',
#   '坐',
#   '满满当当',
#   '中午',
#   '11',
#   '点多',
#   '来到',
#   '剩下',
#   '三楼',
#   '座位',
#   '赶紧',
#   '入座',
#   '点餐',
#   '菜',
#   '回头',
#   '空座位',
#   '满座',
#   '不禁',
#   '感叹',
#   '这家',
#   '店',
#   '太',
#   '火爆',
#   '这家',
#   '小店',
#   '菜式',
#   '单一',
#   '总共',
#   '四样',
#   '鸭',
#   '粥',
#   '鸭肉',
# ...
#   '一点',
#   '改善',
#   '洗浴',
#   '用品',
#   '洗发水',
#   '沐浴露',
#   '盖子',
#   '真的',
#   '不好',
#   '挤'],
#  ['酒店',
#   '市中心',
#   '交通',
#   '环境',
#   '酒店',
#   '周边',
#   '餐厅',
#   '吃饭',
#   '客房',
#   '卫生',
#   '干净',
#   '前台',
#   '小姐姐',
#   '服务',
#   '热情',
#   '酒店',
#   '二楼',
#   '开了个',
#   '茶',
#   '市',
#   '推荐',
#   '入住'],
#  ['酒店', '前台', '礼貌', '卫生', '干净', '酒店', '位置', '吃喝玩乐'],
#  ['性价比', '高', '居住', '环境'],
#  ['房间', '设备', '不错', '空调', '滴水', '外面', '道', '味'],
#  ['酒店设施', '位置', '第一', '滩', '挺', '小吃店'],
#  ['住',
#   '凯里',
#   '亚德',
#   '床',
#   '舒服',
#   '环境',
#   '不错',
#   '停车',
#   '接待',
#   '礼貌',
#   '新店',
#   '环境',
#   '不错',
#   '位置',
#   '不错',
#   '会员',
#   '评价'],
#  ['酒店',
#   '新开',
#   '房间',
#   '干净',
#   '服务',
#   '不错',
#   '早餐',
#   '酒店',
#   '周边',
#   '出行',
#   '吃饭',
#   '便利',
#   '楼下',
#   '超市',
#   '购物',
#   '便利'],
#  ['前台', '姐姐', '服务', '很棒', '房间', '实况', '图片'],
#  ['不错', '环境'],
#  ['吃', '酒店', '早餐', '房间', '空间', '很大', '性价比', '高'],
#  ['舒服', '安静'],
#  ['酒店',
#   '开发区',
#   '市区',
#   '远',
#   '火车站',
#   '很近',
#   '坐车',
#   '行',
#   '酒店',
#   '楼下',
#   '共享',
#   '电瓶',
#   '自行车',
#   '骑行'],
#  ['性价比',
#   '极高',
#   '新装修',
#   '房间',
#   '喜欢',
#   '时尚',
#   '装修',
#   '风格',
#   '房间',
#   '够',
#   '单独',
#   '电视柜',
#   '做法',
#   '套房',
#   '视感',
#   '房间',
#   '设施',
#   '新',
#   '质量',
#   '高',
#   '牙刷',
#   '拖鞋',
#   '品质',
#   '不错',
#   '堪比',
#   '星级宾馆',
#   '记忆',
#   '棉枕',
#   '睡着',
#   '舒服',
#   '床垫',
#   '舒服',
#   '偏软',
#   '挺',
#   '适合',
#   '强烈推荐',
#   '值得',
#   '入住'],
#  ['一如既往', '地好'],
#  ['价格', '实惠', '不错', '酒店'],
#  ['酒店',
#   '环境',
#   '市中心',
#   '交通',
#   '前台',
#   '服务',
#   '热情',
#   '客房',
#   '卫生',
#   '干净',
#   '二楼',
#   '茶楼',
#   '喝',
#   '早晚',
#   '茶',
#   '万达',
#   '广场',
#   '分钟',
#   '车程',
#   '对面',
#   '一家',
#   '很大',
#   '书店',
#   '女儿',
#   '看书',
#   '半天'],
#  ['感觉', '时尚', '感', '没想到', '空间', '享受', '整套', '智能化', '设备'],
#  ['一家', '店', '服务态度', '满分', '早餐', '送', '环境', '免费', '停车场', '医院'],
#  ['早餐',
#   '楼',
#   '餐厅',
#   '订',
#   '送上',
#   '房间',
#   '房间',
#   '挺大',
#   '位置',
#   '镇',
#   '中心',
#   '导航',
#   '挺',
#   '旁边',
#   '对面',
#   '美食',
#   '门口',
#   '地方',
#   '停车',
#   '地下',
#   '停车场',
#   '不错',
#   '选择'],
#  ['喜欢',
#   '温馨',
#   '安静',
#   '气氛',
#   '这家',
#   '酒店',
#   '很合',
#   '胃口',
#   '一进到',
#   '酒店',
#   '气氛',
#   '音乐',
#   '温馨',
#   '环境',
#   '灯光',
#   '感觉',
#   '挺',
#   '暖',
#   '酒店',
#   '服务',
#   '进到',
#   '酒店',
#   '大堂',
#   '坐下',
#   '前台',
#   '工作人员',
#   '递来',
#   '一杯',
#   '茶',
#   '一条',
#   '热',
#   '毛巾',
#   '房间',
#   '新',
#   '酒店',
#   '原因',
#   '施舍',
#   '设备',
#   '新',
#   '酒店',
#   '满意'],
#  ['服务', '地下', '停车场', '乌漆', '黑', '指示', '标识', '不清', '手机信号', '不好'],
#  ['环境', '出行'],
#  ['房间', '挺'],
#  ['干净',
#   '舒适',
#   '停车',
#   '大堂',
#   '经理',
#   '前台',
#   '小妹',
#   '搞',
#   '卫生',
#   '阿姨',
#   '服务',
#   '热情',
#   '滨海',
#   '绿城',
#   '好心',
#   '荔枝',
#   '红艳',
#   '龙眼',
#   '清甜',
#   '神清气爽',
#   '回味无穷'],
#  ['停车场',
#   '很大',
#   '大厅',
#   '很大',
#   '空调',
#   '热',
#   '前台',
#   '工作人员',
#   '热情',
#   '楼层',
#   '服务员',
#   '热情',
#   '对面',
#   '万达',
#   '广场'],
#  ['酒店', '房间', '不错', '前台', '服务', '茶水', '喝'],
#  ['服务',
#   '真的',
#   '前台',
#   '服务员',
#   '热情好客',
#   '笑容满面',
#   '价钱',
#   '经济',
#   '实惠',
#   '地理位置',
#   '住',
#   '新装修',
#   '客房',
#   '贪便宜',
#   '不差',
#   '就行了',
#   '需求',
#   '下次',
#   '还会',
#   '推荐',
#   '入住'],
#  ['很晚',
#   '酒店',
#   '入住',
#   '前台',
#   '服务',
#   '挺',
#   '地下',
#   '停车位',
#   '停',
#   '几辆',
#   '前台',
#   '安排',
#   '后院',
#   '停车位',
#   '入住',
#   '整体',
#   '挺'],
#  ['超级',
#   '喜欢',
#   '房间',
#   '想象',
#   '中',
#   '干净',
#   '卫生',
#   '隔音',
#   '睡着',
#   '安心',
#   '不远处',
#   '东汇城',
#   '找',
#   '吃'],
#  ['酒店',
#   '房间',
#   '隔音',
#   '效果',
#   '真心',
#   '不错',
#   '比效',
#   '安静',
#   '受',
#   '房间',
#   '外',
#   '声音',
#   '影响',
#   '酒店',
#   '不错',
#   '等价',
#   '格',
#   '酒店',
#   '此店',
#   '确实',
#   '性价比',
#   '高',
#   '物有所值'],
#  ['海景房',
#   '正对',
#   '一线',
#   '海景',
#   '旁边',
#   '海云雁少',
#   '泳池',
#   '出门',
#   '沙滩',
#   '游泳',
#   '区域',
#   '热水',
#   '慢',
#   '但水',
#   '猛',
#   '冲沙',
#   '很爽',
#   '没带',
#   '早餐',
#   '楼下',
#   '吃',
#   '晚餐',
#   '右边',
#   '旁边',
#   '那家',
#   '吃',
#   '不错',
#   '套餐',
#   '点',
#   '鱼虾',
#   '蟹',
#   '实在',
#   '乱七八糟',
#   '加收',
#   '建议',
#   '水东',
#   '东湖',
#   '饮个',
#   '早茶',
#   '好多',
#   '加点',
#   '海味',
#   '蚝',
#   '仔',
#   '瘦肉粥',
#   '海味',
#   '干蒸',
#   '各色',
#   '坂',
#   '建议',
#   '问',
#   '有无',
#   '提前',
#   '订位',
#   '周末',
#   '人超',
#   '夜晚',
#   '红树林',
#   '栈道',
#   '开灯',
#   '很漂亮',
#   '下雨',
#   '没去',
#   '成'],
#  ['考试',
#   '学校',
#   '确实',
#   '很近',
#   '中午',
#   '走路',
#   '回',
#   '酒店',
#   '午睡',
#   '休息',
#   '中规中矩',
#   '不算',
#   '很差',
#   '写',
#   '评论',
#   '时',
#   '录取',
#   '希望',
#   '考生',
#   '加油'],
#  ['酒店',
#   '位置',
#   '挺',
#   '斜对面',
#   '万达',
#   '广场',
#   '步行',
#   '前往',
#   '卫生',
#   '服务',
#   '不错',
#   '足够',
#   '免费',
#   '停车位'],
#  ['很棒', '旅途', '下次', '还会', '入住'],
#  ['配套',
#   '空调',
#   '风口',
#   '着床',
#   '方向',
#   '做',
#   '遮挡',
#   '人性化',
#   '设计',
#   '缺点',
#   '价格',
#   '高',
#   '早餐',
#   '吃饭',
#   '地方',
#   '少'],
#  ['出差'],
#  ['性价比',
#   '超高',
#   '酒店',
#   '服务',
#   '到位',
#   '强',
#   '推荐',
#   '本来',
#   '预定',
#   '部留',
#   '13',
#   '楼',
#   '前台',
#   '想',
#   '高层',
#   '换',
#   '17',
#   '楼',
#   '视野',
#   '超好',
#   '本来',
#   '订单',
#   '含',
#   '早餐',
#   '送',
#   '早餐券',
#   '下午茶',
#   '券',
#   '行政',
#   '酒廊',
#   '品尝',
#   '下午茶',
#   '回来',
#   '发现',
#   '送',
#   '水果',
#   '糖水',
#   '赞',
#   '半夜',
#   '喝水',
#   '弄湿',
#   '床单',
#   '安排',
#   '换',
#   '床单',
#   '服务到位',
#   '物超所值'],
#  ['第一次',
#   '体验',
#   '丽枫',
#   '酒店',
#   '门口',
#   '震惊',
#   '地理位置',
#   '超好',
#   '旁边',
#   '万达',
#   '广场',
#   '停车场',
#   '宽敞',
#   '门口',
#   '看着',
#   '豪华',
#   '招待',
#   '朋友',
#   '首选',
#   '丽枫',
#   '酒店',
#   '丢脸',
#   '大堂',
#   '空调',
#   '力',
#   '办理',
#   '入住',
#   '很快',
#   '前台',
#   '接待',
#   '热情',
#   '细心',
#   '落',
#   '东西',
#   '前台',
#   '细心',
#   '提醒',
#   '客房',
#   '大姐',
#   '礼貌',
#   '房间',
#   '干净',
#   '卫生',
#   '设施',
#   '齐全',
#   '新颖',
#   '早餐',
#   '配送',
#   '房间',
#   '住',
#   '酒店',
#   '第一次',
#   '入住',
#   '体验',
#   '太棒了'],
#  ['海滩', '不算', '太远', '酒店', '停车', '房间', '整洁', '设施', '完善', '性价比', '高'],
#  ['酒店',
#   '地理位置',
#   '硬件',
#   '软件',
#   '不错',
#   '性价比',
#   '高',
#   '房间',
#   '正对着',
#   '公园',
#   '风景',
#   '周边',
#   '餐饮店',
#   '商务',
#   '休闲',
#   '合适'],
#  ['l',
#   '选择',
#   '酒店',
#   '真的',
#   '楼下',
#   '沙滩',
#   '海景',
#   '房间',
#   '特别',
#   '冰雪',
#   '乐园',
#   '周边',
#   '设施',
#   '完善',
#   '沙滩',
#   '广阔',
#   '舒服',
#   '好玩'],
#  ['设施', '陈旧', '服务态度', '环境', '海边', '很近'],
#  ['酒店',
#   '不错',
#   '同等',
#   '价格',
#   '酒店',
#   '此店',
#   '性价比',
#   '高',
#   '物有所值',
#   '酒店',
#   '房间',
#   '隔音',
#   '效果',
#   '不错',
#   '效',
#   '安静',
#   '房间',
#   '外',
#   '走廊',
#   '说话',
#   '声音',
#   '听',
#   '不到'],
#  ['大堂', '经理', '服务', '真', '周到', '升级', '套房', '超级', '棒'],
#  ['挺', '环境卫生', 'OK'],
#  ['喜欢', '住', '简约', '舒适'],
#  ['超值',
#   '体验',
#   '订',
#   '双人床',
#   '房',
#   '前台',
#   '美女',
#   '免费',
#   '升级',
#   '豪华',
#   '1.8',
#   '米',
#   '双床',
#   '房',
#   '超赞',
#   '房间',
#   '干净',
#   '送',
#   '矿泉水',
#   '热水',
#   '够',
#   '猛',
#   'WiFi',
#   '给力',
#   '楼下',
#   '停车',
#   '开票'],
#  ['装修',
#   '不错',
#   '停车场',
#   '车位',
#   '停车',
#   '房间',
#   '卫生',
#   '不错',
#   '酒店',
#   '旁边',
#   '吃饭',
#   '地方',
#   '找',
#   '不太'],
#  ['服务态度', '干净', '整洁', '交通', '便利', '空调', '效果', '性价比', '高'],
#  ['订',
#   '大床',
#   '房间',
#   '二楼',
#   '隐私',
#   '性',
#   '不太好',
#   '窗户',
#   '百叶窗',
#   '紧贴着',
#   '隔壁',
#   '楼',
#   '洗澡间',
#   '下水道',
#   '不知',
#   '总有',
#   '一股',
#   '难闻',
#   '气味',
#   '房间',
#   '卫生',
#   '设施',
#   '算',
#   '不错',
#   '大型',
#   '停车场',
#   '停车'],
#  ['棒',
#   '酒店',
#   '入住',
#   '体验',
#   '前台',
#   '服务',
#   '棒',
#   '周边',
#   '设施',
#   '配套',
#   '齐全',
#   '地段',
#   '繁华',
#   '住',
#   '舒适',
#   '真心',
#   '赞'],
#  ['第二次',
#   '入住',
#   '酒店',
#   '地理位置',
#   '停车',
#   '入口',
#   '房间',
#   '宽敞明亮',
#   '卫生',
#   '床铺',
#   '够',
#   '宽',
#   '枕头',
#   '柔软',
#   '舒服',
#   '全',
#   '五星',
#   '好评'],
#  ['空调', '不给力'],
#  ['前台',
#   '小姐姐',
#   '服务态度',
#   '超级',
#   '赞滴',
#   '细心',
#   '房间',
#   '一眼',
#   '舒服',
#   '床',
#   '软',
#   '舒服',
#   '卫生',
#   '环境',
#   '服务周到',
#   '还会'],
#  ['一个月',
#   '三到',
#   '四次',
#   '住',
#   '熟悉',
#   '感',
#   '环境',
#   '挺',
#   '干净',
#   '早餐',
#   '吃',
#   '挺好吃',
#   '下个月',
#   '住',
#   '两次'],
#  ['酒店',
#   '位置',
#   '优越',
#   '旁边',
#   '公园',
#   '对面',
#   '步行街',
#   '口碑',
#   '特色',
#   '老店',
#   '电影院',
#   '小吃',
#   '糖水',
#   '店',
#   '按摩',
#   '店',
#   '一步之遥',
#   '点赞',
#   '酒店',
#   '服务',
#   '前台',
#   '人员',
#   '碰到',
#   '工作人员',
#   '热情',
#   '面带微笑',
#   '问好',
#   '全程',
#   '入住',
#   '退房',
#   '顺利',
#   '升级',
#   '园',
#   '景房',
#   '细节',
#   '很加分',
#   '插头',
#   '接入',
#   '国际标准',
#   '插板',
#   '升级',
#   '房型',
#   '配置',
#   '电脑',
#   '玩',
#   '一会',
#   '愤怒',
#   '小鸟',
#   '美中不足',
#   '两条',
#   '浴室',
#   '导致',
#   '房间',
#   '空间',
#   '感觉',
#   '有限',
#   '二是',
#   '配置',
#   '落后',
#   '陈旧',
#   '升级',
#   '晚上',
#   '电压',
#   '稳',
#   '室内',
#   '灯微',
#   '闪',
#   '几次',
#   '听到',
#   '隔壁',
#   '楼上',
#   '过道',
#   '少许',
#   '噪音',
#   '浴室',
#   '花洒',
#   '款式',
#   '太老',
#   '变更',
#   '淋浴',
#   '方式',
#   '人手',
#   '艰难',
#   '扭动',
#   '希望',
#   '条件',
#   '升级',
#   '科勒才',
#   '对得起',
#   '五星级',
#   '配置'],
#  ['位置',
#   '好找',
#   '挺',
#   '舒适',
#   '喜欢',
#   '电视接收',
#   '遥控',
#   '感应',
#   '灯',
#   '关',
#   '房间',
#   '灯',
#   '睡觉',
#   '感应',
#   '灯',
#   '贼亮',
#   '光污染',
#   '影响',
#   '入睡',
#   '费好',
#   '功夫',
#   '东西',
#   '遮住'],
#  ['卫生',
#   '不错',
#   '环境',
#   '安静',
#   '办事',
#   '服务员',
#   '打扫',
#   '房间',
#   '热情',
#   '货品',
#   '包装袋',
#   '垃圾',
#   '扫掉',
#   '要紧',
#   '之物',
#   '物品',
#   '只能',
#   '光秃秃',
#   '希望',
#   '改进',
#   '乱动',
#   '客人',
#   '物品'],
#  ['酒店',
#   '电白',
#   '繁荣',
#   '地带',
#   '餐饮',
#   '购物',
#   '二楼',
#   '喜欢',
#   '早',
#   '晚茶市',
#   '消费水平',
#   '中等',
#   '停车位',
#   '紧张'],
#  ['第一次',
#   '入住',
#   '维也纳',
#   '酒店',
#   '免费',
#   '洗衣',
#   '干衣',
#   '服务',
#   '免费手机',
#   '充电器',
#   '免费',
#   '停车场',
#   '几种',
#   '免费',
#   '服务',
#   '值得',
#   '点赞',
#   '酒店',
#   '收费',
#   '环境',
#   '干净',
#   '卫生',
#   '价格合理',
#   '下次',
#   '旅行',
#   '首选',
#   '品牌',
#   '酒店'],
#  ['第一次',
#   '住',
#   '這家店',
#   '卫生',
#   '舒適',
#   '交通',
#   '酒店',
#   '楼下',
#   '家不錯',
#   '美食',
#   '款式',
#   '多样化',
#   '不想',
#   '走',
#   '点个',
#   '美团',
#   '外卖'],
#  ['酒店', '房间', '很大', '卫生', '干净', '前台', '服务', '热情', '楼下', '买', '东西', '吃'],
#  ['两年',
#   '回来',
#   '喜欢',
#   '住',
#   '国际',
#   '酒店',
#   '位置',
#   '足够',
#   '车位',
#   '五星',
#   '酒店',
#   '维护',
#   '保养',
#   '不错',
#   '那种',
#   '陈旧',
#   '感',
#   '早餐',
#   '那种',
#   '看似',
#   '品种繁多',
#   '吃',
#   '五星',
#   '通病',
#   '中西餐',
#   '品种',
#   '精选',
#   '特色',
#   '去年',
#   '改善',
#   '特赞',
#   '唯一',
#   '房间',
#   '有股',
#   '霉味',
#   '去年',
#   '入住',
#   '豪华',
#   '双人间',
#   '抽风',
#   '系统',
#   '毛巾',
#   '晚上',
#   '湿哒',
#   '回来',
#   '还会',
#   '首选'],
#  ['酒店',
#   '肯定',
#   '火',
#   '太',
#   '智能',
#   '升降',
#   '电视',
#   '电动',
#   '插座',
#   '变色',
#   '玻璃',
#   '小度',
#   '管家',
#   '平民化',
#   '价格',
#   '介绍',
#   '朋友'],
#  ['晚上', '周边', '住户', '吵', '挺'],
#  ['房间',
#   '宽敞',
#   '异味',
#   '布局合理',
#   '设施',
#   '设备齐全',
#   '新',
#   '性价比',
#   '高',
#   '一家',
#   '公寓',
#   '满意',
#   '入住',
#   '选择'],
#  ['环境', '安静', '睡得', '舒服'],
#  ['酒店',
#   '干净',
#   '卫生',
#   '前台',
#   '接待',
#   '有礼',
#   '10',
#   '地下',
#   '停车位',
#   '二楼',
#   '早茶',
#   '喝',
#   '价格',
#   '便民',
#   '唯独',
#   '酒店',
#   '提供',
#   '拖鞋',
#   '这方面',
#   '真的',
#   '改善'],
#  ['性价比', '高', '烤', '青口', '好吃'],
#  ['挺', '满意', '后期', '住', '卫生', '差', '点', '希望', '酒店', '杀虫'],
#  ['环境', '清静', '交通', '服务态度'],
#  ['性价比', '酒店', '电动', '窗帘', '房间', '很大', '装修', '现代化', '前台', '服务', '每次', '住'],
#  ['不错', '窗帘', '拉不紧', '早上', '亮', '旁边', '学校', '上课', '铃声', '挺大'],
#  ['扫描',
#   '以下内容',
#   '环境卫生',
#   '床',
#   '舒服',
#   '设施',
#   '给力',
#   '环境',
#   '优雅',
#   '交通',
#   '便利',
#   '性价比',
#   '高',
#   '位置',
#   '价格',
#   '实惠',
#   '服务',
#   '热情',
#   '干净',
#   '房间',
#   '隔音',
#   '浅',
#   '睡',
#   '睡得',
#   '舒服',
#   '服务态度',
#   '一如既往',
#   '地好',
#   '打电话',
#   '前台',
#   '快速',
#   '解决',
#   '办事效率',
#   '高',
#   '满意'],
#  ['第一次', '玩', '第一次', '住', '新', '开张', '酒店', '干净', '很大', '烟味'],
#  ['点评',
#   '内容',
#   '写',
#   '客服',
#   '管家',
#   '服务',
#   '贴心',
#   '提前',
#   '来电',
#   '询问',
#   '客人',
#   '帮忙',
#   '房间',
#   '调成',
#   '湖景大床',
#   '房',
#   '住',
#   '舒服',
#   '房间',
#   '干净',
#   '银湖',
#   '夜景',
#   '很漂亮',
#   '早餐',
#   '很棒',
#   '中',
#   '西式',
#   '餐点',
#   '样样',
#   '俱全',
#   '服务',
#   '下次',
#   '还会',
#   '住',
#   '这家'],
#  ['感觉',
#   '不好',
#   '一点',
#   '住',
#   '两晚',
#   '第二天',
#   '房卡',
#   '开',
#   '门',
#   '进不去',
#   '太',
#   '不好',
#   '希望',
#   '改善',
#   '房客',
#   '整天',
#   '服务台',
#   '跑'],
#  ['新',
#   '酒店',
#   '装修',
#   '房间',
#   '智能',
#   '声控',
#   '设备',
#   '服务',
#   '前台',
#   '客房',
#   '服务员',
#   '礼貌',
#   '卫生',
#   '请',
#   '服务员',
#   '送来',
#   '新',
#   '床单',
#   '床单',
#   '号',
#   '热热',
#   '消毒',
#   '唯一',
#   '吐槽',
#   '号',
#   '电梯',
#   '太慢'],
#  ['前台',
#   '小姐姐',
#   '挺',
#   '热情',
#   '停车位',
#   '保安',
#   '主动',
#   '带领',
#   '指导',
#   '停车',
#   '下雨',
#   '主动',
#   '客人',
#   '撑伞',
#   '服务周到',
#   '值得',
#   '推荐',
#   '强',
#   '强',
#   '强'],
#  ['毛巾', '感觉', '不太', '卫生', '环境', '服务态度'],
#  ['理想'],
#  ['酒店',
#   '整体',
#   '服务',
#   '员工',
#   '彬彬有礼',
#   '早餐',
#   '品种',
#   '需求',
#   '美中不足',
#   '卫生间',
#   '面积',
#   '稍',
#   '头会',
#   '顶撞',
#   '卫生间',
#   '门把手'],
#  ['首次',
#   '入住',
#   '满意',
#   '前台',
#   '服务态度',
#   '热情',
#   '房间',
#   '卫生',
#   '打扫',
#   '干净',
#   '下次',
#   '还来',
#   '入住',
#   '这家',
#   '酒店'],
#  ['总体', '还行', '床头', '两边', '插座', '坏', '修理', '手机', '充电', '书卓', '麻烦'],
#  ['停车场', '位置', '周边', '好像', '餐厅', '吃', '安静', '适合', '休息', '当天', '累', '天亮'],
#  ['酒店',
#   '大堂',
#   '专人',
#   '开门',
#   '大堂',
#   '香香的',
#   '笑脸',
#   '亲',
#   '感觉',
#   '舒服',
#   '办理',
#   '入住',
#   '帮忙',
#   '送',
#   '行李',
#   '进',
#   '房间',
#   '点赞',
#   '孩子',
#   '确实',
#   '帮忙',
#   '送',
#   '水果',
#   '一次性',
#   '浴缸',
#   '垫',
#   '真心',
#   '不错',
#   '下次',
#   '住',
#   '一家'],
#  ['服务',
#   '前台',
#   '花茶',
#   '热',
#   '毛巾',
#   '第一个',
#   '感觉',
#   '特别',
#   '贴心',
#   '热情',
#   '帮',
#   '提',
#   '行李',
#   '房间',
#   '办理',
#   '入住',
#   '很快',
#   '房间',
#   '那一刻',
#   '感觉',
#   '舒适',
#   '简洁',
#   '早上',
#   '配送',
#   '早餐',
#   '房间',
#   '服务质量',
#   '地方',
#   '真的',
#   '少有',
#   '一家',
#   '酒店',
#   '酒店',
#   '位置',
#   '优越',
#   '隔壁',
#   '万达',
#   '广场',
#   '停车场',
#   '很大',
#   '宽敞',
#   '住',
#   '多家',
#   '酒店',
#   '性价比',
#   '这家',
#   '棒',
#   '入住',
#   '体验'],
#  ['环境',
#   '交通',
#   '便利',
#   '价格',
#   '不贵',
#   '蛋糕店',
#   '性价比',
#   '超高',
#   '环境',
#   '真的',
#   '不错',
#   '舒适',
#   '旅行'],
#  ['设施', '挺', '完善', '风景', '早餐', '味道', '不错', '机会', '还会'],
#  ['太棒了', '酒店', '新'],
#  ['新装修',
#   '酒店',
#   '设施',
#   '房内',
#   '状态',
#   '棒',
#   '开门',
#   '房间内',
#   '装修',
#   '味道',
#   '房间',
#   '二楼',
#   '餐厅',
#   '对外',
#   '营业',
#   '早茶'],
#  ['房间',
#   '设备齐全',
#   '满意',
#   '沙发',
#   '洗衣房',
#   '冰箱',
#   '早餐',
#   '送到',
#   '房间',
#   '体验',
#   '感',
#   '不错',
#   '服务态度'],
#  ['环境', '不错'],
#  ['酒店', '性价比', '中式', '装潢', '喜欢', '位置', '中心', '区域', '有车', '算'],
#  ['海滩', '好玩', '早上', '超赞', '酒店'],
#  ['位置',
#   '稍远',
#   '还好',
#   '外卖',
#   '公路',
#   '旁边',
#   '住',
#   '楼不受',
#   '影响',
#   '价格',
#   '实惠',
#   '房间',
#   '很大',
#   '超出',
#   '预期',
#   '设施',
#   '设备',
#   '完善',
#   '新',
#   '选择',
#   '推荐',
#   '入住'],
#  ['第二次', '住', '服务', '卫生', '位置'],
#  ['早餐', '价格', '适合', '孩子', '位置', '新区', '大节', '人多', '吃', '东西'],
#  ['打开门',
#   '一瞬间',
#   '特别',
#   '温馨',
#   '房间',
#   '异味',
#   '一点点',
#   '香味',
#   '开关',
#   '按钮',
#   '智能化',
#   '床',
#   '特别',
#   '软',
#   '特别',
#   '舒服',
#   '窗帘',
#   '自动',
#   '女朋友',
#   '丢脸'],
#  ['景观', '不错', '视野', '开阔', '酒店', '楼下', '海边', '距离', '停车', '免费'],
#  ['交通', '空气清新'],
#  ['位置', '出门', '海滩'],
#  ['河东', '车站', '旁', '挺', '实惠'],
#  ['环境', '不错'],
#  ['地點', '樓下', '東匯城', '吃喝', '玩樂應', '盡', '房間裡', '設施', '不錯', '連續', '住', '三晚'],
#  ['前台',
#   '小姐姐',
#   '奈斯',
#   '热情周到',
#   '位置',
#   '繁华',
#   '酒店',
#   '步行街',
#   '太',
#   '热闹',
#   '提供',
#   '免费',
#   '降噪',
#   '耳塞'],
#  ['经济',
#   '实惠',
#   '房间',
#   '舒适',
#   '酒店',
#   '提供',
#   '洗衣机',
#   '烘干机',
#   '冬天',
#   '这项',
#   '设备',
#   '真的',
#   '懒人',
#   '救星',
#   '赞'],
#  ['环境', '舒适', '干净', '卫生', '装修', '新', '车站', '高铁', '站', '满意', '推荐'],
#  ['位置',
#   '好找',
#   '房间',
#   '卫生',
#   '洁净',
#   '环境',
#   '五星级',
#   '标准',
#   '路边',
#   '隔音',
#   '效果',
#   '房间',
#   '听',
#   '不到',
#   '马路上',
#   '汽车',
#   '声音',
#   '前台',
#   '开',
#   '房间',
#   '开',
#   '其他人',
#   '睡',
#   '半夜',
#   '有人',
#   '刷',
#   '门禁',
#   '女儿',
#   '打电话',
#   '希望',
#   '犯',
#   '低级',
#   '错误'],
#  ['位置', '优越', '停车'],
#  ['环境', '挺不错', '服务态度'],
#  ['酒店',
#   '不错',
#   '每次',
#   '电白',
#   '住',
#   '位置',
#   '好找',
#   '路边',
#   '房间',
#   '干净',
#   '异味',
#   '楼下',
#   '停车',
#   '挺',
#   '酒店',
#   '提供',
#   '早餐'],
#  ['设备', '新', '卫生', '干净', '房间', '舒适', '楼下', '饮茶', '地方', '超市'],
#  ['酒店设施',
#   '齐全',
#   '前台',
#   '小姐姐',
#   '态度',
#   '地理位置',
#   '汽车站',
#   '对面',
#   '高铁',
#   '隔壁',
#   '不到',
#   '200',
#   '米',
#   '强烈推荐',
#   '试一下',
#   '新',
#   '开张',
#   '卫生'],
#  ['酒店设计',
#   '南越',
#   '特色',
#   '工艺品',
#   '书吧',
#   '亮点',
#   '位置',
#   '繁华',
#   '商业街',
#   '下次',
#   '机会',
#   '还会',
#   '入住'],
#  ['夜班', '服务员', '特别', '前台', '保安', '特别', '贴心', '下次', '还会', '不错', '体验'],
#  ['酒店', '环境', '服务', '热情', '下次', '还会'],
#  ['特别',
#   '开床',
#   '服务',
#   '房间',
#   '摆件',
#   '设计',
#   '特色',
#   '性价比',
#   '不错',
#   '下次',
#   '入住',
#   '环境优美',
#   '地理位置',
#   '交通',
#   '房间',
#   '舒适',
#   '卫生',
#   '服务',
#   '人员',
#   '热情',
#   '乐于',
#   '提供',
#   '早餐',
#   '设施',
#   '人性化',
#   '网络',
#   '高速',
#   '信号',
#   '窗外',
#   '风景'],
#  ['酒店', '前台', '服务'],
#  ['房间',
#   '不错',
#   '性价比',
#   '高',
#   '唯一',
#   '管道',
#   '水声',
#   '设备',
#   '房间',
#   '新装修',
#   '还给',
#   '免费',
#   '升级',
#   '值得',
#   '推荐'],
#  ['客运站',
#   '很近',
#   '位置',
#   '内部',
#   '高端',
#   '大气',
#   '喜欢',
#   '门口',
#   '沐足',
#   '广告',
#   '一群',
#   '女',
#   '穿',
#   '内个',
#   '出出入入',
#   '降低',
#   '酒店',
#   '档次'],
#  ['酒店', '挺', '东西', '吃', '酒店', '挺', '好找', '东西', '挺', '齐全'],
#  ['房间',
#   '环境',
#   '不错',
#   '灯光',
#   '太暗',
#   '浴巾',
#   '破洞',
#   '不舍',
#   '换',
#   '一换',
#   '受',
#   '疫情',
#   '影响',
#   '挺',
#   '万达',
#   '广场',
#   '较近'],
#  ['满意', '服务态度', '地理位置', '全', '五星', '好评'],
#  ['早餐', '吃', '床', '挺舒服', '下次', '还会', '入住'],
#  ['房间', '很大', '卫生', '干净', '舒服', '景点'],
#  ['算是', '早餐', '位置', '停车', '前台', '服务', '提升', '一副', '皇帝', '女儿', '不愁', '嫁', '姿态'],
#  ['酒店设施',
#   '全新',
#   '服务态度',
#   '超好',
#   '一百个',
#   '赞给',
#   '这家',
#   '酒店',
#   '遇上',
#   '便宜',
#   '酒店',
#   '真是太',
#   '幸运',
#   '便宜',
#   '货',
#   '服务态度',
#   '进门',
#   '站',
#   '迎接',
#   '君君',
#   '妹妹',
#   '君君',
#   '妹妹',
#   '妹'],
#  ['设施',
#   '设备',
#   '空调',
#   '制冷',
#   '效果',
#   '热水',
#   '给力',
#   '无线网',
#   '好用',
#   '电视机',
#   '高清',
#   '服务员',
#   '专业',
#   '服务',
#   '热情',
#   '入住',
#   '办理',
#   '收',
#   '押金',
#   '卫生',
#   '情况',
#   '房间',
#   '干净',
#   '布草',
#   '干净',
#   '大堂',
#   '明亮',
#   '不错',
#   '出行',
#   '打车',
#   '餐饮店',
#   '价格',
#   '实惠'],
#  ['酒店',
#   '路边',
#   '挺',
#   '安静',
#   '地下',
#   '停车场',
#   '设施',
#   '新',
#   '房间',
#   '安静',
#   '舒适',
#   '淋浴室',
#   '洗手盆',
#   '热水',
#   '打开',
#   '一两秒',
#   '热水',
#   '枕头',
#   '硬度',
#   '刚刚',
#   '行程',
#   '安排',
#   '下午',
#   '退房',
#   '前台',
#   'nice',
#   '免费',
#   '延迟',
#   '退房',
#   '下午',
#   '两点',
#   '下次',
#   '住'],
#  ['酒店',
#   '整体',
#   '不错',
#   '经济',
#   '实惠',
#   '设施',
#   '不错',
#   'Wifi',
#   '速度',
#   '不错',
#   '10M',
#   'S',
#   '速度',
#   '酒店',
#   '日用品',
#   '挺',
#   '卫生',
#   '不错',
#   '安心',
#   '入住'],
#  ...]

# %%
def word2vec_model(text_list=None):
    model = Word2Vec(text_list, vector_size=200, window=5, min_count=1, seed=1, workers=4)
    model.save('data/word2vec.model')

# %%
word2vec_model(text_stop)

# %%
model = Word2Vec.load('data/word2vec.model')
wv = model.wv

# %%
wv.similarity('海滩', '沙滩')
# Out:
# 0.9982938

# %% [markdown]
# ### 删除关联度为0的实体

# %%
# new_entitys_pmis = {i:j for i, j in zip(entitys_pmis.keys(), list(entitys_pmis.values())) if j[0] != 0}

# %%
new_entitys_pmis = entitys_pmis

# %% [markdown]
# ### 保存数据

# %%
entity_values = list(new_entitys_pmis.values())
entity_values
# Out:
# [[0, 'ID26-ID56'],
#  [0, 'ID26-ID72'],
#  [0, 'ID26-ID54'],
#  [0, 'ID26-ID33'],
#  [0, 'ID26-ID27'],
#  [0, 'ID26-ID51'],
#  [0, 'ID26-ID12'],
#  [0, 'ID26-ID67'],
#  [0, 'ID26-ID6'],
#  [0, 'ID26-ID9'],
#  [0, 'ID26-ID65'],
#  [0, 'ID26-ID40'],
#  [6.05, 'ID26-ID31'],
#  [0, 'ID26-ID89'],
#  [0, 'ID26-ID49'],
#  [0, 'ID26-ID80'],
#  [3.98, 'ID26-ID5'],
#  [0, 'ID26-ID57'],
#  [9.05, 'ID26-ID26'],
#  [0, 'ID26-ID88'],
#  [0, 'ID26-ID25'],
#  [0, 'ID26-ID11'],
#  [5.15, 'ID26-ID45'],
#  [0, 'ID26-ID59'],
#  [0, 'ID26-ID71'],
#  [0, 'ID26-ID63'],
#  [6.25, 'ID26-ID15'],
#  [0, 'ID26-ID8'],
#  [0, 'ID26-ID75'],
#  [0, 'ID26-ID32'],
#  [5.05, 'ID26-ID36'],
#  [0, 'ID26-ID58'],
#  [0, 'ID26-ID78'],
#  [0, 'ID26-ID84'],
#  [2.5, 'ID26-ID66'],
#  [0, 'ID26-ID50'],
#  [0, 'ID26-ID38'],
#  [0, 'ID26-ID77'],
#  [0, 'ID26-ID16'],
#  [0, 'ID26-ID39'],
#  [0, 'ID26-ID62'],
#  [0, 'ID26-ID42'],
#  [0, 'ID26-ID74'],
#  [0, 'ID26-ID17'],
#  [0, 'ID26-ID70'],
#  [0, 'ID26-ID85'],
#  [7.21, 'ID26-ID23'],
#  [0, 'ID26-ID3'],
#  [6.55, 'ID26-ID24'],
#  [0, 'ID26-ID79'],
#  [0, 'ID26-ID19'],
#  [8.05, 'ID26-ID48'],
#  [0, 'ID26-ID37'],
#  [0, 'ID26-ID87'],
#  [0, 'ID26-ID46'],
#  [6.15, 'ID26-ID10'],
#  [0, 'ID26-ID86'],
#  [0, 'ID26-ID61'],
#  [0, 'ID26-ID82'],
#  [0, 'ID26-ID90'],
#  [0, 'ID26-ID13'],
#  [0, 'ID26-ID18'],
#  [0, 'ID26-ID41'],
#  [0, 'ID26-ID81'],
#  [0, 'ID26-ID7'],
#  [6.25, 'ID26-ID14'],
#  [0, 'ID26-ID52'],
#  [0, 'ID26-ID68'],
#  [0, 'ID26-ID76'],
#  [0, 'ID26-ID53'],
#  [3.44, 'ID26-ID20'],
#  [3.32, 'ID26-ID4'],
#  [0, 'ID26-ID22'],
#  [0, 'ID26-ID47'],
#  [0, 'ID26-ID44'],
#  [0, 'ID26-ID55'],
#  [0, 'ID26-ID43'],
#  [0, 'ID26-ID1'],
#  [0, 'ID26-ID21'],
#  [0, 'ID26-ID2'],
#  [0, 'ID26-ID60'],
#  [3.81, 'ID26-ID35'],
#  [7.47, 'ID26-ID30'],
#  [0, 'ID26-ID69'],
#  [0, 'ID26-ID73'],
#  [0, 'ID26-ID28'],
#  [0, 'ID26-ID64'],
#  [0, 'ID26-ID34'],
#  [0, 'ID26-ID83'],
#  [3.47, 'ID26-ID29'],
#  [0, 'ID56-ID72'],
#  [0, 'ID56-ID54'],
#  [0, 'ID56-ID33'],
#  [0, 'ID56-ID27'],
#  [0, 'ID56-ID51'],
#  [0, 'ID56-ID12'],
#  [0, 'ID56-ID67'],
#  [0, 'ID56-ID6'],
#  [0, 'ID56-ID9'],
#  [5.32, 'ID56-ID65'],
#  [0, 'ID56-ID40'],
#  [0, 'ID56-ID31'],
#  [0, 'ID56-ID89'],
#  [0, 'ID56-ID49'],
#  [0, 'ID56-ID80'],
#  [0, 'ID56-ID5'],
#  [6.82, 'ID56-ID57'],
#  [0, 'ID56-ID26'],
#  [0, 'ID56-ID88'],
#  [0, 'ID56-ID25'],
#  [0, 'ID56-ID11'],
#  [0, 'ID56-ID45'],
#  [0, 'ID56-ID59'],
#  [0, 'ID56-ID71'],
#  [0, 'ID56-ID63'],
#  [0, 'ID56-ID15'],
#  [0, 'ID56-ID8'],
#  [0, 'ID56-ID75'],
#  [9.32, 'ID56-ID56'],
#  [0, 'ID56-ID32'],
#  [0, 'ID56-ID36'],
#  [0, 'ID56-ID58'],
#  [0, 'ID56-ID78'],
#  [0, 'ID56-ID84'],
#  [0, 'ID56-ID66'],
#  [0, 'ID56-ID50'],
#  [0, 'ID56-ID38'],
#  [0, 'ID56-ID77'],
#  [0, 'ID56-ID16'],
#  [0, 'ID56-ID39'],
#  [0, 'ID56-ID62'],
#  [0, 'ID56-ID42'],
#  [0, 'ID56-ID74'],
#  [0, 'ID56-ID17'],
#  [0, 'ID56-ID70'],
#  [0, 'ID56-ID85'],
#  [0, 'ID56-ID23'],
#  [0, 'ID56-ID3'],
#  [0, 'ID56-ID24'],
#  [0, 'ID56-ID79'],
#  [0, 'ID56-ID19'],
#  [0, 'ID56-ID48'],
#  [0, 'ID56-ID37'],
#  [0, 'ID56-ID87'],
#  [0, 'ID56-ID46'],
#  [0, 'ID56-ID10'],
#  [0, 'ID56-ID86'],
#  [0, 'ID56-ID61'],
#  [0, 'ID56-ID82'],
#  [0, 'ID56-ID90'],
#  [0, 'ID56-ID13'],
#  [0, 'ID56-ID18'],
#  [0, 'ID56-ID41'],
#  [0, 'ID56-ID81'],
#  [0, 'ID56-ID7'],
#  [0, 'ID56-ID14'],
#  [0, 'ID56-ID52'],
#  [0, 'ID56-ID68'],
#  [0, 'ID56-ID76'],
#  [0, 'ID56-ID53'],
#  [0, 'ID56-ID20'],
#  [0, 'ID56-ID4'],
#  [0, 'ID56-ID22'],
#  [0, 'ID56-ID47'],
#  [0, 'ID56-ID44'],
#  [0, 'ID56-ID55'],
#  [0, 'ID56-ID43'],
#  [0, 'ID56-ID1'],
#  [0, 'ID56-ID21'],
#  [0, 'ID56-ID2'],
#  [0, 'ID56-ID60'],
#  [0, 'ID56-ID35'],
#  [0, 'ID56-ID30'],
#  [0, 'ID56-ID69'],
#  [0, 'ID56-ID73'],
#  [0, 'ID56-ID28'],
#  [0, 'ID56-ID64'],
#  [0, 'ID56-ID34'],
#  [0, 'ID56-ID83'],
#  [0, 'ID56-ID29'],
#  [0, 'ID72-ID54'],
#  [0, 'ID72-ID33'],
#  [0, 'ID72-ID27'],
#  [0, 'ID72-ID51'],
#  [0, 'ID72-ID12'],
#  [0, 'ID72-ID67'],
#  [0, 'ID72-ID6'],
#  [0, 'ID72-ID9'],
#  [0, 'ID72-ID65'],
#  [0, 'ID72-ID40'],
#  [0, 'ID72-ID31'],
#  [0, 'ID72-ID89'],
#  [0, 'ID72-ID49'],
#  [0, 'ID72-ID80'],
#  [0, 'ID72-ID5'],
#  [0, 'ID72-ID57'],
#  [0, 'ID72-ID26'],
#  [0, 'ID72-ID88'],
#  [0, 'ID72-ID25'],
#  [0, 'ID72-ID11'],
#  [0, 'ID72-ID45'],
#  [0, 'ID72-ID59'],
#  [0, 'ID72-ID71'],
#  [8.32, 'ID72-ID63'],
#  [0, 'ID72-ID15'],
#  [0, 'ID72-ID8'],
#  [0, 'ID72-ID75'],
#  [0, 'ID72-ID56'],
#  [0, 'ID72-ID32'],
#  [0, 'ID72-ID36'],
#  [0, 'ID72-ID58'],
#  [0, 'ID72-ID78'],
#  [12.22, 'ID72-ID84'],
#  [0, 'ID72-ID66'],
#  [0, 'ID72-ID50'],
#  [0, 'ID72-ID38'],
#  [0, 'ID72-ID77'],
#  [0, 'ID72-ID16'],
#  [0, 'ID72-ID39'],
#  [0, 'ID72-ID62'],
#  [0, 'ID72-ID42'],
#  [0, 'ID72-ID74'],
#  [0, 'ID72-ID17'],
#  [0, 'ID72-ID70'],
#  [0, 'ID72-ID85'],
#  [0, 'ID72-ID23'],
#  [0, 'ID72-ID3'],
#  [0, 'ID72-ID24'],
#  [0, 'ID72-ID79'],
#  [0, 'ID72-ID19'],
#  [0, 'ID72-ID48'],
#  [0, 'ID72-ID37'],
#  [0, 'ID72-ID87'],
#  [10.42, 'ID72-ID46'],
#  [0, 'ID72-ID10'],
#  [0, 'ID72-ID86'],
#  [6.22, 'ID72-ID61'],
#  [0, 'ID72-ID82'],
#  [0, 'ID72-ID90'],
#  [0, 'ID72-ID13'],
#  [0, 'ID72-ID18'],
#  [0, 'ID72-ID41'],
#  [0, 'ID72-ID81'],
#  [0, 'ID72-ID7'],
#  [0, 'ID72-ID14'],
#  [0, 'ID72-ID52'],
#  [0, 'ID72-ID68'],
#  [0, 'ID72-ID76'],
#  [0, 'ID72-ID53'],
#  [0, 'ID72-ID20'],
#  [0, 'ID72-ID4'],
#  [0, 'ID72-ID22'],
#  [0, 'ID72-ID47'],
#  [0, 'ID72-ID44'],
#  [0, 'ID72-ID55'],
#  [0, 'ID72-ID43'],
#  [0, 'ID72-ID1'],
#  [0, 'ID72-ID21'],
#  [0, 'ID72-ID2'],
#  [0, 'ID72-ID60'],
#  [0, 'ID72-ID35'],
#  [0, 'ID72-ID30'],
#  [0, 'ID72-ID69'],
#  [0, 'ID72-ID73'],
#  [0, 'ID72-ID28'],
#  [0, 'ID72-ID64'],
#  [0, 'ID72-ID34'],
#  [0, 'ID72-ID83'],
#  [0, 'ID72-ID29'],
#  [12.22, 'ID72-ID72'],
#  [0, 'ID54-ID33'],
#  [0, 'ID54-ID27'],
#  [0, 'ID54-ID51'],
#  [0, 'ID54-ID12'],
#  [0, 'ID54-ID67'],
#  [0, 'ID54-ID6'],
#  [0, 'ID54-ID9'],
#  [0, 'ID54-ID65'],
#  [0, 'ID54-ID40'],
#  [0, 'ID54-ID31'],
#  [0, 'ID54-ID89'],
#  [2.27, 'ID54-ID49'],
#  [0, 'ID54-ID80'],
#  [0, 'ID54-ID5'],
#  [0, 'ID54-ID57'],
#  [0, 'ID54-ID26'],
#  [0, 'ID54-ID88'],
#  [0, 'ID54-ID25'],
#  [0, 'ID54-ID11'],
#  [6.48, 'ID54-ID54'],
#  [0, 'ID54-ID45'],
#  [0, 'ID54-ID59'],
#  [0, 'ID54-ID71'],
#  [0, 'ID54-ID63'],
#  [0, 'ID54-ID15'],
#  [0, 'ID54-ID8'],
#  [0, 'ID54-ID75'],
#  [0, 'ID54-ID56'],
#  [0, 'ID54-ID32'],
#  [0, 'ID54-ID36'],
#  [0, 'ID54-ID58'],
#  [0, 'ID54-ID78'],
#  [0, 'ID54-ID84'],
#  [0, 'ID54-ID66'],
#  [0, 'ID54-ID50'],
#  [0, 'ID54-ID38'],
#  [0, 'ID54-ID77'],
#  [0.84, 'ID54-ID16'],
#  [0, 'ID54-ID39'],
#  [2.74, 'ID54-ID62'],
#  [0, 'ID54-ID42'],
#  [0, 'ID54-ID74'],
#  [0, 'ID54-ID17'],
#  [0, 'ID54-ID70'],
#  [0, 'ID54-ID85'],
#  [0, 'ID54-ID23'],
#  [0, 'ID54-ID3'],
#  [0, 'ID54-ID24'],
#  [0, 'ID54-ID79'],
#  [0, 'ID54-ID19'],
#  [0, 'ID54-ID48'],
#  [0, 'ID54-ID37'],
#  [0, 'ID54-ID87'],
#  [0, 'ID54-ID46'],
#  [0, 'ID54-ID10'],
#  [0, 'ID54-ID86'],
#  [0, 'ID54-ID61'],
#  [0, 'ID54-ID82'],
#  [0, 'ID54-ID90'],
#  [0, 'ID54-ID13'],
#  [0, 'ID54-ID18'],
#  [0, 'ID54-ID41'],
#  [0, 'ID54-ID81'],
#  [0, 'ID54-ID7'],
#  [0, 'ID54-ID14'],
#  [4.4, 'ID54-ID52'],
#  [0, 'ID54-ID68'],
#  [0, 'ID54-ID76'],
#  [1.6, 'ID54-ID53'],
#  [0, 'ID54-ID20'],
#  [0, 'ID54-ID4'],
#  [0, 'ID54-ID22'],
#  [0, 'ID54-ID47'],
#  [0, 'ID54-ID44'],
#  [0, 'ID54-ID55'],
#  [0, 'ID54-ID43'],
#  [0, 'ID54-ID1'],
#  [0, 'ID54-ID21'],
#  [0, 'ID54-ID2'],
#  [0, 'ID54-ID60'],
#  [0, 'ID54-ID35'],
#  [0, 'ID54-ID30'],
#  [0, 'ID54-ID69'],
#  [0, 'ID54-ID73'],
#  [0, 'ID54-ID28'],
#  [0, 'ID54-ID64'],
#  [0, 'ID54-ID34'],
#  [0, 'ID54-ID83'],
#  [0, 'ID54-ID29'],
#  [0, 'ID54-ID72'],
#  [0, 'ID33-ID27'],
#  [0, 'ID33-ID51'],
#  [0, 'ID33-ID12'],
#  [0, 'ID33-ID67'],
#  [0, 'ID33-ID6'],
#  [4.01, 'ID33-ID9'],
#  [0, 'ID33-ID65'],
#  [0, 'ID33-ID40'],
#  [7.05, 'ID33-ID31'],
#  [0, 'ID33-ID89'],
#  [3.85, 'ID33-ID49'],
#  [0, 'ID33-ID80'],
#  [4.65, 'ID33-ID5'],
#  [0, 'ID33-ID57'],
#  [0, 'ID33-ID26'],
#  [0, 'ID33-ID88'],
#  [0, 'ID33-ID25'],
#  [4.73, 'ID33-ID11'],
#  [0, 'ID33-ID54'],
#  [0, 'ID33-ID45'],
#  [0, 'ID33-ID59'],
#  [0, 'ID33-ID71'],
#  [0, 'ID33-ID63'],
#  [0, 'ID33-ID15'],
#  [5.35, 'ID33-ID8'],
#  [0, 'ID33-ID75'],
#  [0, 'ID33-ID56'],
#  [0, 'ID33-ID32'],
#  [5.05, 'ID33-ID36'],
#  [5.05, 'ID33-ID58'],
#  [0, 'ID33-ID78'],
#  [0, 'ID33-ID84'],
#  [0, 'ID33-ID66'],
#  [0, 'ID33-ID50'],
#  [0, 'ID33-ID38'],
#  [0, 'ID33-ID77'],
#  [0, 'ID33-ID16'],
#  [6.85, 'ID33-ID39'],
#  [0, 'ID33-ID62'],
#  [0, 'ID33-ID42'],
#  [0, 'ID33-ID74'],
#  [5.89, 'ID33-ID17'],
#  [6.05, 'ID33-ID70'],
#  [9.05, 'ID33-ID33'],
#  [0, 'ID33-ID85'],
#  [0, 'ID33-ID23'],
#  [0, 'ID33-ID3'],
#  [0, 'ID33-ID24'],
#  [0, 'ID33-ID79'],
#  [0, 'ID33-ID19'],
#  [0, 'ID33-ID48'],
#  [0, 'ID33-ID37'],
#  [0, 'ID33-ID87'],
#  [0, 'ID33-ID46'],
#  [5.15, 'ID33-ID10'],
#  [0, 'ID33-ID86'],
#  [0, 'ID33-ID61'],
#  [0, 'ID33-ID82'],
#  [0, 'ID33-ID90'],
#  [4.1, 'ID33-ID13'],
#  [0, 'ID33-ID18'],
#  [0, 'ID33-ID41'],
#  [0, 'ID33-ID81'],
#  [0, 'ID33-ID7'],
#  [0, 'ID33-ID14'],
#  [0, 'ID33-ID52'],
#  [0, 'ID33-ID68'],
#  [7.25, 'ID33-ID76'],
#  [0, 'ID33-ID53'],
#  [5.03, 'ID33-ID20'],
#  [4.54, 'ID33-ID4'],
#  [4.63, 'ID33-ID22'],
#  [0, 'ID33-ID47'],
#  [0, 'ID33-ID44'],
#  [0, 'ID33-ID55'],
#  [0, 'ID33-ID43'],
#  [4.98, 'ID33-ID1'],
#  [0, 'ID33-ID21'],
#  [3.81, 'ID33-ID2'],
#  [0, 'ID33-ID60'],
#  [0, 'ID33-ID35'],
#  [0, 'ID33-ID30'],
#  [0, 'ID33-ID69'],
#  [0, 'ID33-ID73'],
#  [5.73, 'ID33-ID28'],
#  [0, 'ID33-ID64'],
#  [0, 'ID33-ID34'],
#  [0, 'ID33-ID83'],
#  [4.47, 'ID33-ID29'],
#  [0, 'ID33-ID72'],
#  [0, 'ID27-ID51'],
#  [0, 'ID27-ID12'],
#  [0, 'ID27-ID67'],
#  [0, 'ID27-ID6'],
#  [0, 'ID27-ID9'],
#  [0, 'ID27-ID65'],
#  [0, 'ID27-ID40'],
#  [0, 'ID27-ID31'],
#  [0, 'ID27-ID89'],
#  [0, 'ID27-ID49'],
#  [0, 'ID27-ID80'],
#  [5.12, 'ID27-ID5'],
#  [0, 'ID27-ID57'],
#  [0, 'ID27-ID26'],
#  [0, 'ID27-ID88'],
#  [8.94, 'ID27-ID25'],
#  [0, 'ID27-ID11'],
#  [0, 'ID27-ID54'],
#  [0, 'ID27-ID45'],
#  [0, 'ID27-ID59'],
#  [0, 'ID27-ID71'],
#  [0, 'ID27-ID63'],
#  [0, 'ID27-ID15'],
#  [0, 'ID27-ID8'],
#  [0, 'ID27-ID75'],
#  [0, 'ID27-ID56'],
#  [0, 'ID27-ID32'],
#  [0, 'ID27-ID36'],
#  [0, 'ID27-ID58'],
#  [0, 'ID27-ID78'],
#  [0, 'ID27-ID84'],
#  [2.97, 'ID27-ID66'],
#  [0, 'ID27-ID50'],
#  [0, 'ID27-ID38'],
#  [0, 'ID27-ID77'],
#  [2.88, 'ID27-ID16'],
#  [0, 'ID27-ID39'],
#  [0, 'ID27-ID62'],
#  [0, 'ID27-ID42'],
#  [0, 'ID27-ID74'],
#  [0, 'ID27-ID17'],
#  [0, 'ID27-ID70'],
#  [0, 'ID27-ID33'],
#  [0, 'ID27-ID85'],
#  [0, 'ID27-ID23'],
#  [0, 'ID27-ID3'],
#  [0, 'ID27-ID24'],
#  [0, 'ID27-ID79'],
#  [0, 'ID27-ID19'],
#  [0, 'ID27-ID48'],
#  [4.88, 'ID27-ID37'],
#  [0, 'ID27-ID87'],
#  [0, 'ID27-ID46'],
#  [5.62, 'ID27-ID10'],
#  [0, 'ID27-ID86'],
#  [0, 'ID27-ID61'],
#  [0, 'ID27-ID82'],
#  [0, 'ID27-ID90'],
#  [0, 'ID27-ID13'],
#  [0, 'ID27-ID18'],
#  [0, 'ID27-ID41'],
#  [0, 'ID27-ID81'],
#  [4.94, 'ID27-ID7'],
#  [0, 'ID27-ID14'],
#  [0, 'ID27-ID52'],
#  [0, 'ID27-ID68'],
#  [0, 'ID27-ID76'],
#  [0, 'ID27-ID53'],
#  [9.52, 'ID27-ID27'],
#  [3.91, 'ID27-ID20'],
#  [4.2, 'ID27-ID4'],
#  [7.1, 'ID27-ID22'],
#  [0, 'ID27-ID47'],
#  [0, 'ID27-ID44'],
#  [0, 'ID27-ID55'],
#  [0, 'ID27-ID43'],
#  [5.45, 'ID27-ID1'],
#  [0, 'ID27-ID21'],
#  [4.28, 'ID27-ID2'],
#  [0, 'ID27-ID60'],
#  [0, 'ID27-ID35'],
#  [0, 'ID27-ID30'],
#  [0, 'ID27-ID69'],
#  [0, 'ID27-ID73'],
#  [0, 'ID27-ID28'],
#  [0, 'ID27-ID64'],
#  [0, 'ID27-ID34'],
#  [0, 'ID27-ID83'],
#  [0, 'ID27-ID29'],
#  [0, 'ID27-ID72'],
#  [0, 'ID51-ID12'],
#  [0, 'ID51-ID67'],
#  [0, 'ID51-ID6'],
#  [0, 'ID51-ID9'],
#  [0, 'ID51-ID65'],
#  [0, 'ID51-ID40'],
#  [0, 'ID51-ID31'],
#  [0, 'ID51-ID89'],
#  [0, 'ID51-ID49'],
#  [0, 'ID51-ID80'],
#  [0, 'ID51-ID5'],
#  [0, 'ID51-ID57'],
#  [0, 'ID51-ID26'],
#  [0, 'ID51-ID88'],
#  [0, 'ID51-ID25'],
#  [0, 'ID51-ID11'],
#  [0, 'ID51-ID54'],
#  [0, 'ID51-ID45'],
#  [0, 'ID51-ID59'],
#  [0, 'ID51-ID71'],
#  [0, 'ID51-ID63'],
#  [0, 'ID51-ID15'],
#  [0, 'ID51-ID8'],
#  [0, 'ID51-ID75'],
#  [0, 'ID51-ID56'],
#  [0, 'ID51-ID32'],
#  [0, 'ID51-ID36'],
#  [0, 'ID51-ID58'],
#  [0, 'ID51-ID78'],
#  [0, 'ID51-ID84'],
#  [0, 'ID51-ID66'],
#  [0, 'ID51-ID50'],
#  [0, 'ID51-ID38'],
#  [0, 'ID51-ID77'],
#  [0, 'ID51-ID16'],
#  [0, 'ID51-ID39'],
#  [0, 'ID51-ID62'],
#  [0, 'ID51-ID42'],
#  [0, 'ID51-ID74'],
#  [0, 'ID51-ID17'],
#  [0, 'ID51-ID70'],
#  [0, 'ID51-ID33'],
#  [0, 'ID51-ID85'],
#  [0, 'ID51-ID23'],
#  [0, 'ID51-ID3'],
#  [0, 'ID51-ID24'],
#  [0, 'ID51-ID79'],
#  [0, 'ID51-ID19'],
#  [0, 'ID51-ID48'],
#  [0, 'ID51-ID37'],
#  [0, 'ID51-ID87'],
#  [0, 'ID51-ID46'],
#  [0, 'ID51-ID10'],
#  [0, 'ID51-ID86'],
#  [0, 'ID51-ID61'],
#  [0, 'ID51-ID82'],
#  [0, 'ID51-ID90'],
#  [0, 'ID51-ID13'],
#  [0, 'ID51-ID18'],
#  [0, 'ID51-ID41'],
#  [0, 'ID51-ID81'],
#  [0, 'ID51-ID7'],
#  [0, 'ID51-ID14'],
#  [0, 'ID51-ID52'],
#  [0, 'ID51-ID68'],
#  [0, 'ID51-ID76'],
#  [0, 'ID51-ID53'],
#  [0, 'ID51-ID27'],
#  [0, 'ID51-ID20'],
#  [0, 'ID51-ID4'],
#  [0, 'ID51-ID22'],
#  [0, 'ID51-ID47'],
#  [0, 'ID51-ID44'],
#  [0, 'ID51-ID55'],
#  [0, 'ID51-ID43'],
#  [0, 'ID51-ID1'],
#  [0, 'ID51-ID21'],
#  [0, 'ID51-ID2'],
#  [0, 'ID51-ID60'],
#  [0, 'ID51-ID35'],
#  [0, 'ID51-ID30'],
#  [0, 'ID51-ID69'],
#  [0, 'ID51-ID73'],
#  [0, 'ID51-ID28'],
#  [0, 'ID51-ID64'],
#  [0, 'ID51-ID34'],
#  [0, 'ID51-ID83'],
#  [11.64, 'ID51-ID51'],
#  [0, 'ID51-ID29'],
#  [0, 'ID51-ID72'],
#  [0, 'ID12-ID67'],
#  [0, 'ID12-ID6'],
#  [0, 'ID12-ID9'],
#  [0, 'ID12-ID65'],
#  [0, 'ID12-ID40'],
#  [0, 'ID12-ID31'],
#  [0, 'ID12-ID89'],
#  [5.56, 'ID12-ID49'],
#  [0, 'ID12-ID80'],
#  [2.36, 'ID12-ID5'],
#  [0, 'ID12-ID57'],
#  [0, 'ID12-ID26'],
#  [0, 'ID12-ID88'],
#  [0, 'ID12-ID25'],
#  [0, 'ID12-ID11'],
#  [0, 'ID12-ID54'],
#  [0, 'ID12-ID45'],
#  [0, 'ID12-ID59'],
#  [0, 'ID12-ID71'],
#  [0, 'ID12-ID63'],
#  [0, 'ID12-ID15'],
#  [0, 'ID12-ID8'],
#  [0, 'ID12-ID75'],
#  [0, 'ID12-ID56'],
#  [0, 'ID12-ID32'],
#  [0, 'ID12-ID36'],
#  [0, 'ID12-ID58'],
#  [0, 'ID12-ID78'],
#  [0, 'ID12-ID84'],
#  [9.77, 'ID12-ID12'],
#  [0, 'ID12-ID66'],
#  [0, 'ID12-ID50'],
#  [0, 'ID12-ID38'],
#  [0, 'ID12-ID77'],
#  [3.12, 'ID12-ID16'],
#  [5.24, 'ID12-ID39'],
#  [3.7, 'ID12-ID62'],
#  [3.73, 'ID12-ID42'],
#  [0, 'ID12-ID74'],
#  [0, 'ID12-ID17'],
#  [0, 'ID12-ID70'],
#  [0, 'ID12-ID33'],
#  [0, 'ID12-ID85'],
#  [0, 'ID12-ID23'],
#  [0, 'ID12-ID3'],
#  [0, 'ID12-ID24'],
#  [0, 'ID12-ID79'],
#  [0, 'ID12-ID19'],
#  [0, 'ID12-ID48'],
#  [0, 'ID12-ID37'],
#  [0, 'ID12-ID87'],
#  [0, 'ID12-ID46'],
#  [0, 'ID12-ID10'],
#  [0, 'ID12-ID86'],
#  [0, 'ID12-ID61'],
#  [0, 'ID12-ID82'],
#  [0, 'ID12-ID90'],
#  [0, 'ID12-ID13'],
#  [0, 'ID12-ID18'],
#  [0, 'ID12-ID41'],
#  [0, 'ID12-ID81'],
#  [0, 'ID12-ID7'],
#  [0, 'ID12-ID14'],
#  [0, 'ID12-ID52'],
#  [0, 'ID12-ID68'],
#  [0, 'ID12-ID76'],
#  [0, 'ID12-ID53'],
#  [0, 'ID12-ID27'],
#  [0, 'ID12-ID20'],
#  [4.03, 'ID12-ID4'],
#  [4.34, 'ID12-ID22'],
#  [0, 'ID12-ID47'],
#  [0, 'ID12-ID44'],
#  [0, 'ID12-ID55'],
#  [0, 'ID12-ID43'],
#  [3.11, 'ID12-ID1'],
#  [0, 'ID12-ID21'],
#  [0, 'ID12-ID2'],
#  [0, 'ID12-ID60'],
#  [4.52, 'ID12-ID35'],
#  [0, 'ID12-ID30'],
#  [0, 'ID12-ID69'],
#  [0, 'ID12-ID73'],
#  [0, 'ID12-ID28'],
#  [0, 'ID12-ID64'],
#  [0, 'ID12-ID34'],
#  [0, 'ID12-ID83'],
#  [0, 'ID12-ID51'],
#  [0, 'ID12-ID29'],
#  [0, 'ID12-ID72'],
#  [0, 'ID67-ID6'],
#  [0, 'ID67-ID9'],
#  [0, 'ID67-ID65'],
#  [0, 'ID67-ID40'],
#  [0, 'ID67-ID31'],
#  [6.95, 'ID67-ID89'],
#  [4.06, 'ID67-ID49'],
#  [0, 'ID67-ID80'],
#  [0, 'ID67-ID5'],
#  [0, 'ID67-ID57'],
#  [0, 'ID67-ID26'],
#  [0, 'ID67-ID88'],
#  [0, 'ID67-ID25'],
#  [3.95, 'ID67-ID11'],
#  [0, 'ID67-ID54'],
#  [0, 'ID67-ID45'],
#  [0, 'ID67-ID59'],
#  [0, 'ID67-ID71'],
#  [0, 'ID67-ID63'],
#  [0, 'ID67-ID15'],
#  [0, 'ID67-ID8'],
#  [0, 'ID67-ID75'],
#  [0, 'ID67-ID56'],
#  [0, 'ID67-ID32'],
#  [0, 'ID67-ID36'],
#  [0, 'ID67-ID58'],
#  [0, 'ID67-ID78'],
#  [0, 'ID67-ID84'],
#  [0, 'ID67-ID12'],
#  [0, 'ID67-ID66'],
#  [5.95, 'ID67-ID50'],
#  [0, 'ID67-ID38'],
#  [0, 'ID67-ID77'],
#  [1.63, 'ID67-ID16'],
#  [0, 'ID67-ID39'],
#  [6.11, 'ID67-ID62'],
#  [0.65, 'ID67-ID42'],
#  [0, 'ID67-ID74'],
#  [0, 'ID67-ID17'],
#  [0, 'ID67-ID70'],
#  [0, 'ID67-ID33'],
#  [0, 'ID67-ID85'],
#  [0, 'ID67-ID23'],
#  [0, 'ID67-ID3'],
#  [0, 'ID67-ID24'],
#  [0, 'ID67-ID79'],
#  [0, 'ID67-ID19'],
#  [0, 'ID67-ID48'],
#  [0, 'ID67-ID37'],
#  [0, 'ID67-ID87'],
#  [0, 'ID67-ID46'],
#  [0, 'ID67-ID10'],
#  [0, 'ID67-ID86'],
#  [0, 'ID67-ID61'],
#  [0, 'ID67-ID82'],
#  [7.27, 'ID67-ID90'],
#  [3.32, 'ID67-ID13'],
#  [0, 'ID67-ID18'],
#  [0, 'ID67-ID41'],
#  [0, 'ID67-ID81'],
#  [3.69, 'ID67-ID7'],
#  [0, 'ID67-ID14'],
#  [0, 'ID67-ID52'],
#  [0, 'ID67-ID68'],
#  [0, 'ID67-ID76'],
#  [1.06, 'ID67-ID53'],
#  [0, 'ID67-ID27'],
#  [0, 'ID67-ID20'],
#  [0.95, 'ID67-ID4'],
#  [0, 'ID67-ID22'],
#  [0, 'ID67-ID47'],
#  [0, 'ID67-ID44'],
#  [1.99, 'ID67-ID55'],
#  [0, 'ID67-ID43'],
#  [0, 'ID67-ID1'],
#  [0, 'ID67-ID21'],
#  [0, 'ID67-ID2'],
#  [0, 'ID67-ID60'],
#  [3.02, 'ID67-ID35'],
#  [0, 'ID67-ID30'],
#  [0, 'ID67-ID69'],
#  [0, 'ID67-ID73'],
#  [0, 'ID67-ID28'],
#  [0, 'ID67-ID64'],
#  [8.27, 'ID67-ID67'],
#  [0, 'ID67-ID34'],
#  [0, 'ID67-ID83'],
#  [0, 'ID67-ID51'],
#  [0, 'ID67-ID29'],
#  [0, 'ID67-ID72'],
#  [4.6, 'ID6-ID9'],
#  [0, 'ID6-ID65'],
#  [0, 'ID6-ID40'],
#  [0, 'ID6-ID31'],
#  [0, 'ID6-ID89'],
#  [0, 'ID6-ID49'],
#  [0, 'ID6-ID80'],
#  [0, 'ID6-ID5'],
#  [0, 'ID6-ID57'],
#  [0, 'ID6-ID26'],
#  [0, 'ID6-ID88'],
#  [0, 'ID6-ID25'],
#  [0, 'ID6-ID11'],
#  [0, 'ID6-ID54'],
#  [0, 'ID6-ID45'],
#  [0, 'ID6-ID59'],
#  [0, 'ID6-ID71'],
#  [0, 'ID6-ID63'],
#  [0, 'ID6-ID15'],
#  [0, 'ID6-ID8'],
#  [0, 'ID6-ID75'],
#  [0, 'ID6-ID56'],
#  [0, 'ID6-ID32'],
#  [0, 'ID6-ID36'],
#  [0, 'ID6-ID58'],
#  [0, 'ID6-ID78'],
#  [0, 'ID6-ID84'],
#  [0, 'ID6-ID12'],
#  [0, 'ID6-ID66'],
#  [0, 'ID6-ID50'],
#  [0, 'ID6-ID38'],
#  [0, 'ID6-ID77'],
#  [0, 'ID6-ID16'],
#  [0, 'ID6-ID39'],
#  [0, 'ID6-ID62'],
#  [0, 'ID6-ID42'],
#  [8.64, 'ID6-ID6'],
#  [0, 'ID6-ID74'],
#  [0, 'ID6-ID17'],
#  [0, 'ID6-ID70'],
#  [0, 'ID6-ID33'],
#  [0, 'ID6-ID85'],
#  [0, 'ID6-ID23'],
#  [0, 'ID6-ID3'],
#  [0, 'ID6-ID24'],
#  [0, 'ID6-ID79'],
#  [0, 'ID6-ID19'],
#  [0, 'ID6-ID48'],
#  [0, 'ID6-ID37'],
#  [0, 'ID6-ID87'],
#  [0, 'ID6-ID46'],
#  [0, 'ID6-ID10'],
#  [0, 'ID6-ID86'],
#  [0, 'ID6-ID61'],
#  [0, 'ID6-ID82'],
#  [0, 'ID6-ID90'],
#  [0, 'ID6-ID13'],
#  [0, 'ID6-ID18'],
#  [0, 'ID6-ID41'],
#  [0, 'ID6-ID81'],
#  [0, 'ID6-ID7'],
#  [0, 'ID6-ID14'],
#  [0, 'ID6-ID52'],
#  [0, 'ID6-ID68'],
#  [0, 'ID6-ID76'],
#  [0, 'ID6-ID53'],
#  [0, 'ID6-ID27'],
#  [0, 'ID6-ID20'],
#  [0, 'ID6-ID4'],
#  [0, 'ID6-ID22'],
#  [0, 'ID6-ID47'],
#  [0, 'ID6-ID44'],
#  [0, 'ID6-ID55'],
#  [0, 'ID6-ID43'],
#  [0, 'ID6-ID1'],
#  [0, 'ID6-ID21'],
#  [0, 'ID6-ID2'],
#  [0, 'ID6-ID60'],
#  [0, 'ID6-ID35'],
#  [0, 'ID6-ID30'],
#  [0, 'ID6-ID69'],
#  [0, 'ID6-ID73'],
#  [0, 'ID6-ID28'],
#  [0, 'ID6-ID64'],
#  [0, 'ID6-ID67'],
#  [0, 'ID6-ID34'],
#  [0, 'ID6-ID83'],
#  [0, 'ID6-ID51'],
#  [4.05, 'ID6-ID29'],
#  [0, 'ID6-ID72'],
#  [0, 'ID9-ID65'],
#  [0, 'ID9-ID40'],
#  [5.18, 'ID9-ID31'],
#  [0, 'ID9-ID89'],
#  [8.18, 'ID9-ID9'],
#  [0, 'ID9-ID49'],
#  [0, 'ID9-ID80'],
#  [0.78, 'ID9-ID5'],
#  [0, 'ID9-ID57'],
#  [0, 'ID9-ID26'],
#  [0, 'ID9-ID88'],
#  [0, 'ID9-ID25'],
#  [3.86, 'ID9-ID11'],
#  [0, 'ID9-ID54'],
#  [4.27, 'ID9-ID45'],
#  [0, 'ID9-ID59'],
#  [0, 'ID9-ID71'],
#  [0, 'ID9-ID63'],
#  [5.37, 'ID9-ID15'],
#  [5.48, 'ID9-ID8'],
#  [0, 'ID9-ID75'],
#  [0, 'ID9-ID56'],
#  [0, 'ID9-ID32'],
#  [0, 'ID9-ID36'],
#  [4.18, 'ID9-ID58'],
#  [0, 'ID9-ID78'],
#  [0, 'ID9-ID84'],
#  [0, 'ID9-ID12'],
#  [1.63, 'ID9-ID66'],
#  [0, 'ID9-ID50'],
#  [0, 'ID9-ID38'],
#  [0, 'ID9-ID77'],
#  [0, 'ID9-ID16'],
#  [0, 'ID9-ID39'],
#  [0, 'ID9-ID62'],
#  [0, 'ID9-ID42'],
#  [4.6, 'ID9-ID6'],
#  [7.01, 'ID9-ID74'],
#  [0, 'ID9-ID17'],
#  [0, 'ID9-ID70'],
#  [4.01, 'ID9-ID33'],
#  [0, 'ID9-ID85'],
#  [4.01, 'ID9-ID23'],
#  [0, 'ID9-ID3'],
#  [7.26, 'ID9-ID24'],
#  [0, 'ID9-ID79'],
#  [4.48, 'ID9-ID19'],
#  [0, 'ID9-ID48'],
#  [3.54, 'ID9-ID37'],
#  [0, 'ID9-ID87'],
#  [0, 'ID9-ID46'],
#  [4.27, 'ID9-ID10'],
#  [0, 'ID9-ID86'],
#  [0, 'ID9-ID61'],
#  [0, 'ID9-ID82'],
#  [0, 'ID9-ID90'],
#  [6.23, 'ID9-ID13'],
#  [0, 'ID9-ID18'],
#  [0, 'ID9-ID41'],
#  [0, 'ID9-ID81'],
#  [0, 'ID9-ID7'],
#  [5.37, 'ID9-ID14'],
#  [0, 'ID9-ID52'],
#  [0, 'ID9-ID68'],
#  [5.37, 'ID9-ID76'],
#  [0, 'ID9-ID53'],
#  [0, 'ID9-ID27'],
#  [4.89, 'ID9-ID20'],
#  [3.18, 'ID9-ID4'],
#  [0, 'ID9-ID22'],
#  [0, 'ID9-ID47'],
#  [0, 'ID9-ID44'],
#  [0, 'ID9-ID55'],
#  [6.6, 'ID9-ID43'],
#  [1.52, 'ID9-ID1'],
#  [0, 'ID9-ID21'],
#  [2.93, 'ID9-ID2'],
#  [0, 'ID9-ID60'],
#  [0, 'ID9-ID35'],
#  [0, 'ID9-ID30'],
#  [5.86, 'ID9-ID69'],
#  [0, 'ID9-ID73'],
#  [4.86, 'ID9-ID28'],
#  [0, 'ID9-ID64'],
#  [0, 'ID9-ID67'],
#  [0, 'ID9-ID34'],
#  [0, 'ID9-ID83'],
#  [0, 'ID9-ID51'],
#  [5.92, 'ID9-ID29'],
#  [0, 'ID9-ID72'],
#  [0, 'ID65-ID40'],
#  [0, 'ID65-ID31'],
#  [0, 'ID65-ID89'],
#  [0, 'ID65-ID9'],
#  [0, 'ID65-ID49'],
#  [0, 'ID65-ID80'],
#  [0, 'ID65-ID5'],
#  [0, 'ID65-ID57'],
#  [0, 'ID65-ID26'],
#  [0, 'ID65-ID88'],
#  ...]

# %%
entity_names = [str(entity).split('-') for entity in list(new_entitys_pmis.keys())]
idxs = [str(idx[1]).split('-') for idx in entity_values]
sims = [i[0] for i in entity_values]

# %%
entity_names
# Out:
# [['海滨公园', '叉烧饭'],
#  ['海滨公园', '脆皮热狗卷'],
#  ['海滨公园', '榴莲千层'],
#  ['海滨公园', '御水古温泉'],
#  ['海滨公园', '大角湾'],
#  ['海滨公园', '雅米乐园'],
#  ['海滨公园', '甜点'],
#  ['海滨公园', '蛋挞'],
#  ['海滨公园', '文化广场'],
#  ['海滨公园', '小东江'],
#  ['海滨公园', '拉面'],
#  ['海滨公园', '东南码头'],
#  ['海滨公园', '骑楼'],
#  ['海滨公园', '凉拌菜'],
#  ['海滨公园', '甜品'],
#  ['海滨公园', 'UNPOCO柏蔻'],
#  ['海滨公园', '沙滩'],
#  ['海滨公园', '烧鸭饭'],
#  ['海滨公园', '海滨公园'],
#  ['海滨公园', '煲仔饭'],
#  ['海滨公园', '北洛湾'],
#  ['海滨公园', '面包'],
#  ['海滨公园', '水东湾'],
#  ['海滨公园', '炸鸡'],
#  ['海滨公园', '火腿'],
#  ['海滨公园', '肉松'],
#  ['海滨公园', '东湖'],
#  ['海滨公园', 'I'],
#  ['海滨公园', '黄油'],
#  ['海滨公园', '三元塔'],
#  ['海滨公园', '湖光岩'],
#  ['海滨公园', '蔬菜'],
#  ['海滨公园', '日式蟹肉卷'],
#  ['海滨公园', '油条碎'],
#  ['海滨公园', '牛肉'],
#  ['海滨公园', '小炒'],
#  ['海滨公园', '野菠萝公园'],
#  ['海滨公园', '和牛盖饭'],
#  ['海滨公园', '饮料'],
#  ['海滨公园', '温德姆酒店'],
#  ['海滨公园', '泡芙'],
#  ['海滨公园', '牛排'],
#  ['海滨公园', '牛肚'],
#  ['海滨公园', '晏镜岭'],
#  ['海滨公园', '刺身'],
#  ['海滨公园', '自助菜'],
#  ['海滨公园', '游乐场'],
#  ['海滨公园', '中心广场'],
#  ['海滨公园', '摩天轮'],
#  ['海滨公园', '高钙大骨鸳鸯锅'],
#  ['海滨公园', '天马山'],
#  ['海滨公园', '赤坎老街'],
#  ['海滨公园', '玉湖'],
#  ['海滨公园', '菠萝皮'],
#  ['海滨公园', '热狗'],
#  ['海滨公园', '红树林'],
#  ['海滨公园', '菠萝包'],
#  ['海滨公园', '米饭'],
#  ['海滨公园', '无花果'],
#  ['海滨公园', '关东煮'],
#  ['海滨公园', '荔枝'],
#  ['海滨公园', '架海灯塔'],
#  ['海滨公园', '望海楼'],
#  ['海滨公园', '无花果萨拉米披萨'],
#  ['海滨公园', '早茶'],
#  ['海滨公园', '红树林栈道'],
#  ['海滨公园', '榴莲蛋糕'],
#  ['海滨公园', '炒乌冬'],
#  ['海滨公园', '酱汁'],
#  ['海滨公园', '奶油'],
#  ['海滨公园', '博物馆'],
#  ['海滨公园', '海鲜'],
#  ['海滨公园', '海陵岛'],
#  ['海滨公园', '高州仙人洞景区'],
#  ['海滨公园', '湛江大桥'],
#  ['海滨公园', '寿司'],
#  ['海滨公园', '新湖公园'],
#  ['海滨公园', '海滩'],
#  ['海滨公园', '玻璃桥'],
#  ['海滨公园', '第一滩'],
#  ['海滨公园', '蜂蜜芥末'],
#  ['海滨公园', '生蚝'],
#  ['海滨公园', '十里军港'],
#  ['海滨公园', '凤梨'],
#  ['海滨公园', '炒牛河'],
#  ['海滨公园', '露天矿生态公园'],
#  ['海滨公园', '薯条'],
#  ['海滨公园', '雷州古城'],
#  ['海滨公园', '粗薯'],
#  ['海滨公园', '露天矿'],
#  ['叉烧饭', '脆皮热狗卷'],
#  ['叉烧饭', '榴莲千层'],
#  ['叉烧饭', '御水古温泉'],
#  ['叉烧饭', '大角湾'],
#  ['叉烧饭', '雅米乐园'],
#  ['叉烧饭', '甜点'],
#  ['叉烧饭', '蛋挞'],
#  ['叉烧饭', '文化广场'],
#  ['叉烧饭', '小东江'],
#  ['叉烧饭', '拉面'],
#  ['叉烧饭', '东南码头'],
#  ['叉烧饭', '骑楼'],
#  ['叉烧饭', '凉拌菜'],
#  ['叉烧饭', '甜品'],
#  ['叉烧饭', 'UNPOCO柏蔻'],
#  ['叉烧饭', '沙滩'],
#  ['叉烧饭', '烧鸭饭'],
#  ['叉烧饭', '海滨公园'],
#  ['叉烧饭', '煲仔饭'],
#  ['叉烧饭', '北洛湾'],
#  ['叉烧饭', '面包'],
#  ['叉烧饭', '水东湾'],
#  ['叉烧饭', '炸鸡'],
#  ['叉烧饭', '火腿'],
#  ['叉烧饭', '肉松'],
#  ['叉烧饭', '东湖'],
#  ['叉烧饭', 'I'],
#  ['叉烧饭', '黄油'],
#  ['叉烧饭', '叉烧饭'],
#  ['叉烧饭', '三元塔'],
#  ['叉烧饭', '湖光岩'],
#  ['叉烧饭', '蔬菜'],
#  ['叉烧饭', '日式蟹肉卷'],
#  ['叉烧饭', '油条碎'],
#  ['叉烧饭', '牛肉'],
#  ['叉烧饭', '小炒'],
#  ['叉烧饭', '野菠萝公园'],
#  ['叉烧饭', '和牛盖饭'],
#  ['叉烧饭', '饮料'],
#  ['叉烧饭', '温德姆酒店'],
#  ['叉烧饭', '泡芙'],
#  ['叉烧饭', '牛排'],
#  ['叉烧饭', '牛肚'],
#  ['叉烧饭', '晏镜岭'],
#  ['叉烧饭', '刺身'],
#  ['叉烧饭', '自助菜'],
#  ['叉烧饭', '游乐场'],
#  ['叉烧饭', '中心广场'],
#  ['叉烧饭', '摩天轮'],
#  ['叉烧饭', '高钙大骨鸳鸯锅'],
#  ['叉烧饭', '天马山'],
#  ['叉烧饭', '赤坎老街'],
#  ['叉烧饭', '玉湖'],
#  ['叉烧饭', '菠萝皮'],
#  ['叉烧饭', '热狗'],
#  ['叉烧饭', '红树林'],
#  ['叉烧饭', '菠萝包'],
#  ['叉烧饭', '米饭'],
#  ['叉烧饭', '无花果'],
#  ['叉烧饭', '关东煮'],
#  ['叉烧饭', '荔枝'],
#  ['叉烧饭', '架海灯塔'],
#  ['叉烧饭', '望海楼'],
#  ['叉烧饭', '无花果萨拉米披萨'],
#  ['叉烧饭', '早茶'],
#  ['叉烧饭', '红树林栈道'],
#  ['叉烧饭', '榴莲蛋糕'],
#  ['叉烧饭', '炒乌冬'],
#  ['叉烧饭', '酱汁'],
#  ['叉烧饭', '奶油'],
#  ['叉烧饭', '博物馆'],
#  ['叉烧饭', '海鲜'],
#  ['叉烧饭', '海陵岛'],
#  ['叉烧饭', '高州仙人洞景区'],
#  ['叉烧饭', '湛江大桥'],
#  ['叉烧饭', '寿司'],
#  ['叉烧饭', '新湖公园'],
#  ['叉烧饭', '海滩'],
#  ['叉烧饭', '玻璃桥'],
#  ['叉烧饭', '第一滩'],
#  ['叉烧饭', '蜂蜜芥末'],
#  ['叉烧饭', '生蚝'],
#  ['叉烧饭', '十里军港'],
#  ['叉烧饭', '凤梨'],
#  ['叉烧饭', '炒牛河'],
#  ['叉烧饭', '露天矿生态公园'],
#  ['叉烧饭', '薯条'],
#  ['叉烧饭', '雷州古城'],
#  ['叉烧饭', '粗薯'],
#  ['叉烧饭', '露天矿'],
#  ['脆皮热狗卷', '榴莲千层'],
#  ['脆皮热狗卷', '御水古温泉'],
#  ['脆皮热狗卷', '大角湾'],
#  ['脆皮热狗卷', '雅米乐园'],
#  ['脆皮热狗卷', '甜点'],
#  ['脆皮热狗卷', '蛋挞'],
#  ['脆皮热狗卷', '文化广场'],
#  ['脆皮热狗卷', '小东江'],
#  ['脆皮热狗卷', '拉面'],
#  ['脆皮热狗卷', '东南码头'],
#  ['脆皮热狗卷', '骑楼'],
#  ['脆皮热狗卷', '凉拌菜'],
#  ['脆皮热狗卷', '甜品'],
#  ['脆皮热狗卷', 'UNPOCO柏蔻'],
#  ['脆皮热狗卷', '沙滩'],
#  ['脆皮热狗卷', '烧鸭饭'],
#  ['脆皮热狗卷', '海滨公园'],
#  ['脆皮热狗卷', '煲仔饭'],
#  ['脆皮热狗卷', '北洛湾'],
#  ['脆皮热狗卷', '面包'],
#  ['脆皮热狗卷', '水东湾'],
#  ['脆皮热狗卷', '炸鸡'],
#  ['脆皮热狗卷', '火腿'],
#  ['脆皮热狗卷', '肉松'],
#  ['脆皮热狗卷', '东湖'],
#  ['脆皮热狗卷', 'I'],
#  ['脆皮热狗卷', '黄油'],
#  ['脆皮热狗卷', '叉烧饭'],
#  ['脆皮热狗卷', '三元塔'],
#  ['脆皮热狗卷', '湖光岩'],
#  ['脆皮热狗卷', '蔬菜'],
#  ['脆皮热狗卷', '日式蟹肉卷'],
#  ['脆皮热狗卷', '油条碎'],
#  ['脆皮热狗卷', '牛肉'],
#  ['脆皮热狗卷', '小炒'],
#  ['脆皮热狗卷', '野菠萝公园'],
#  ['脆皮热狗卷', '和牛盖饭'],
#  ['脆皮热狗卷', '饮料'],
#  ['脆皮热狗卷', '温德姆酒店'],
#  ['脆皮热狗卷', '泡芙'],
#  ['脆皮热狗卷', '牛排'],
#  ['脆皮热狗卷', '牛肚'],
#  ['脆皮热狗卷', '晏镜岭'],
#  ['脆皮热狗卷', '刺身'],
#  ['脆皮热狗卷', '自助菜'],
#  ['脆皮热狗卷', '游乐场'],
#  ['脆皮热狗卷', '中心广场'],
#  ['脆皮热狗卷', '摩天轮'],
#  ['脆皮热狗卷', '高钙大骨鸳鸯锅'],
#  ['脆皮热狗卷', '天马山'],
#  ['脆皮热狗卷', '赤坎老街'],
#  ['脆皮热狗卷', '玉湖'],
#  ['脆皮热狗卷', '菠萝皮'],
#  ['脆皮热狗卷', '热狗'],
#  ['脆皮热狗卷', '红树林'],
#  ['脆皮热狗卷', '菠萝包'],
#  ['脆皮热狗卷', '米饭'],
#  ['脆皮热狗卷', '无花果'],
#  ['脆皮热狗卷', '关东煮'],
#  ['脆皮热狗卷', '荔枝'],
#  ['脆皮热狗卷', '架海灯塔'],
#  ['脆皮热狗卷', '望海楼'],
#  ['脆皮热狗卷', '无花果萨拉米披萨'],
#  ['脆皮热狗卷', '早茶'],
#  ['脆皮热狗卷', '红树林栈道'],
#  ['脆皮热狗卷', '榴莲蛋糕'],
#  ['脆皮热狗卷', '炒乌冬'],
#  ['脆皮热狗卷', '酱汁'],
#  ['脆皮热狗卷', '奶油'],
#  ['脆皮热狗卷', '博物馆'],
#  ['脆皮热狗卷', '海鲜'],
#  ['脆皮热狗卷', '海陵岛'],
#  ['脆皮热狗卷', '高州仙人洞景区'],
#  ['脆皮热狗卷', '湛江大桥'],
#  ['脆皮热狗卷', '寿司'],
#  ['脆皮热狗卷', '新湖公园'],
#  ['脆皮热狗卷', '海滩'],
#  ['脆皮热狗卷', '玻璃桥'],
#  ['脆皮热狗卷', '第一滩'],
#  ['脆皮热狗卷', '蜂蜜芥末'],
#  ['脆皮热狗卷', '生蚝'],
#  ['脆皮热狗卷', '十里军港'],
#  ['脆皮热狗卷', '凤梨'],
#  ['脆皮热狗卷', '炒牛河'],
#  ['脆皮热狗卷', '露天矿生态公园'],
#  ['脆皮热狗卷', '薯条'],
#  ['脆皮热狗卷', '雷州古城'],
#  ['脆皮热狗卷', '粗薯'],
#  ['脆皮热狗卷', '露天矿'],
#  ['脆皮热狗卷', '脆皮热狗卷'],
#  ['榴莲千层', '御水古温泉'],
#  ['榴莲千层', '大角湾'],
#  ['榴莲千层', '雅米乐园'],
#  ['榴莲千层', '甜点'],
#  ['榴莲千层', '蛋挞'],
#  ['榴莲千层', '文化广场'],
#  ['榴莲千层', '小东江'],
#  ['榴莲千层', '拉面'],
#  ['榴莲千层', '东南码头'],
#  ['榴莲千层', '骑楼'],
#  ['榴莲千层', '凉拌菜'],
#  ['榴莲千层', '甜品'],
#  ['榴莲千层', 'UNPOCO柏蔻'],
#  ['榴莲千层', '沙滩'],
#  ['榴莲千层', '烧鸭饭'],
#  ['榴莲千层', '海滨公园'],
#  ['榴莲千层', '煲仔饭'],
#  ['榴莲千层', '北洛湾'],
#  ['榴莲千层', '面包'],
#  ['榴莲千层', '榴莲千层'],
#  ['榴莲千层', '水东湾'],
#  ['榴莲千层', '炸鸡'],
#  ['榴莲千层', '火腿'],
#  ['榴莲千层', '肉松'],
#  ['榴莲千层', '东湖'],
#  ['榴莲千层', 'I'],
#  ['榴莲千层', '黄油'],
#  ['榴莲千层', '叉烧饭'],
#  ['榴莲千层', '三元塔'],
#  ['榴莲千层', '湖光岩'],
#  ['榴莲千层', '蔬菜'],
#  ['榴莲千层', '日式蟹肉卷'],
#  ['榴莲千层', '油条碎'],
#  ['榴莲千层', '牛肉'],
#  ['榴莲千层', '小炒'],
#  ['榴莲千层', '野菠萝公园'],
#  ['榴莲千层', '和牛盖饭'],
#  ['榴莲千层', '饮料'],
#  ['榴莲千层', '温德姆酒店'],
#  ['榴莲千层', '泡芙'],
#  ['榴莲千层', '牛排'],
#  ['榴莲千层', '牛肚'],
#  ['榴莲千层', '晏镜岭'],
#  ['榴莲千层', '刺身'],
#  ['榴莲千层', '自助菜'],
#  ['榴莲千层', '游乐场'],
#  ['榴莲千层', '中心广场'],
#  ['榴莲千层', '摩天轮'],
#  ['榴莲千层', '高钙大骨鸳鸯锅'],
#  ['榴莲千层', '天马山'],
#  ['榴莲千层', '赤坎老街'],
#  ['榴莲千层', '玉湖'],
#  ['榴莲千层', '菠萝皮'],
#  ['榴莲千层', '热狗'],
#  ['榴莲千层', '红树林'],
#  ['榴莲千层', '菠萝包'],
#  ['榴莲千层', '米饭'],
#  ['榴莲千层', '无花果'],
#  ['榴莲千层', '关东煮'],
#  ['榴莲千层', '荔枝'],
#  ['榴莲千层', '架海灯塔'],
#  ['榴莲千层', '望海楼'],
#  ['榴莲千层', '无花果萨拉米披萨'],
#  ['榴莲千层', '早茶'],
#  ['榴莲千层', '红树林栈道'],
#  ['榴莲千层', '榴莲蛋糕'],
#  ['榴莲千层', '炒乌冬'],
#  ['榴莲千层', '酱汁'],
#  ['榴莲千层', '奶油'],
#  ['榴莲千层', '博物馆'],
#  ['榴莲千层', '海鲜'],
#  ['榴莲千层', '海陵岛'],
#  ['榴莲千层', '高州仙人洞景区'],
#  ['榴莲千层', '湛江大桥'],
#  ['榴莲千层', '寿司'],
#  ['榴莲千层', '新湖公园'],
#  ['榴莲千层', '海滩'],
#  ['榴莲千层', '玻璃桥'],
#  ['榴莲千层', '第一滩'],
#  ['榴莲千层', '蜂蜜芥末'],
#  ['榴莲千层', '生蚝'],
#  ['榴莲千层', '十里军港'],
#  ['榴莲千层', '凤梨'],
#  ['榴莲千层', '炒牛河'],
#  ['榴莲千层', '露天矿生态公园'],
#  ['榴莲千层', '薯条'],
#  ['榴莲千层', '雷州古城'],
#  ['榴莲千层', '粗薯'],
#  ['榴莲千层', '露天矿'],
#  ['榴莲千层', '脆皮热狗卷'],
#  ['御水古温泉', '大角湾'],
#  ['御水古温泉', '雅米乐园'],
#  ['御水古温泉', '甜点'],
#  ['御水古温泉', '蛋挞'],
#  ['御水古温泉', '文化广场'],
#  ['御水古温泉', '小东江'],
#  ['御水古温泉', '拉面'],
#  ['御水古温泉', '东南码头'],
#  ['御水古温泉', '骑楼'],
#  ['御水古温泉', '凉拌菜'],
#  ['御水古温泉', '甜品'],
#  ['御水古温泉', 'UNPOCO柏蔻'],
#  ['御水古温泉', '沙滩'],
#  ['御水古温泉', '烧鸭饭'],
#  ['御水古温泉', '海滨公园'],
#  ['御水古温泉', '煲仔饭'],
#  ['御水古温泉', '北洛湾'],
#  ['御水古温泉', '面包'],
#  ['御水古温泉', '榴莲千层'],
#  ['御水古温泉', '水东湾'],
#  ['御水古温泉', '炸鸡'],
#  ['御水古温泉', '火腿'],
#  ['御水古温泉', '肉松'],
#  ['御水古温泉', '东湖'],
#  ['御水古温泉', 'I'],
#  ['御水古温泉', '黄油'],
#  ['御水古温泉', '叉烧饭'],
#  ['御水古温泉', '三元塔'],
#  ['御水古温泉', '湖光岩'],
#  ['御水古温泉', '蔬菜'],
#  ['御水古温泉', '日式蟹肉卷'],
#  ['御水古温泉', '油条碎'],
#  ['御水古温泉', '牛肉'],
#  ['御水古温泉', '小炒'],
#  ['御水古温泉', '野菠萝公园'],
#  ['御水古温泉', '和牛盖饭'],
#  ['御水古温泉', '饮料'],
#  ['御水古温泉', '温德姆酒店'],
#  ['御水古温泉', '泡芙'],
#  ['御水古温泉', '牛排'],
#  ['御水古温泉', '牛肚'],
#  ['御水古温泉', '晏镜岭'],
#  ['御水古温泉', '刺身'],
#  ['御水古温泉', '御水古温泉'],
#  ['御水古温泉', '自助菜'],
#  ['御水古温泉', '游乐场'],
#  ['御水古温泉', '中心广场'],
#  ['御水古温泉', '摩天轮'],
#  ['御水古温泉', '高钙大骨鸳鸯锅'],
#  ['御水古温泉', '天马山'],
#  ['御水古温泉', '赤坎老街'],
#  ['御水古温泉', '玉湖'],
#  ['御水古温泉', '菠萝皮'],
#  ['御水古温泉', '热狗'],
#  ['御水古温泉', '红树林'],
#  ['御水古温泉', '菠萝包'],
#  ['御水古温泉', '米饭'],
#  ['御水古温泉', '无花果'],
#  ['御水古温泉', '关东煮'],
#  ['御水古温泉', '荔枝'],
#  ['御水古温泉', '架海灯塔'],
#  ['御水古温泉', '望海楼'],
#  ['御水古温泉', '无花果萨拉米披萨'],
#  ['御水古温泉', '早茶'],
#  ['御水古温泉', '红树林栈道'],
#  ['御水古温泉', '榴莲蛋糕'],
#  ['御水古温泉', '炒乌冬'],
#  ['御水古温泉', '酱汁'],
#  ['御水古温泉', '奶油'],
#  ['御水古温泉', '博物馆'],
#  ['御水古温泉', '海鲜'],
#  ['御水古温泉', '海陵岛'],
#  ['御水古温泉', '高州仙人洞景区'],
#  ['御水古温泉', '湛江大桥'],
#  ['御水古温泉', '寿司'],
#  ['御水古温泉', '新湖公园'],
#  ['御水古温泉', '海滩'],
#  ['御水古温泉', '玻璃桥'],
#  ['御水古温泉', '第一滩'],
#  ['御水古温泉', '蜂蜜芥末'],
#  ['御水古温泉', '生蚝'],
#  ['御水古温泉', '十里军港'],
#  ['御水古温泉', '凤梨'],
#  ['御水古温泉', '炒牛河'],
#  ['御水古温泉', '露天矿生态公园'],
#  ['御水古温泉', '薯条'],
#  ['御水古温泉', '雷州古城'],
#  ['御水古温泉', '粗薯'],
#  ['御水古温泉', '露天矿'],
#  ['御水古温泉', '脆皮热狗卷'],
#  ['大角湾', '雅米乐园'],
#  ['大角湾', '甜点'],
#  ['大角湾', '蛋挞'],
#  ['大角湾', '文化广场'],
#  ['大角湾', '小东江'],
#  ['大角湾', '拉面'],
#  ['大角湾', '东南码头'],
#  ['大角湾', '骑楼'],
#  ['大角湾', '凉拌菜'],
#  ['大角湾', '甜品'],
#  ['大角湾', 'UNPOCO柏蔻'],
#  ['大角湾', '沙滩'],
#  ['大角湾', '烧鸭饭'],
#  ['大角湾', '海滨公园'],
#  ['大角湾', '煲仔饭'],
#  ['大角湾', '北洛湾'],
#  ['大角湾', '面包'],
#  ['大角湾', '榴莲千层'],
#  ['大角湾', '水东湾'],
#  ['大角湾', '炸鸡'],
#  ['大角湾', '火腿'],
#  ['大角湾', '肉松'],
#  ['大角湾', '东湖'],
#  ['大角湾', 'I'],
#  ['大角湾', '黄油'],
#  ['大角湾', '叉烧饭'],
#  ['大角湾', '三元塔'],
#  ['大角湾', '湖光岩'],
#  ['大角湾', '蔬菜'],
#  ['大角湾', '日式蟹肉卷'],
#  ['大角湾', '油条碎'],
#  ['大角湾', '牛肉'],
#  ['大角湾', '小炒'],
#  ['大角湾', '野菠萝公园'],
#  ['大角湾', '和牛盖饭'],
#  ['大角湾', '饮料'],
#  ['大角湾', '温德姆酒店'],
#  ['大角湾', '泡芙'],
#  ['大角湾', '牛排'],
#  ['大角湾', '牛肚'],
#  ['大角湾', '晏镜岭'],
#  ['大角湾', '刺身'],
#  ['大角湾', '御水古温泉'],
#  ['大角湾', '自助菜'],
#  ['大角湾', '游乐场'],
#  ['大角湾', '中心广场'],
#  ['大角湾', '摩天轮'],
#  ['大角湾', '高钙大骨鸳鸯锅'],
#  ['大角湾', '天马山'],
#  ['大角湾', '赤坎老街'],
#  ['大角湾', '玉湖'],
#  ['大角湾', '菠萝皮'],
#  ['大角湾', '热狗'],
#  ['大角湾', '红树林'],
#  ['大角湾', '菠萝包'],
#  ['大角湾', '米饭'],
#  ['大角湾', '无花果'],
#  ['大角湾', '关东煮'],
#  ['大角湾', '荔枝'],
#  ['大角湾', '架海灯塔'],
#  ['大角湾', '望海楼'],
#  ['大角湾', '无花果萨拉米披萨'],
#  ['大角湾', '早茶'],
#  ['大角湾', '红树林栈道'],
#  ['大角湾', '榴莲蛋糕'],
#  ['大角湾', '炒乌冬'],
#  ['大角湾', '酱汁'],
#  ['大角湾', '奶油'],
#  ['大角湾', '大角湾'],
#  ['大角湾', '博物馆'],
#  ['大角湾', '海鲜'],
#  ['大角湾', '海陵岛'],
#  ['大角湾', '高州仙人洞景区'],
#  ['大角湾', '湛江大桥'],
#  ['大角湾', '寿司'],
#  ['大角湾', '新湖公园'],
#  ['大角湾', '海滩'],
#  ['大角湾', '玻璃桥'],
#  ['大角湾', '第一滩'],
#  ['大角湾', '蜂蜜芥末'],
#  ['大角湾', '生蚝'],
#  ['大角湾', '十里军港'],
#  ['大角湾', '凤梨'],
#  ['大角湾', '炒牛河'],
#  ['大角湾', '露天矿生态公园'],
#  ['大角湾', '薯条'],
#  ['大角湾', '雷州古城'],
#  ['大角湾', '粗薯'],
#  ['大角湾', '露天矿'],
#  ['大角湾', '脆皮热狗卷'],
#  ['雅米乐园', '甜点'],
#  ['雅米乐园', '蛋挞'],
#  ['雅米乐园', '文化广场'],
#  ['雅米乐园', '小东江'],
#  ['雅米乐园', '拉面'],
#  ['雅米乐园', '东南码头'],
#  ['雅米乐园', '骑楼'],
#  ['雅米乐园', '凉拌菜'],
#  ['雅米乐园', '甜品'],
#  ['雅米乐园', 'UNPOCO柏蔻'],
#  ['雅米乐园', '沙滩'],
#  ['雅米乐园', '烧鸭饭'],
#  ['雅米乐园', '海滨公园'],
#  ['雅米乐园', '煲仔饭'],
#  ['雅米乐园', '北洛湾'],
#  ['雅米乐园', '面包'],
#  ['雅米乐园', '榴莲千层'],
#  ['雅米乐园', '水东湾'],
#  ['雅米乐园', '炸鸡'],
#  ['雅米乐园', '火腿'],
#  ['雅米乐园', '肉松'],
#  ['雅米乐园', '东湖'],
#  ['雅米乐园', 'I'],
#  ['雅米乐园', '黄油'],
#  ['雅米乐园', '叉烧饭'],
#  ['雅米乐园', '三元塔'],
#  ['雅米乐园', '湖光岩'],
#  ['雅米乐园', '蔬菜'],
#  ['雅米乐园', '日式蟹肉卷'],
#  ['雅米乐园', '油条碎'],
#  ['雅米乐园', '牛肉'],
#  ['雅米乐园', '小炒'],
#  ['雅米乐园', '野菠萝公园'],
#  ['雅米乐园', '和牛盖饭'],
#  ['雅米乐园', '饮料'],
#  ['雅米乐园', '温德姆酒店'],
#  ['雅米乐园', '泡芙'],
#  ['雅米乐园', '牛排'],
#  ['雅米乐园', '牛肚'],
#  ['雅米乐园', '晏镜岭'],
#  ['雅米乐园', '刺身'],
#  ['雅米乐园', '御水古温泉'],
#  ['雅米乐园', '自助菜'],
#  ['雅米乐园', '游乐场'],
#  ['雅米乐园', '中心广场'],
#  ['雅米乐园', '摩天轮'],
#  ['雅米乐园', '高钙大骨鸳鸯锅'],
#  ['雅米乐园', '天马山'],
#  ['雅米乐园', '赤坎老街'],
#  ['雅米乐园', '玉湖'],
#  ['雅米乐园', '菠萝皮'],
#  ['雅米乐园', '热狗'],
#  ['雅米乐园', '红树林'],
#  ['雅米乐园', '菠萝包'],
#  ['雅米乐园', '米饭'],
#  ['雅米乐园', '无花果'],
#  ['雅米乐园', '关东煮'],
#  ['雅米乐园', '荔枝'],
#  ['雅米乐园', '架海灯塔'],
#  ['雅米乐园', '望海楼'],
#  ['雅米乐园', '无花果萨拉米披萨'],
#  ['雅米乐园', '早茶'],
#  ['雅米乐园', '红树林栈道'],
#  ['雅米乐园', '榴莲蛋糕'],
#  ['雅米乐园', '炒乌冬'],
#  ['雅米乐园', '酱汁'],
#  ['雅米乐园', '奶油'],
#  ['雅米乐园', '大角湾'],
#  ['雅米乐园', '博物馆'],
#  ['雅米乐园', '海鲜'],
#  ['雅米乐园', '海陵岛'],
#  ['雅米乐园', '高州仙人洞景区'],
#  ['雅米乐园', '湛江大桥'],
#  ['雅米乐园', '寿司'],
#  ['雅米乐园', '新湖公园'],
#  ['雅米乐园', '海滩'],
#  ['雅米乐园', '玻璃桥'],
#  ['雅米乐园', '第一滩'],
#  ['雅米乐园', '蜂蜜芥末'],
#  ['雅米乐园', '生蚝'],
#  ['雅米乐园', '十里军港'],
#  ['雅米乐园', '凤梨'],
#  ['雅米乐园', '炒牛河'],
#  ['雅米乐园', '露天矿生态公园'],
#  ['雅米乐园', '薯条'],
#  ['雅米乐园', '雷州古城'],
#  ['雅米乐园', '粗薯'],
#  ['雅米乐园', '雅米乐园'],
#  ['雅米乐园', '露天矿'],
#  ['雅米乐园', '脆皮热狗卷'],
#  ['甜点', '蛋挞'],
#  ['甜点', '文化广场'],
#  ['甜点', '小东江'],
#  ['甜点', '拉面'],
#  ['甜点', '东南码头'],
#  ['甜点', '骑楼'],
#  ['甜点', '凉拌菜'],
#  ['甜点', '甜品'],
#  ['甜点', 'UNPOCO柏蔻'],
#  ['甜点', '沙滩'],
#  ['甜点', '烧鸭饭'],
#  ['甜点', '海滨公园'],
#  ['甜点', '煲仔饭'],
#  ['甜点', '北洛湾'],
#  ['甜点', '面包'],
#  ['甜点', '榴莲千层'],
#  ['甜点', '水东湾'],
#  ['甜点', '炸鸡'],
#  ['甜点', '火腿'],
#  ['甜点', '肉松'],
#  ['甜点', '东湖'],
#  ['甜点', 'I'],
#  ['甜点', '黄油'],
#  ['甜点', '叉烧饭'],
#  ['甜点', '三元塔'],
#  ['甜点', '湖光岩'],
#  ['甜点', '蔬菜'],
#  ['甜点', '日式蟹肉卷'],
#  ['甜点', '油条碎'],
#  ['甜点', '甜点'],
#  ['甜点', '牛肉'],
#  ['甜点', '小炒'],
#  ['甜点', '野菠萝公园'],
#  ['甜点', '和牛盖饭'],
#  ['甜点', '饮料'],
#  ['甜点', '温德姆酒店'],
#  ['甜点', '泡芙'],
#  ['甜点', '牛排'],
#  ['甜点', '牛肚'],
#  ['甜点', '晏镜岭'],
#  ['甜点', '刺身'],
#  ['甜点', '御水古温泉'],
#  ['甜点', '自助菜'],
#  ['甜点', '游乐场'],
#  ['甜点', '中心广场'],
#  ['甜点', '摩天轮'],
#  ['甜点', '高钙大骨鸳鸯锅'],
#  ['甜点', '天马山'],
#  ['甜点', '赤坎老街'],
#  ['甜点', '玉湖'],
#  ['甜点', '菠萝皮'],
#  ['甜点', '热狗'],
#  ['甜点', '红树林'],
#  ['甜点', '菠萝包'],
#  ['甜点', '米饭'],
#  ['甜点', '无花果'],
#  ['甜点', '关东煮'],
#  ['甜点', '荔枝'],
#  ['甜点', '架海灯塔'],
#  ['甜点', '望海楼'],
#  ['甜点', '无花果萨拉米披萨'],
#  ['甜点', '早茶'],
#  ['甜点', '红树林栈道'],
#  ['甜点', '榴莲蛋糕'],
#  ['甜点', '炒乌冬'],
#  ['甜点', '酱汁'],
#  ['甜点', '奶油'],
#  ['甜点', '大角湾'],
#  ['甜点', '博物馆'],
#  ['甜点', '海鲜'],
#  ['甜点', '海陵岛'],
#  ['甜点', '高州仙人洞景区'],
#  ['甜点', '湛江大桥'],
#  ['甜点', '寿司'],
#  ['甜点', '新湖公园'],
#  ['甜点', '海滩'],
#  ['甜点', '玻璃桥'],
#  ['甜点', '第一滩'],
#  ['甜点', '蜂蜜芥末'],
#  ['甜点', '生蚝'],
#  ['甜点', '十里军港'],
#  ['甜点', '凤梨'],
#  ['甜点', '炒牛河'],
#  ['甜点', '露天矿生态公园'],
#  ['甜点', '薯条'],
#  ['甜点', '雷州古城'],
#  ['甜点', '粗薯'],
#  ['甜点', '雅米乐园'],
#  ['甜点', '露天矿'],
#  ['甜点', '脆皮热狗卷'],
#  ['蛋挞', '文化广场'],
#  ['蛋挞', '小东江'],
#  ['蛋挞', '拉面'],
#  ['蛋挞', '东南码头'],
#  ['蛋挞', '骑楼'],
#  ['蛋挞', '凉拌菜'],
#  ['蛋挞', '甜品'],
#  ['蛋挞', 'UNPOCO柏蔻'],
#  ['蛋挞', '沙滩'],
#  ['蛋挞', '烧鸭饭'],
#  ['蛋挞', '海滨公园'],
#  ['蛋挞', '煲仔饭'],
#  ['蛋挞', '北洛湾'],
#  ['蛋挞', '面包'],
#  ['蛋挞', '榴莲千层'],
#  ['蛋挞', '水东湾'],
#  ['蛋挞', '炸鸡'],
#  ['蛋挞', '火腿'],
#  ['蛋挞', '肉松'],
#  ['蛋挞', '东湖'],
#  ['蛋挞', 'I'],
#  ['蛋挞', '黄油'],
#  ['蛋挞', '叉烧饭'],
#  ['蛋挞', '三元塔'],
#  ['蛋挞', '湖光岩'],
#  ['蛋挞', '蔬菜'],
#  ['蛋挞', '日式蟹肉卷'],
#  ['蛋挞', '油条碎'],
#  ['蛋挞', '甜点'],
#  ['蛋挞', '牛肉'],
#  ['蛋挞', '小炒'],
#  ['蛋挞', '野菠萝公园'],
#  ['蛋挞', '和牛盖饭'],
#  ['蛋挞', '饮料'],
#  ['蛋挞', '温德姆酒店'],
#  ['蛋挞', '泡芙'],
#  ['蛋挞', '牛排'],
#  ['蛋挞', '牛肚'],
#  ['蛋挞', '晏镜岭'],
#  ['蛋挞', '刺身'],
#  ['蛋挞', '御水古温泉'],
#  ['蛋挞', '自助菜'],
#  ['蛋挞', '游乐场'],
#  ['蛋挞', '中心广场'],
#  ['蛋挞', '摩天轮'],
#  ['蛋挞', '高钙大骨鸳鸯锅'],
#  ['蛋挞', '天马山'],
#  ['蛋挞', '赤坎老街'],
#  ['蛋挞', '玉湖'],
#  ['蛋挞', '菠萝皮'],
#  ['蛋挞', '热狗'],
#  ['蛋挞', '红树林'],
#  ['蛋挞', '菠萝包'],
#  ['蛋挞', '米饭'],
#  ['蛋挞', '无花果'],
#  ['蛋挞', '关东煮'],
#  ['蛋挞', '荔枝'],
#  ['蛋挞', '架海灯塔'],
#  ['蛋挞', '望海楼'],
#  ['蛋挞', '无花果萨拉米披萨'],
#  ['蛋挞', '早茶'],
#  ['蛋挞', '红树林栈道'],
#  ['蛋挞', '榴莲蛋糕'],
#  ['蛋挞', '炒乌冬'],
#  ['蛋挞', '酱汁'],
#  ['蛋挞', '奶油'],
#  ['蛋挞', '大角湾'],
#  ['蛋挞', '博物馆'],
#  ['蛋挞', '海鲜'],
#  ['蛋挞', '海陵岛'],
#  ['蛋挞', '高州仙人洞景区'],
#  ['蛋挞', '湛江大桥'],
#  ['蛋挞', '寿司'],
#  ['蛋挞', '新湖公园'],
#  ['蛋挞', '海滩'],
#  ['蛋挞', '玻璃桥'],
#  ['蛋挞', '第一滩'],
#  ['蛋挞', '蜂蜜芥末'],
#  ['蛋挞', '生蚝'],
#  ['蛋挞', '十里军港'],
#  ['蛋挞', '凤梨'],
#  ['蛋挞', '炒牛河'],
#  ['蛋挞', '露天矿生态公园'],
#  ['蛋挞', '薯条'],
#  ['蛋挞', '蛋挞'],
#  ['蛋挞', '雷州古城'],
#  ['蛋挞', '粗薯'],
#  ['蛋挞', '雅米乐园'],
#  ['蛋挞', '露天矿'],
#  ['蛋挞', '脆皮热狗卷'],
#  ['文化广场', '小东江'],
#  ['文化广场', '拉面'],
#  ['文化广场', '东南码头'],
#  ['文化广场', '骑楼'],
#  ['文化广场', '凉拌菜'],
#  ['文化广场', '甜品'],
#  ['文化广场', 'UNPOCO柏蔻'],
#  ['文化广场', '沙滩'],
#  ['文化广场', '烧鸭饭'],
#  ['文化广场', '海滨公园'],
#  ['文化广场', '煲仔饭'],
#  ['文化广场', '北洛湾'],
#  ['文化广场', '面包'],
#  ['文化广场', '榴莲千层'],
#  ['文化广场', '水东湾'],
#  ['文化广场', '炸鸡'],
#  ['文化广场', '火腿'],
#  ['文化广场', '肉松'],
#  ['文化广场', '东湖'],
#  ['文化广场', 'I'],
#  ['文化广场', '黄油'],
#  ['文化广场', '叉烧饭'],
#  ['文化广场', '三元塔'],
#  ['文化广场', '湖光岩'],
#  ['文化广场', '蔬菜'],
#  ['文化广场', '日式蟹肉卷'],
#  ['文化广场', '油条碎'],
#  ['文化广场', '甜点'],
#  ['文化广场', '牛肉'],
#  ['文化广场', '小炒'],
#  ['文化广场', '野菠萝公园'],
#  ['文化广场', '和牛盖饭'],
#  ['文化广场', '饮料'],
#  ['文化广场', '温德姆酒店'],
#  ['文化广场', '泡芙'],
#  ['文化广场', '牛排'],
#  ['文化广场', '文化广场'],
#  ['文化广场', '牛肚'],
#  ['文化广场', '晏镜岭'],
#  ['文化广场', '刺身'],
#  ['文化广场', '御水古温泉'],
#  ['文化广场', '自助菜'],
#  ['文化广场', '游乐场'],
#  ['文化广场', '中心广场'],
#  ['文化广场', '摩天轮'],
#  ['文化广场', '高钙大骨鸳鸯锅'],
#  ['文化广场', '天马山'],
#  ['文化广场', '赤坎老街'],
#  ['文化广场', '玉湖'],
#  ['文化广场', '菠萝皮'],
#  ['文化广场', '热狗'],
#  ['文化广场', '红树林'],
#  ['文化广场', '菠萝包'],
#  ['文化广场', '米饭'],
#  ['文化广场', '无花果'],
#  ['文化广场', '关东煮'],
#  ['文化广场', '荔枝'],
#  ['文化广场', '架海灯塔'],
#  ['文化广场', '望海楼'],
#  ['文化广场', '无花果萨拉米披萨'],
#  ['文化广场', '早茶'],
#  ['文化广场', '红树林栈道'],
#  ['文化广场', '榴莲蛋糕'],
#  ['文化广场', '炒乌冬'],
#  ['文化广场', '酱汁'],
#  ['文化广场', '奶油'],
#  ['文化广场', '大角湾'],
#  ['文化广场', '博物馆'],
#  ['文化广场', '海鲜'],
#  ['文化广场', '海陵岛'],
#  ['文化广场', '高州仙人洞景区'],
#  ['文化广场', '湛江大桥'],
#  ['文化广场', '寿司'],
#  ['文化广场', '新湖公园'],
#  ['文化广场', '海滩'],
#  ['文化广场', '玻璃桥'],
#  ['文化广场', '第一滩'],
#  ['文化广场', '蜂蜜芥末'],
#  ['文化广场', '生蚝'],
#  ['文化广场', '十里军港'],
#  ['文化广场', '凤梨'],
#  ['文化广场', '炒牛河'],
#  ['文化广场', '露天矿生态公园'],
#  ['文化广场', '薯条'],
#  ['文化广场', '蛋挞'],
#  ['文化广场', '雷州古城'],
#  ['文化广场', '粗薯'],
#  ['文化广场', '雅米乐园'],
#  ['文化广场', '露天矿'],
#  ['文化广场', '脆皮热狗卷'],
#  ['小东江', '拉面'],
#  ['小东江', '东南码头'],
#  ['小东江', '骑楼'],
#  ['小东江', '凉拌菜'],
#  ['小东江', '小东江'],
#  ['小东江', '甜品'],
#  ['小东江', 'UNPOCO柏蔻'],
#  ['小东江', '沙滩'],
#  ['小东江', '烧鸭饭'],
#  ['小东江', '海滨公园'],
#  ['小东江', '煲仔饭'],
#  ['小东江', '北洛湾'],
#  ['小东江', '面包'],
#  ['小东江', '榴莲千层'],
#  ['小东江', '水东湾'],
#  ['小东江', '炸鸡'],
#  ['小东江', '火腿'],
#  ['小东江', '肉松'],
#  ['小东江', '东湖'],
#  ['小东江', 'I'],
#  ['小东江', '黄油'],
#  ['小东江', '叉烧饭'],
#  ['小东江', '三元塔'],
#  ['小东江', '湖光岩'],
#  ['小东江', '蔬菜'],
#  ['小东江', '日式蟹肉卷'],
#  ['小东江', '油条碎'],
#  ['小东江', '甜点'],
#  ['小东江', '牛肉'],
#  ['小东江', '小炒'],
#  ['小东江', '野菠萝公园'],
#  ['小东江', '和牛盖饭'],
#  ['小东江', '饮料'],
#  ['小东江', '温德姆酒店'],
#  ['小东江', '泡芙'],
#  ['小东江', '牛排'],
#  ['小东江', '文化广场'],
#  ['小东江', '牛肚'],
#  ['小东江', '晏镜岭'],
#  ['小东江', '刺身'],
#  ['小东江', '御水古温泉'],
#  ['小东江', '自助菜'],
#  ['小东江', '游乐场'],
#  ['小东江', '中心广场'],
#  ['小东江', '摩天轮'],
#  ['小东江', '高钙大骨鸳鸯锅'],
#  ['小东江', '天马山'],
#  ['小东江', '赤坎老街'],
#  ['小东江', '玉湖'],
#  ['小东江', '菠萝皮'],
#  ['小东江', '热狗'],
#  ['小东江', '红树林'],
#  ['小东江', '菠萝包'],
#  ['小东江', '米饭'],
#  ['小东江', '无花果'],
#  ['小东江', '关东煮'],
#  ['小东江', '荔枝'],
#  ['小东江', '架海灯塔'],
#  ['小东江', '望海楼'],
#  ['小东江', '无花果萨拉米披萨'],
#  ['小东江', '早茶'],
#  ['小东江', '红树林栈道'],
#  ['小东江', '榴莲蛋糕'],
#  ['小东江', '炒乌冬'],
#  ['小东江', '酱汁'],
#  ['小东江', '奶油'],
#  ['小东江', '大角湾'],
#  ['小东江', '博物馆'],
#  ['小东江', '海鲜'],
#  ['小东江', '海陵岛'],
#  ['小东江', '高州仙人洞景区'],
#  ['小东江', '湛江大桥'],
#  ['小东江', '寿司'],
#  ['小东江', '新湖公园'],
#  ['小东江', '海滩'],
#  ['小东江', '玻璃桥'],
#  ['小东江', '第一滩'],
#  ['小东江', '蜂蜜芥末'],
#  ['小东江', '生蚝'],
#  ['小东江', '十里军港'],
#  ['小东江', '凤梨'],
#  ['小东江', '炒牛河'],
#  ['小东江', '露天矿生态公园'],
#  ['小东江', '薯条'],
#  ['小东江', '蛋挞'],
#  ['小东江', '雷州古城'],
#  ['小东江', '粗薯'],
#  ['小东江', '雅米乐园'],
#  ['小东江', '露天矿'],
#  ['小东江', '脆皮热狗卷'],
#  ['拉面', '东南码头'],
#  ['拉面', '骑楼'],
#  ['拉面', '凉拌菜'],
#  ['拉面', '小东江'],
#  ['拉面', '甜品'],
#  ['拉面', 'UNPOCO柏蔻'],
#  ['拉面', '沙滩'],
#  ['拉面', '烧鸭饭'],
#  ['拉面', '海滨公园'],
#  ['拉面', '煲仔饭'],
#  ...]

# %%
idxs
# Out:
# [['ID26', 'ID56'],
#  ['ID26', 'ID72'],
#  ['ID26', 'ID54'],
#  ['ID26', 'ID33'],
#  ['ID26', 'ID27'],
#  ['ID26', 'ID51'],
#  ['ID26', 'ID12'],
#  ['ID26', 'ID67'],
#  ['ID26', 'ID6'],
#  ['ID26', 'ID9'],
#  ['ID26', 'ID65'],
#  ['ID26', 'ID40'],
#  ['ID26', 'ID31'],
#  ['ID26', 'ID89'],
#  ['ID26', 'ID49'],
#  ['ID26', 'ID80'],
#  ['ID26', 'ID5'],
#  ['ID26', 'ID57'],
#  ['ID26', 'ID26'],
#  ['ID26', 'ID88'],
#  ['ID26', 'ID25'],
#  ['ID26', 'ID11'],
#  ['ID26', 'ID45'],
#  ['ID26', 'ID59'],
#  ['ID26', 'ID71'],
#  ['ID26', 'ID63'],
#  ['ID26', 'ID15'],
#  ['ID26', 'ID8'],
#  ['ID26', 'ID75'],
#  ['ID26', 'ID32'],
#  ['ID26', 'ID36'],
#  ['ID26', 'ID58'],
#  ['ID26', 'ID78'],
#  ['ID26', 'ID84'],
#  ['ID26', 'ID66'],
#  ['ID26', 'ID50'],
#  ['ID26', 'ID38'],
#  ['ID26', 'ID77'],
#  ['ID26', 'ID16'],
#  ['ID26', 'ID39'],
#  ['ID26', 'ID62'],
#  ['ID26', 'ID42'],
#  ['ID26', 'ID74'],
#  ['ID26', 'ID17'],
#  ['ID26', 'ID70'],
#  ['ID26', 'ID85'],
#  ['ID26', 'ID23'],
#  ['ID26', 'ID3'],
#  ['ID26', 'ID24'],
#  ['ID26', 'ID79'],
#  ['ID26', 'ID19'],
#  ['ID26', 'ID48'],
#  ['ID26', 'ID37'],
#  ['ID26', 'ID87'],
#  ['ID26', 'ID46'],
#  ['ID26', 'ID10'],
#  ['ID26', 'ID86'],
#  ['ID26', 'ID61'],
#  ['ID26', 'ID82'],
#  ['ID26', 'ID90'],
#  ['ID26', 'ID13'],
#  ['ID26', 'ID18'],
#  ['ID26', 'ID41'],
#  ['ID26', 'ID81'],
#  ['ID26', 'ID7'],
#  ['ID26', 'ID14'],
#  ['ID26', 'ID52'],
#  ['ID26', 'ID68'],
#  ['ID26', 'ID76'],
#  ['ID26', 'ID53'],
#  ['ID26', 'ID20'],
#  ['ID26', 'ID4'],
#  ['ID26', 'ID22'],
#  ['ID26', 'ID47'],
#  ['ID26', 'ID44'],
#  ['ID26', 'ID55'],
#  ['ID26', 'ID43'],
#  ['ID26', 'ID1'],
#  ['ID26', 'ID21'],
#  ['ID26', 'ID2'],
#  ['ID26', 'ID60'],
#  ['ID26', 'ID35'],
#  ['ID26', 'ID30'],
#  ['ID26', 'ID69'],
#  ['ID26', 'ID73'],
#  ['ID26', 'ID28'],
#  ['ID26', 'ID64'],
#  ['ID26', 'ID34'],
#  ['ID26', 'ID83'],
#  ['ID26', 'ID29'],
#  ['ID56', 'ID72'],
#  ['ID56', 'ID54'],
#  ['ID56', 'ID33'],
#  ['ID56', 'ID27'],
#  ['ID56', 'ID51'],
#  ['ID56', 'ID12'],
#  ['ID56', 'ID67'],
#  ['ID56', 'ID6'],
#  ['ID56', 'ID9'],
#  ['ID56', 'ID65'],
#  ['ID56', 'ID40'],
#  ['ID56', 'ID31'],
#  ['ID56', 'ID89'],
#  ['ID56', 'ID49'],
#  ['ID56', 'ID80'],
#  ['ID56', 'ID5'],
#  ['ID56', 'ID57'],
#  ['ID56', 'ID26'],
#  ['ID56', 'ID88'],
#  ['ID56', 'ID25'],
#  ['ID56', 'ID11'],
#  ['ID56', 'ID45'],
#  ['ID56', 'ID59'],
#  ['ID56', 'ID71'],
#  ['ID56', 'ID63'],
#  ['ID56', 'ID15'],
#  ['ID56', 'ID8'],
#  ['ID56', 'ID75'],
#  ['ID56', 'ID56'],
#  ['ID56', 'ID32'],
#  ['ID56', 'ID36'],
#  ['ID56', 'ID58'],
#  ['ID56', 'ID78'],
#  ['ID56', 'ID84'],
#  ['ID56', 'ID66'],
#  ['ID56', 'ID50'],
#  ['ID56', 'ID38'],
#  ['ID56', 'ID77'],
#  ['ID56', 'ID16'],
#  ['ID56', 'ID39'],
#  ['ID56', 'ID62'],
#  ['ID56', 'ID42'],
#  ['ID56', 'ID74'],
#  ['ID56', 'ID17'],
#  ['ID56', 'ID70'],
#  ['ID56', 'ID85'],
#  ['ID56', 'ID23'],
#  ['ID56', 'ID3'],
#  ['ID56', 'ID24'],
#  ['ID56', 'ID79'],
#  ['ID56', 'ID19'],
#  ['ID56', 'ID48'],
#  ['ID56', 'ID37'],
#  ['ID56', 'ID87'],
#  ['ID56', 'ID46'],
#  ['ID56', 'ID10'],
#  ['ID56', 'ID86'],
#  ['ID56', 'ID61'],
#  ['ID56', 'ID82'],
#  ['ID56', 'ID90'],
#  ['ID56', 'ID13'],
#  ['ID56', 'ID18'],
#  ['ID56', 'ID41'],
#  ['ID56', 'ID81'],
#  ['ID56', 'ID7'],
#  ['ID56', 'ID14'],
#  ['ID56', 'ID52'],
#  ['ID56', 'ID68'],
#  ['ID56', 'ID76'],
#  ['ID56', 'ID53'],
#  ['ID56', 'ID20'],
#  ['ID56', 'ID4'],
#  ['ID56', 'ID22'],
#  ['ID56', 'ID47'],
#  ['ID56', 'ID44'],
#  ['ID56', 'ID55'],
#  ['ID56', 'ID43'],
#  ['ID56', 'ID1'],
#  ['ID56', 'ID21'],
#  ['ID56', 'ID2'],
#  ['ID56', 'ID60'],
#  ['ID56', 'ID35'],
#  ['ID56', 'ID30'],
#  ['ID56', 'ID69'],
#  ['ID56', 'ID73'],
#  ['ID56', 'ID28'],
#  ['ID56', 'ID64'],
#  ['ID56', 'ID34'],
#  ['ID56', 'ID83'],
#  ['ID56', 'ID29'],
#  ['ID72', 'ID54'],
#  ['ID72', 'ID33'],
#  ['ID72', 'ID27'],
#  ['ID72', 'ID51'],
#  ['ID72', 'ID12'],
#  ['ID72', 'ID67'],
#  ['ID72', 'ID6'],
#  ['ID72', 'ID9'],
#  ['ID72', 'ID65'],
#  ['ID72', 'ID40'],
#  ['ID72', 'ID31'],
#  ['ID72', 'ID89'],
#  ['ID72', 'ID49'],
#  ['ID72', 'ID80'],
#  ['ID72', 'ID5'],
#  ['ID72', 'ID57'],
#  ['ID72', 'ID26'],
#  ['ID72', 'ID88'],
#  ['ID72', 'ID25'],
#  ['ID72', 'ID11'],
#  ['ID72', 'ID45'],
#  ['ID72', 'ID59'],
#  ['ID72', 'ID71'],
#  ['ID72', 'ID63'],
#  ['ID72', 'ID15'],
#  ['ID72', 'ID8'],
#  ['ID72', 'ID75'],
#  ['ID72', 'ID56'],
#  ['ID72', 'ID32'],
#  ['ID72', 'ID36'],
#  ['ID72', 'ID58'],
#  ['ID72', 'ID78'],
#  ['ID72', 'ID84'],
#  ['ID72', 'ID66'],
#  ['ID72', 'ID50'],
#  ['ID72', 'ID38'],
#  ['ID72', 'ID77'],
#  ['ID72', 'ID16'],
#  ['ID72', 'ID39'],
#  ['ID72', 'ID62'],
#  ['ID72', 'ID42'],
#  ['ID72', 'ID74'],
#  ['ID72', 'ID17'],
#  ['ID72', 'ID70'],
#  ['ID72', 'ID85'],
#  ['ID72', 'ID23'],
#  ['ID72', 'ID3'],
#  ['ID72', 'ID24'],
#  ['ID72', 'ID79'],
#  ['ID72', 'ID19'],
#  ['ID72', 'ID48'],
#  ['ID72', 'ID37'],
#  ['ID72', 'ID87'],
#  ['ID72', 'ID46'],
#  ['ID72', 'ID10'],
#  ['ID72', 'ID86'],
#  ['ID72', 'ID61'],
#  ['ID72', 'ID82'],
#  ['ID72', 'ID90'],
#  ['ID72', 'ID13'],
#  ['ID72', 'ID18'],
#  ['ID72', 'ID41'],
#  ['ID72', 'ID81'],
#  ['ID72', 'ID7'],
#  ['ID72', 'ID14'],
#  ['ID72', 'ID52'],
#  ['ID72', 'ID68'],
#  ['ID72', 'ID76'],
#  ['ID72', 'ID53'],
#  ['ID72', 'ID20'],
#  ['ID72', 'ID4'],
#  ['ID72', 'ID22'],
#  ['ID72', 'ID47'],
#  ['ID72', 'ID44'],
#  ['ID72', 'ID55'],
#  ['ID72', 'ID43'],
#  ['ID72', 'ID1'],
#  ['ID72', 'ID21'],
#  ['ID72', 'ID2'],
#  ['ID72', 'ID60'],
#  ['ID72', 'ID35'],
#  ['ID72', 'ID30'],
#  ['ID72', 'ID69'],
#  ['ID72', 'ID73'],
#  ['ID72', 'ID28'],
#  ['ID72', 'ID64'],
#  ['ID72', 'ID34'],
#  ['ID72', 'ID83'],
#  ['ID72', 'ID29'],
#  ['ID72', 'ID72'],
#  ['ID54', 'ID33'],
#  ['ID54', 'ID27'],
#  ['ID54', 'ID51'],
#  ['ID54', 'ID12'],
#  ['ID54', 'ID67'],
#  ['ID54', 'ID6'],
#  ['ID54', 'ID9'],
#  ['ID54', 'ID65'],
#  ['ID54', 'ID40'],
#  ['ID54', 'ID31'],
#  ['ID54', 'ID89'],
#  ['ID54', 'ID49'],
#  ['ID54', 'ID80'],
#  ['ID54', 'ID5'],
#  ['ID54', 'ID57'],
#  ['ID54', 'ID26'],
#  ['ID54', 'ID88'],
#  ['ID54', 'ID25'],
#  ['ID54', 'ID11'],
#  ['ID54', 'ID54'],
#  ['ID54', 'ID45'],
#  ['ID54', 'ID59'],
#  ['ID54', 'ID71'],
#  ['ID54', 'ID63'],
#  ['ID54', 'ID15'],
#  ['ID54', 'ID8'],
#  ['ID54', 'ID75'],
#  ['ID54', 'ID56'],
#  ['ID54', 'ID32'],
#  ['ID54', 'ID36'],
#  ['ID54', 'ID58'],
#  ['ID54', 'ID78'],
#  ['ID54', 'ID84'],
#  ['ID54', 'ID66'],
#  ['ID54', 'ID50'],
#  ['ID54', 'ID38'],
#  ['ID54', 'ID77'],
#  ['ID54', 'ID16'],
#  ['ID54', 'ID39'],
#  ['ID54', 'ID62'],
#  ['ID54', 'ID42'],
#  ['ID54', 'ID74'],
#  ['ID54', 'ID17'],
#  ['ID54', 'ID70'],
#  ['ID54', 'ID85'],
#  ['ID54', 'ID23'],
#  ['ID54', 'ID3'],
#  ['ID54', 'ID24'],
#  ['ID54', 'ID79'],
#  ['ID54', 'ID19'],
#  ['ID54', 'ID48'],
#  ['ID54', 'ID37'],
#  ['ID54', 'ID87'],
#  ['ID54', 'ID46'],
#  ['ID54', 'ID10'],
#  ['ID54', 'ID86'],
#  ['ID54', 'ID61'],
#  ['ID54', 'ID82'],
#  ['ID54', 'ID90'],
#  ['ID54', 'ID13'],
#  ['ID54', 'ID18'],
#  ['ID54', 'ID41'],
#  ['ID54', 'ID81'],
#  ['ID54', 'ID7'],
#  ['ID54', 'ID14'],
#  ['ID54', 'ID52'],
#  ['ID54', 'ID68'],
#  ['ID54', 'ID76'],
#  ['ID54', 'ID53'],
#  ['ID54', 'ID20'],
#  ['ID54', 'ID4'],
#  ['ID54', 'ID22'],
#  ['ID54', 'ID47'],
#  ['ID54', 'ID44'],
#  ['ID54', 'ID55'],
#  ['ID54', 'ID43'],
#  ['ID54', 'ID1'],
#  ['ID54', 'ID21'],
#  ['ID54', 'ID2'],
#  ['ID54', 'ID60'],
#  ['ID54', 'ID35'],
#  ['ID54', 'ID30'],
#  ['ID54', 'ID69'],
#  ['ID54', 'ID73'],
#  ['ID54', 'ID28'],
#  ['ID54', 'ID64'],
#  ['ID54', 'ID34'],
#  ['ID54', 'ID83'],
#  ['ID54', 'ID29'],
#  ['ID54', 'ID72'],
#  ['ID33', 'ID27'],
#  ['ID33', 'ID51'],
#  ['ID33', 'ID12'],
#  ['ID33', 'ID67'],
#  ['ID33', 'ID6'],
#  ['ID33', 'ID9'],
#  ['ID33', 'ID65'],
#  ['ID33', 'ID40'],
#  ['ID33', 'ID31'],
#  ['ID33', 'ID89'],
#  ['ID33', 'ID49'],
#  ['ID33', 'ID80'],
#  ['ID33', 'ID5'],
#  ['ID33', 'ID57'],
#  ['ID33', 'ID26'],
#  ['ID33', 'ID88'],
#  ['ID33', 'ID25'],
#  ['ID33', 'ID11'],
#  ['ID33', 'ID54'],
#  ['ID33', 'ID45'],
#  ['ID33', 'ID59'],
#  ['ID33', 'ID71'],
#  ['ID33', 'ID63'],
#  ['ID33', 'ID15'],
#  ['ID33', 'ID8'],
#  ['ID33', 'ID75'],
#  ['ID33', 'ID56'],
#  ['ID33', 'ID32'],
#  ['ID33', 'ID36'],
#  ['ID33', 'ID58'],
#  ['ID33', 'ID78'],
#  ['ID33', 'ID84'],
#  ['ID33', 'ID66'],
#  ['ID33', 'ID50'],
#  ['ID33', 'ID38'],
#  ['ID33', 'ID77'],
#  ['ID33', 'ID16'],
#  ['ID33', 'ID39'],
#  ['ID33', 'ID62'],
#  ['ID33', 'ID42'],
#  ['ID33', 'ID74'],
#  ['ID33', 'ID17'],
#  ['ID33', 'ID70'],
#  ['ID33', 'ID33'],
#  ['ID33', 'ID85'],
#  ['ID33', 'ID23'],
#  ['ID33', 'ID3'],
#  ['ID33', 'ID24'],
#  ['ID33', 'ID79'],
#  ['ID33', 'ID19'],
#  ['ID33', 'ID48'],
#  ['ID33', 'ID37'],
#  ['ID33', 'ID87'],
#  ['ID33', 'ID46'],
#  ['ID33', 'ID10'],
#  ['ID33', 'ID86'],
#  ['ID33', 'ID61'],
#  ['ID33', 'ID82'],
#  ['ID33', 'ID90'],
#  ['ID33', 'ID13'],
#  ['ID33', 'ID18'],
#  ['ID33', 'ID41'],
#  ['ID33', 'ID81'],
#  ['ID33', 'ID7'],
#  ['ID33', 'ID14'],
#  ['ID33', 'ID52'],
#  ['ID33', 'ID68'],
#  ['ID33', 'ID76'],
#  ['ID33', 'ID53'],
#  ['ID33', 'ID20'],
#  ['ID33', 'ID4'],
#  ['ID33', 'ID22'],
#  ['ID33', 'ID47'],
#  ['ID33', 'ID44'],
#  ['ID33', 'ID55'],
#  ['ID33', 'ID43'],
#  ['ID33', 'ID1'],
#  ['ID33', 'ID21'],
#  ['ID33', 'ID2'],
#  ['ID33', 'ID60'],
#  ['ID33', 'ID35'],
#  ['ID33', 'ID30'],
#  ['ID33', 'ID69'],
#  ['ID33', 'ID73'],
#  ['ID33', 'ID28'],
#  ['ID33', 'ID64'],
#  ['ID33', 'ID34'],
#  ['ID33', 'ID83'],
#  ['ID33', 'ID29'],
#  ['ID33', 'ID72'],
#  ['ID27', 'ID51'],
#  ['ID27', 'ID12'],
#  ['ID27', 'ID67'],
#  ['ID27', 'ID6'],
#  ['ID27', 'ID9'],
#  ['ID27', 'ID65'],
#  ['ID27', 'ID40'],
#  ['ID27', 'ID31'],
#  ['ID27', 'ID89'],
#  ['ID27', 'ID49'],
#  ['ID27', 'ID80'],
#  ['ID27', 'ID5'],
#  ['ID27', 'ID57'],
#  ['ID27', 'ID26'],
#  ['ID27', 'ID88'],
#  ['ID27', 'ID25'],
#  ['ID27', 'ID11'],
#  ['ID27', 'ID54'],
#  ['ID27', 'ID45'],
#  ['ID27', 'ID59'],
#  ['ID27', 'ID71'],
#  ['ID27', 'ID63'],
#  ['ID27', 'ID15'],
#  ['ID27', 'ID8'],
#  ['ID27', 'ID75'],
#  ['ID27', 'ID56'],
#  ['ID27', 'ID32'],
#  ['ID27', 'ID36'],
#  ['ID27', 'ID58'],
#  ['ID27', 'ID78'],
#  ['ID27', 'ID84'],
#  ['ID27', 'ID66'],
#  ['ID27', 'ID50'],
#  ['ID27', 'ID38'],
#  ['ID27', 'ID77'],
#  ['ID27', 'ID16'],
#  ['ID27', 'ID39'],
#  ['ID27', 'ID62'],
#  ['ID27', 'ID42'],
#  ['ID27', 'ID74'],
#  ['ID27', 'ID17'],
#  ['ID27', 'ID70'],
#  ['ID27', 'ID33'],
#  ['ID27', 'ID85'],
#  ['ID27', 'ID23'],
#  ['ID27', 'ID3'],
#  ['ID27', 'ID24'],
#  ['ID27', 'ID79'],
#  ['ID27', 'ID19'],
#  ['ID27', 'ID48'],
#  ['ID27', 'ID37'],
#  ['ID27', 'ID87'],
#  ['ID27', 'ID46'],
#  ['ID27', 'ID10'],
#  ['ID27', 'ID86'],
#  ['ID27', 'ID61'],
#  ['ID27', 'ID82'],
#  ['ID27', 'ID90'],
#  ['ID27', 'ID13'],
#  ['ID27', 'ID18'],
#  ['ID27', 'ID41'],
#  ['ID27', 'ID81'],
#  ['ID27', 'ID7'],
#  ['ID27', 'ID14'],
#  ['ID27', 'ID52'],
#  ['ID27', 'ID68'],
#  ['ID27', 'ID76'],
#  ['ID27', 'ID53'],
#  ['ID27', 'ID27'],
#  ['ID27', 'ID20'],
#  ['ID27', 'ID4'],
#  ['ID27', 'ID22'],
#  ['ID27', 'ID47'],
#  ['ID27', 'ID44'],
#  ['ID27', 'ID55'],
#  ['ID27', 'ID43'],
#  ['ID27', 'ID1'],
#  ['ID27', 'ID21'],
#  ['ID27', 'ID2'],
#  ['ID27', 'ID60'],
#  ['ID27', 'ID35'],
#  ['ID27', 'ID30'],
#  ['ID27', 'ID69'],
#  ['ID27', 'ID73'],
#  ['ID27', 'ID28'],
#  ['ID27', 'ID64'],
#  ['ID27', 'ID34'],
#  ['ID27', 'ID83'],
#  ['ID27', 'ID29'],
#  ['ID27', 'ID72'],
#  ['ID51', 'ID12'],
#  ['ID51', 'ID67'],
#  ['ID51', 'ID6'],
#  ['ID51', 'ID9'],
#  ['ID51', 'ID65'],
#  ['ID51', 'ID40'],
#  ['ID51', 'ID31'],
#  ['ID51', 'ID89'],
#  ['ID51', 'ID49'],
#  ['ID51', 'ID80'],
#  ['ID51', 'ID5'],
#  ['ID51', 'ID57'],
#  ['ID51', 'ID26'],
#  ['ID51', 'ID88'],
#  ['ID51', 'ID25'],
#  ['ID51', 'ID11'],
#  ['ID51', 'ID54'],
#  ['ID51', 'ID45'],
#  ['ID51', 'ID59'],
#  ['ID51', 'ID71'],
#  ['ID51', 'ID63'],
#  ['ID51', 'ID15'],
#  ['ID51', 'ID8'],
#  ['ID51', 'ID75'],
#  ['ID51', 'ID56'],
#  ['ID51', 'ID32'],
#  ['ID51', 'ID36'],
#  ['ID51', 'ID58'],
#  ['ID51', 'ID78'],
#  ['ID51', 'ID84'],
#  ['ID51', 'ID66'],
#  ['ID51', 'ID50'],
#  ['ID51', 'ID38'],
#  ['ID51', 'ID77'],
#  ['ID51', 'ID16'],
#  ['ID51', 'ID39'],
#  ['ID51', 'ID62'],
#  ['ID51', 'ID42'],
#  ['ID51', 'ID74'],
#  ['ID51', 'ID17'],
#  ['ID51', 'ID70'],
#  ['ID51', 'ID33'],
#  ['ID51', 'ID85'],
#  ['ID51', 'ID23'],
#  ['ID51', 'ID3'],
#  ['ID51', 'ID24'],
#  ['ID51', 'ID79'],
#  ['ID51', 'ID19'],
#  ['ID51', 'ID48'],
#  ['ID51', 'ID37'],
#  ['ID51', 'ID87'],
#  ['ID51', 'ID46'],
#  ['ID51', 'ID10'],
#  ['ID51', 'ID86'],
#  ['ID51', 'ID61'],
#  ['ID51', 'ID82'],
#  ['ID51', 'ID90'],
#  ['ID51', 'ID13'],
#  ['ID51', 'ID18'],
#  ['ID51', 'ID41'],
#  ['ID51', 'ID81'],
#  ['ID51', 'ID7'],
#  ['ID51', 'ID14'],
#  ['ID51', 'ID52'],
#  ['ID51', 'ID68'],
#  ['ID51', 'ID76'],
#  ['ID51', 'ID53'],
#  ['ID51', 'ID27'],
#  ['ID51', 'ID20'],
#  ['ID51', 'ID4'],
#  ['ID51', 'ID22'],
#  ['ID51', 'ID47'],
#  ['ID51', 'ID44'],
#  ['ID51', 'ID55'],
#  ['ID51', 'ID43'],
#  ['ID51', 'ID1'],
#  ['ID51', 'ID21'],
#  ['ID51', 'ID2'],
#  ['ID51', 'ID60'],
#  ['ID51', 'ID35'],
#  ['ID51', 'ID30'],
#  ['ID51', 'ID69'],
#  ['ID51', 'ID73'],
#  ['ID51', 'ID28'],
#  ['ID51', 'ID64'],
#  ['ID51', 'ID34'],
#  ['ID51', 'ID83'],
#  ['ID51', 'ID51'],
#  ['ID51', 'ID29'],
#  ['ID51', 'ID72'],
#  ['ID12', 'ID67'],
#  ['ID12', 'ID6'],
#  ['ID12', 'ID9'],
#  ['ID12', 'ID65'],
#  ['ID12', 'ID40'],
#  ['ID12', 'ID31'],
#  ['ID12', 'ID89'],
#  ['ID12', 'ID49'],
#  ['ID12', 'ID80'],
#  ['ID12', 'ID5'],
#  ['ID12', 'ID57'],
#  ['ID12', 'ID26'],
#  ['ID12', 'ID88'],
#  ['ID12', 'ID25'],
#  ['ID12', 'ID11'],
#  ['ID12', 'ID54'],
#  ['ID12', 'ID45'],
#  ['ID12', 'ID59'],
#  ['ID12', 'ID71'],
#  ['ID12', 'ID63'],
#  ['ID12', 'ID15'],
#  ['ID12', 'ID8'],
#  ['ID12', 'ID75'],
#  ['ID12', 'ID56'],
#  ['ID12', 'ID32'],
#  ['ID12', 'ID36'],
#  ['ID12', 'ID58'],
#  ['ID12', 'ID78'],
#  ['ID12', 'ID84'],
#  ['ID12', 'ID12'],
#  ['ID12', 'ID66'],
#  ['ID12', 'ID50'],
#  ['ID12', 'ID38'],
#  ['ID12', 'ID77'],
#  ['ID12', 'ID16'],
#  ['ID12', 'ID39'],
#  ['ID12', 'ID62'],
#  ['ID12', 'ID42'],
#  ['ID12', 'ID74'],
#  ['ID12', 'ID17'],
#  ['ID12', 'ID70'],
#  ['ID12', 'ID33'],
#  ['ID12', 'ID85'],
#  ['ID12', 'ID23'],
#  ['ID12', 'ID3'],
#  ['ID12', 'ID24'],
#  ['ID12', 'ID79'],
#  ['ID12', 'ID19'],
#  ['ID12', 'ID48'],
#  ['ID12', 'ID37'],
#  ['ID12', 'ID87'],
#  ['ID12', 'ID46'],
#  ['ID12', 'ID10'],
#  ['ID12', 'ID86'],
#  ['ID12', 'ID61'],
#  ['ID12', 'ID82'],
#  ['ID12', 'ID90'],
#  ['ID12', 'ID13'],
#  ['ID12', 'ID18'],
#  ['ID12', 'ID41'],
#  ['ID12', 'ID81'],
#  ['ID12', 'ID7'],
#  ['ID12', 'ID14'],
#  ['ID12', 'ID52'],
#  ['ID12', 'ID68'],
#  ['ID12', 'ID76'],
#  ['ID12', 'ID53'],
#  ['ID12', 'ID27'],
#  ['ID12', 'ID20'],
#  ['ID12', 'ID4'],
#  ['ID12', 'ID22'],
#  ['ID12', 'ID47'],
#  ['ID12', 'ID44'],
#  ['ID12', 'ID55'],
#  ['ID12', 'ID43'],
#  ['ID12', 'ID1'],
#  ['ID12', 'ID21'],
#  ['ID12', 'ID2'],
#  ['ID12', 'ID60'],
#  ['ID12', 'ID35'],
#  ['ID12', 'ID30'],
#  ['ID12', 'ID69'],
#  ['ID12', 'ID73'],
#  ['ID12', 'ID28'],
#  ['ID12', 'ID64'],
#  ['ID12', 'ID34'],
#  ['ID12', 'ID83'],
#  ['ID12', 'ID51'],
#  ['ID12', 'ID29'],
#  ['ID12', 'ID72'],
#  ['ID67', 'ID6'],
#  ['ID67', 'ID9'],
#  ['ID67', 'ID65'],
#  ['ID67', 'ID40'],
#  ['ID67', 'ID31'],
#  ['ID67', 'ID89'],
#  ['ID67', 'ID49'],
#  ['ID67', 'ID80'],
#  ['ID67', 'ID5'],
#  ['ID67', 'ID57'],
#  ['ID67', 'ID26'],
#  ['ID67', 'ID88'],
#  ['ID67', 'ID25'],
#  ['ID67', 'ID11'],
#  ['ID67', 'ID54'],
#  ['ID67', 'ID45'],
#  ['ID67', 'ID59'],
#  ['ID67', 'ID71'],
#  ['ID67', 'ID63'],
#  ['ID67', 'ID15'],
#  ['ID67', 'ID8'],
#  ['ID67', 'ID75'],
#  ['ID67', 'ID56'],
#  ['ID67', 'ID32'],
#  ['ID67', 'ID36'],
#  ['ID67', 'ID58'],
#  ['ID67', 'ID78'],
#  ['ID67', 'ID84'],
#  ['ID67', 'ID12'],
#  ['ID67', 'ID66'],
#  ['ID67', 'ID50'],
#  ['ID67', 'ID38'],
#  ['ID67', 'ID77'],
#  ['ID67', 'ID16'],
#  ['ID67', 'ID39'],
#  ['ID67', 'ID62'],
#  ['ID67', 'ID42'],
#  ['ID67', 'ID74'],
#  ['ID67', 'ID17'],
#  ['ID67', 'ID70'],
#  ['ID67', 'ID33'],
#  ['ID67', 'ID85'],
#  ['ID67', 'ID23'],
#  ['ID67', 'ID3'],
#  ['ID67', 'ID24'],
#  ['ID67', 'ID79'],
#  ['ID67', 'ID19'],
#  ['ID67', 'ID48'],
#  ['ID67', 'ID37'],
#  ['ID67', 'ID87'],
#  ['ID67', 'ID46'],
#  ['ID67', 'ID10'],
#  ['ID67', 'ID86'],
#  ['ID67', 'ID61'],
#  ['ID67', 'ID82'],
#  ['ID67', 'ID90'],
#  ['ID67', 'ID13'],
#  ['ID67', 'ID18'],
#  ['ID67', 'ID41'],
#  ['ID67', 'ID81'],
#  ['ID67', 'ID7'],
#  ['ID67', 'ID14'],
#  ['ID67', 'ID52'],
#  ['ID67', 'ID68'],
#  ['ID67', 'ID76'],
#  ['ID67', 'ID53'],
#  ['ID67', 'ID27'],
#  ['ID67', 'ID20'],
#  ['ID67', 'ID4'],
#  ['ID67', 'ID22'],
#  ['ID67', 'ID47'],
#  ['ID67', 'ID44'],
#  ['ID67', 'ID55'],
#  ['ID67', 'ID43'],
#  ['ID67', 'ID1'],
#  ['ID67', 'ID21'],
#  ['ID67', 'ID2'],
#  ['ID67', 'ID60'],
#  ['ID67', 'ID35'],
#  ['ID67', 'ID30'],
#  ['ID67', 'ID69'],
#  ['ID67', 'ID73'],
#  ['ID67', 'ID28'],
#  ['ID67', 'ID64'],
#  ['ID67', 'ID67'],
#  ['ID67', 'ID34'],
#  ['ID67', 'ID83'],
#  ['ID67', 'ID51'],
#  ['ID67', 'ID29'],
#  ['ID67', 'ID72'],
#  ['ID6', 'ID9'],
#  ['ID6', 'ID65'],
#  ['ID6', 'ID40'],
#  ['ID6', 'ID31'],
#  ['ID6', 'ID89'],
#  ['ID6', 'ID49'],
#  ['ID6', 'ID80'],
#  ['ID6', 'ID5'],
#  ['ID6', 'ID57'],
#  ['ID6', 'ID26'],
#  ['ID6', 'ID88'],
#  ['ID6', 'ID25'],
#  ['ID6', 'ID11'],
#  ['ID6', 'ID54'],
#  ['ID6', 'ID45'],
#  ['ID6', 'ID59'],
#  ['ID6', 'ID71'],
#  ['ID6', 'ID63'],
#  ['ID6', 'ID15'],
#  ['ID6', 'ID8'],
#  ['ID6', 'ID75'],
#  ['ID6', 'ID56'],
#  ['ID6', 'ID32'],
#  ['ID6', 'ID36'],
#  ['ID6', 'ID58'],
#  ['ID6', 'ID78'],
#  ['ID6', 'ID84'],
#  ['ID6', 'ID12'],
#  ['ID6', 'ID66'],
#  ['ID6', 'ID50'],
#  ['ID6', 'ID38'],
#  ['ID6', 'ID77'],
#  ['ID6', 'ID16'],
#  ['ID6', 'ID39'],
#  ['ID6', 'ID62'],
#  ['ID6', 'ID42'],
#  ['ID6', 'ID6'],
#  ['ID6', 'ID74'],
#  ['ID6', 'ID17'],
#  ['ID6', 'ID70'],
#  ['ID6', 'ID33'],
#  ['ID6', 'ID85'],
#  ['ID6', 'ID23'],
#  ['ID6', 'ID3'],
#  ['ID6', 'ID24'],
#  ['ID6', 'ID79'],
#  ['ID6', 'ID19'],
#  ['ID6', 'ID48'],
#  ['ID6', 'ID37'],
#  ['ID6', 'ID87'],
#  ['ID6', 'ID46'],
#  ['ID6', 'ID10'],
#  ['ID6', 'ID86'],
#  ['ID6', 'ID61'],
#  ['ID6', 'ID82'],
#  ['ID6', 'ID90'],
#  ['ID6', 'ID13'],
#  ['ID6', 'ID18'],
#  ['ID6', 'ID41'],
#  ['ID6', 'ID81'],
#  ['ID6', 'ID7'],
#  ['ID6', 'ID14'],
#  ['ID6', 'ID52'],
#  ['ID6', 'ID68'],
#  ['ID6', 'ID76'],
#  ['ID6', 'ID53'],
#  ['ID6', 'ID27'],
#  ['ID6', 'ID20'],
#  ['ID6', 'ID4'],
#  ['ID6', 'ID22'],
#  ['ID6', 'ID47'],
#  ['ID6', 'ID44'],
#  ['ID6', 'ID55'],
#  ['ID6', 'ID43'],
#  ['ID6', 'ID1'],
#  ['ID6', 'ID21'],
#  ['ID6', 'ID2'],
#  ['ID6', 'ID60'],
#  ['ID6', 'ID35'],
#  ['ID6', 'ID30'],
#  ['ID6', 'ID69'],
#  ['ID6', 'ID73'],
#  ['ID6', 'ID28'],
#  ['ID6', 'ID64'],
#  ['ID6', 'ID67'],
#  ['ID6', 'ID34'],
#  ['ID6', 'ID83'],
#  ['ID6', 'ID51'],
#  ['ID6', 'ID29'],
#  ['ID6', 'ID72'],
#  ['ID9', 'ID65'],
#  ['ID9', 'ID40'],
#  ['ID9', 'ID31'],
#  ['ID9', 'ID89'],
#  ['ID9', 'ID9'],
#  ['ID9', 'ID49'],
#  ['ID9', 'ID80'],
#  ['ID9', 'ID5'],
#  ['ID9', 'ID57'],
#  ['ID9', 'ID26'],
#  ['ID9', 'ID88'],
#  ['ID9', 'ID25'],
#  ['ID9', 'ID11'],
#  ['ID9', 'ID54'],
#  ['ID9', 'ID45'],
#  ['ID9', 'ID59'],
#  ['ID9', 'ID71'],
#  ['ID9', 'ID63'],
#  ['ID9', 'ID15'],
#  ['ID9', 'ID8'],
#  ['ID9', 'ID75'],
#  ['ID9', 'ID56'],
#  ['ID9', 'ID32'],
#  ['ID9', 'ID36'],
#  ['ID9', 'ID58'],
#  ['ID9', 'ID78'],
#  ['ID9', 'ID84'],
#  ['ID9', 'ID12'],
#  ['ID9', 'ID66'],
#  ['ID9', 'ID50'],
#  ['ID9', 'ID38'],
#  ['ID9', 'ID77'],
#  ['ID9', 'ID16'],
#  ['ID9', 'ID39'],
#  ['ID9', 'ID62'],
#  ['ID9', 'ID42'],
#  ['ID9', 'ID6'],
#  ['ID9', 'ID74'],
#  ['ID9', 'ID17'],
#  ['ID9', 'ID70'],
#  ['ID9', 'ID33'],
#  ['ID9', 'ID85'],
#  ['ID9', 'ID23'],
#  ['ID9', 'ID3'],
#  ['ID9', 'ID24'],
#  ['ID9', 'ID79'],
#  ['ID9', 'ID19'],
#  ['ID9', 'ID48'],
#  ['ID9', 'ID37'],
#  ['ID9', 'ID87'],
#  ['ID9', 'ID46'],
#  ['ID9', 'ID10'],
#  ['ID9', 'ID86'],
#  ['ID9', 'ID61'],
#  ['ID9', 'ID82'],
#  ['ID9', 'ID90'],
#  ['ID9', 'ID13'],
#  ['ID9', 'ID18'],
#  ['ID9', 'ID41'],
#  ['ID9', 'ID81'],
#  ['ID9', 'ID7'],
#  ['ID9', 'ID14'],
#  ['ID9', 'ID52'],
#  ['ID9', 'ID68'],
#  ['ID9', 'ID76'],
#  ['ID9', 'ID53'],
#  ['ID9', 'ID27'],
#  ['ID9', 'ID20'],
#  ['ID9', 'ID4'],
#  ['ID9', 'ID22'],
#  ['ID9', 'ID47'],
#  ['ID9', 'ID44'],
#  ['ID9', 'ID55'],
#  ['ID9', 'ID43'],
#  ['ID9', 'ID1'],
#  ['ID9', 'ID21'],
#  ['ID9', 'ID2'],
#  ['ID9', 'ID60'],
#  ['ID9', 'ID35'],
#  ['ID9', 'ID30'],
#  ['ID9', 'ID69'],
#  ['ID9', 'ID73'],
#  ['ID9', 'ID28'],
#  ['ID9', 'ID64'],
#  ['ID9', 'ID67'],
#  ['ID9', 'ID34'],
#  ['ID9', 'ID83'],
#  ['ID9', 'ID51'],
#  ['ID9', 'ID29'],
#  ['ID9', 'ID72'],
#  ['ID65', 'ID40'],
#  ['ID65', 'ID31'],
#  ['ID65', 'ID89'],
#  ['ID65', 'ID9'],
#  ['ID65', 'ID49'],
#  ['ID65', 'ID80'],
#  ['ID65', 'ID5'],
#  ['ID65', 'ID57'],
#  ['ID65', 'ID26'],
#  ['ID65', 'ID88'],
#  ...]

# %%
# 关联度归一化
def MaxMinNormalization(x,Max,Min):
    x = (x - Min) / (Max - Min)
    return x

# %%
new_sims = [MaxMinNormalization(i, max(sims), min(sims)) for i in sims] 
new_sims
# Out:
# [0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5226364846870838,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.38482023968042606,
#  0.11984021304926763,
#  0.72237017310253,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.46271637816245004,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5359520639147803,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4560585885486018,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.28628495339547266,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.599866844207723,
#  0.11984021304926763,
#  0.5559254327563248,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.655792276964048,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.529294274300932,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5359520639147803,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.34886817576564577,
#  0.34087882822902793,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.37350199733688416,
#  0.6171770972037283,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.35086551264980026,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.474034620505992,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5739014647137151,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.7403462050599201,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.6737683089214381,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.933422103861518,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.8135818908122503,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5339547270306257,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.933422103861518,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.27097203728362185,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5512649800266312,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.17576564580559254,
#  0.11984021304926763,
#  0.30226364846870835,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4127829560585885,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.22636484687083888,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3868175765645805,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5892143808255659,
#  0.11984021304926763,
#  0.3761651131824234,
#  0.11984021304926763,
#  0.42942743009320905,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4347536617842876,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4760319573901464,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4560585885486018,
#  0.4560585885486018,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5758988015978694,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5119840213049267,
#  0.5226364846870838,
#  0.72237017310253,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.46271637816245004,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.39280958721704384,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.6025299600532623,
#  0.11984021304926763,
#  0.4547270306258322,
#  0.42210386151797596,
#  0.4280958721704394,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4513981358189081,
#  0.11984021304926763,
#  0.37350199733688416,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5013315579227696,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.41744340878828223,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.46071904127829555,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.7150466045272968,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3175765645805593,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3115845539280958,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.44474034620505987,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4940079893475366,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.44873501997336884,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.7536617842876164,
#  0.3801597869507323,
#  0.3994673768308921,
#  0.59254327563249,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.48268974700399464,
#  0.11984021304926763,
#  0.40479360852197066,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.8948069241011984,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4900133155792276,
#  0.11984021304926763,
#  0.2769640479360852,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.770306258322237,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.32756324900133155,
#  0.4687083888149134,
#  0.3661784287616511,
#  0.36817576564580556,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.38814913448735017,
#  0.4087882822902796,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.32689747003994674,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4207723035952063,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5825565912117177,
#  0.3901464713715046,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3828229027962716,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5159786950732357,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.22836218375499331,
#  0.11984021304926763,
#  0.5266311584553928,
#  0.16311584553928096,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.6038615179760319,
#  0.34087882822902793,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3655126498002663,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.1904127829560586,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.18308921438082554,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.25233022636484687,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3209054593874833,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.6704394141145139,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4260985352862849,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.6950732356857523,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3894806924101198,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.46471371504660447,
#  0.11984021304926763,
#  0.6644474034620506,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.17177097203728361,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3768308921438082,
#  0.11984021304926763,
#  0.4041278295605858,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.47736351531291604,
#  0.48468708388814913,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.39813581890812244,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.22836218375499331,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4260985352862849,
#  0.5865512649800266,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.3868175765645805,
#  0.11984021304926763,
#  0.3868175765645805,
#  0.11984021304926763,
#  0.6031957390146471,
#  0.11984021304926763,
#  0.4181091877496671,
#  0.11984021304926763,
#  0.355525965379494,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4041278295605858,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5346205059920107,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.47736351531291604,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.47736351531291604,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.4454061251664447,
#  0.33155792276964047,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.559254327563249,
#  0.2210386151797603,
#  0.11984021304926763,
#  0.31491344873502,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5099866844207722,
#  0.11984021304926763,
#  0.44340878828229024,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.5139813581890812,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  0.11984021304926763,
#  ...]

# %%
result3 = pd.DataFrame(data=idxs, columns=['产品1ID', '产品2ID'])
result3['关联度'] = sims
result3
# Out:
#      产品1ID 产品2ID   关联度
# 0     ID26  ID56  0.00
# 1     ID26  ID72  0.00
# 2     ID26  ID54  0.00
# 3     ID26  ID33  0.00
# 4     ID26  ID27  0.00
# ...    ...   ...   ...
# 7903  ID29  ID19  0.00
# 7904  ID29  ID62  0.00
# 7905  ID29  ID12  0.00
# 7906  ID29  ID76  4.83
# 7907  ID29  ID58  0.00
#
# [7908 rows x 3 columns]

# %%
prods = pd.DataFrame(data=entity_names, columns=['产品1', '产品2'])
prods
# Out:
#        产品1    产品2
# 0     海滨公园    叉烧饭
# 1     海滨公园  脆皮热狗卷
# 2     海滨公园   榴莲千层
# 3     海滨公园  御水古温泉
# 4     海滨公园    大角湾
# ...    ...    ...
# 7903   露天矿    天马山
# 7904   露天矿     泡芙
# 7905   露天矿     甜点
# 7906   露天矿     酱汁
# 7907   露天矿     蔬菜
#
# [7908 rows x 2 columns]

# %%
# result3.to_csv('data/result3.csv', index=False)

# %%
result_name = result3
result_name['产品1'] = prods['产品1']
result_name['产品2'] = prods['产品2']
result_name.head()
# Out:
#   产品1ID 产品2ID  关联度   产品1    产品2
# 0  ID26  ID56  0.0  海滨公园    叉烧饭
# 1  ID26  ID72  0.0  海滨公园  脆皮热狗卷
# 2  ID26  ID54  0.0  海滨公园   榴莲千层
# 3  ID26  ID33  0.0  海滨公园  御水古温泉
# 4  ID26  ID27  0.0  海滨公园    大角湾

# %%
# result_name.to_csv('data/new_result3.csv', index=False)

# %%
result_name.shape
# Out:
# (7908, 5)

# %%
dup_result = []
for i, j in zip(result_name['产品1'].values, result_name['产品2'].values):
    if i == j:
        dup_result.append(False)
    else:
        dup_result.append(True)
dup_result
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
sum(dup_result)
# Out:
# 7818

# %%
new_result = result3[dup_result]
all_result = result_name[dup_result]

# %%
submit = new_result[['产品1ID', '产品2ID', '关联度']]
submit.head()
# Out:
#   产品1ID 产品2ID  关联度
# 0  ID26  ID56  0.0
# 1  ID26  ID72  0.0
# 2  ID26  ID54  0.0
# 3  ID26  ID33  0.0
# 4  ID26  ID27  0.0

# %%
submit.to_csv('data/result3.csv', index=False)
all_result.to_csv('data/result3(包含产品名).csv', index=False)
